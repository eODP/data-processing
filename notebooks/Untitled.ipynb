# %%
import sys
sys.path.append('../scripts/')
import glob

import pandas as pd

# %%
def unique_filenames(paths):
    index = len(paths[0].split('/')) - 1
    
    files = set()
    for path in paths:
        filename = path.split('/')[index]
        files.add(filename)
    print('unique files', len(files))
        
    for file in files:
        print(file)

def unique_columns(paths):
    columns = set()
    for path in paths:
        df = pd.read_csv(path, nrows=1)
        columns.update(df.columns)
     
    for column in columns:
        print(column)

# %% [markdown]
# ## DSDP_core_data

# %%
path = 'raw_data/NOAA_csv/DSDP_core_data'
csv_paths = glob.glob(f"{path}/**/**/*.csv")
print('files', len(csv_paths))
# Out:
# files 4477

# %%
contents = {}
index = len(csv_paths[0].split('/')) - 1

for path in csv_paths:
    parts = path.split('/')
    exp = parts[3]
    filename = parts[index]
    
    if exp not in contents:
        contents[exp] = {'taxa': set(), 'lithology': None, 'age_model': None}
        
    if filename == 'vistxt.csv':
        contents[exp]['lithology'] = 'vistxt.csv'
    elif filename == 'ageprof.csv':
        contents[exp]['age_model'] = 'ageprof.csv'
    else:
        contents[exp]['taxa'].add(filename)
    
for exp in contents.items():
    print(exp)
# Out:
# ('61', {'taxa': {'nannos.csv', 'b_forams.csv', 'radiolar.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('95', {'taxa': {'b_forams.csv', 'nannos.csv', 'radiolar.csv', 'diatoms.csv', 'ostracod.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('59', {'taxa': {'b_forams.csv', 'siliflag.csv', 'nannos.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('92', {'taxa': {'hr_desc.csv', 'nannos.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('66', {'taxa': {'radiolar.csv', 'nannos.csv', 'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('50', {'taxa': {'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('68', {'taxa': {'siliflag.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('57', {'taxa': {'b_forams.csv', 'siliflag.csv', 'nannos.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'pollen.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('32', {'taxa': {'b_forams.csv', 'siliflag.csv', 'nannos.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'ostracod.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('35', {'taxa': {'b_forams.csv', 'nannos.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('69', {'taxa': {'hr_desc.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('56', {'taxa': {'b_forams.csv', 'radiolar.csv', 'diatoms.csv', 'pollen.csv', 'ostracod.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('51', {'taxa': {'hr_desc.csv', 'nannos.csv', 'diatoms.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('58', {'taxa': {'hr_desc.csv', 'nannos.csv', 'p_forams.csv', 'b_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('67', {'taxa': {'nannos.csv', 'siliflag.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('93', {'taxa': {'nannos.csv', 'ebri_act.csv', 'b_forams.csv', 'radiolar.csv', 'diatoms.csv', 'p_forams.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('94', {'taxa': {'nannos.csv', 'siliflag.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('60', {'taxa': {'b_forams.csv', 'nannos.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('34', {'taxa': {'b_forams.csv', 'nannos.csv', 'siliflag.csv', 'hr_desc.csv', 'ostracod.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('33', {'taxa': {'nannos.csv', 'b_forams.csv', 'radiolar.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('47A', {'taxa': {'nannos.csv', 'p_forams.csv', 'b_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('87B', {'taxa': {'b_forams.csv', 'nannos.csv', 'diatoms.csv', 'ostracod.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('20', {'taxa': {'nannos.csv', 'siliflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('18', {'taxa': {'nannos.csv', 'b_forams.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv', 'pollen.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('27', {'taxa': {'nannos.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('9', {'taxa': {'nannos.csv', 'siliflag.csv', 'b_forams.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('78B', {'taxa': {'nannos.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('11', {'taxa': {'nannos.csv', 'b_forams.csv', 'hr_desc.csv', 'ostracod.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('7', {'taxa': {'nannos.csv', 'siliflag.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('29', {'taxa': {'nannos.csv', 'ebri_act.csv', 'pollen.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('16', {'taxa': {'nannos.csv', 'siliflag.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('42', {'taxa': {'b_forams.csv', 'ebri_act.csv', 'siliflag.csv', 'nannos.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'pollen.csv', 'ostracod.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('89', {'taxa': {'nannos.csv', 'b_forams.csv', 'radiolar.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('45', {'taxa': {'b_forams.csv', 'nannos.csv', 'p_forams.csv', 'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('73', {'taxa': {'nannos.csv', 'b_forams.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('80', {'taxa': {'nannos.csv', 'b_forams.csv', 'radiolar.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('74', {'taxa': {'nannos.csv', 'p_forams.csv', 'hr_desc.csv', 'b_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('6', {'taxa': {'nannos.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('28', {'taxa': {'nannos.csv', 'b_forams.csv', 'pollen.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('17', {'taxa': {'ebri_act.csv', 'siliflag.csv', 'nannos.csv', 'b_forams.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('1', {'taxa': {'nannos.csv', 'b_forams.csv', 'radiolar.csv', 'diatoms.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('10', {'taxa': {'radiolar.csv', 'nannos.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('19', {'taxa': {'ebri_act.csv', 'siliflag.csv', 'nannos.csv', 'b_forams.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('26', {'taxa': {'hr_desc.csv', 'pollen.csv', 'nannos.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('8', {'taxa': {'nannos.csv', 'siliflag.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('21', {'taxa': {'nannos.csv', 'siliflag.csv', 'b_forams.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('75', {'taxa': {'nannos.csv', 'p_forams.csv', 'hr_desc.csv', 'b_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('81', {'taxa': {'b_forams.csv', 'radiolar.csv', 'dinoflag.csv', 'hr_desc.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('86', {'taxa': {'nannos.csv', 'b_forams.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('72', {'taxa': {'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('44', {'taxa': {'nannos.csv', 'radiolar.csv', 'diatoms.csv', 'pollen.csv', 'ostracod.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('43', {'taxa': {'hr_desc.csv', 'diatoms.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('88', {'taxa': {'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': None})
# ('38', {'taxa': {'nannos.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('36', {'taxa': {'nannos.csv', 'siliflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('31', {'taxa': {'nannos.csv', 'ebri_act.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('91', {'taxa': {'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': None})
# ('65', {'taxa': {'radiolar.csv', 'p_forams.csv', 'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('62', {'taxa': {'hr_desc.csv', 'siliflag.csv', 'diatoms.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('96', {'taxa': {'nannos.csv', 'b_forams.csv', 'radiolar.csv', 'p_forams.csv', 'pollen.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('54', {'taxa': {'nannos.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('53', {'taxa': {'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('30', {'taxa': {'nannos.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('37', {'taxa': {'nannos.csv', 'siliflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('39', {'taxa': {'ebri_act.csv', 'siliflag.csv', 'nannos.csv', 'b_forams.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('52', {'taxa': {'hr_desc.csv', 'nannos.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('55', {'taxa': {'b_forams.csv', 'nannos.csv', 'siliflag.csv', 'ebri_act.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('63', {'taxa': {'siliflag.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('64', {'taxa': {'b_forams.csv', 'nannos.csv', 'radiolar.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('90', {'taxa': {'b_forams.csv', 'siliflag.csv', 'nannos.csv', 'ebri_act.csv', 'radiolar.csv', 'diatoms.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('47B', {'taxa': {'nannos.csv', 'p_forams.csv', 'b_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('87A', {'taxa': {'b_forams.csv', 'nannos.csv', 'diatoms.csv', 'ostracod.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('46', {'taxa': {'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('79', {'taxa': {'radiolar.csv', 'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('41', {'taxa': {'b_forams.csv', 'nannos.csv', 'siliflag.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('83', {'taxa': {'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': None})
# ('77', {'taxa': {'hr_desc.csv', 'nannos.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('48', {'taxa': {'b_forams.csv', 'p_forams.csv', 'ostracod.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('70', {'taxa': {'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('84', {'taxa': {'b_forams.csv', 'nannos.csv', 'diatoms.csv', 'hr_desc.csv', 'pollen.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('24', {'taxa': {'nannos.csv', 'b_forams.csv', 'siliflag.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'ostracod.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('23', {'taxa': {'radiolar.csv', 'diatoms.csv', 'p_forams.csv', 'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('4', {'taxa': {'nannos.csv', 'radiolar.csv', 'p_forams.csv', 'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('15', {'taxa': {'nannos.csv', 'radiolar.csv', 'p_forams.csv', 'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('78A', {'taxa': {'nannos.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('3', {'taxa': {'nannos.csv', 'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('12', {'taxa': {'hr_desc.csv', 'radiolar.csv', 'nannos.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('85', {'taxa': {'nannos.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('71', {'taxa': {'b_forams.csv', 'nannos.csv', 'pollen.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('76', {'taxa': {'b_forams.csv', 'p_forams.csv', 'hr_desc.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('82', {'taxa': {'hr_desc.csv', 'nannos.csv', 'siliflag.csv', 'b_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('49', {'taxa': {'nannos.csv', 'siliflag.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('40', {'taxa': {'b_forams.csv', 'siliflag.csv', 'nannos.csv', 'radiolar.csv', 'dinoflag.csv', 'p_forams.csv', 'pollen.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('2', {'taxa': {'hr_desc.csv', 'radiolar.csv', 'nannos.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('13', {'taxa': {'nannos.csv', 'siliflag.csv', 'ebri_act.csv', 'phyliths.csv', 'radiolar.csv', 'diatoms.csv', 'hr_desc.csv', 'ostracod.csv', 'pollen.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('5', {'taxa': {'hr_desc.csv', 'nannos.csv', 'siliflag.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('14', {'taxa': {'b_forams.csv', 'nannos.csv', 'radiolar.csv', 'dinoflag.csv', 'hr_desc.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('22', {'taxa': {'nannos.csv', 'siliflag.csv', 'b_forams.csv', 'radiolar.csv', 'dinoflag.csv', 'diatoms.csv', 'hr_desc.csv', 'pollen.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})
# ('25', {'taxa': {'hr_desc.csv', 'radiolar.csv', 'nannos.csv', 'p_forams.csv'}, 'lithology': 'vistxt.csv', 'age_model': 'ageprof.csv'})

# %%
unique_filenames(csv_paths)
# Out:
# unique files 14
# b_forams.csv
# nannos.csv
# siliflag.csv
# ebri_act.csv
# phyliths.csv
# radiolar.csv
# dinoflag.csv
# diatoms.csv
# hr_desc.csv
# ageprof.csv
# vistxt.csv
# pollen.csv
# ostracod.csv
# p_forams.csv

# %%
unique_columns(csv_paths)
# Out:
# average age(million years)t
# z-coding
# sample midpoint depth(m)
# auxiliary age
# total number of observed fossils
# bottom of layer depth (m)
# color
# chemical overgrowth
# hardness or induration
# top of section(m)
# investigators name
# age
# mechanical preservations
# group abundance
# fossil group
# unknown code
# other information data
# deformations due to drilling
# special condition
# publication date (month/year)
# age top of section(million years)
# bottom interval depth (cm)
# bottom of section depth(m)
# fossil
# top of core depth(m)
# groundmass mineral data
# top interval depth (cm)
# coredepth(m)
# averaged age
# site
# age bottom of section(million years)
# other observations
# piece numbers
# page number reference
# age mnemonic
# chemical dissolution
# fossil abundance
# core
# phenocryst data
# replacement mineral data
# structures
# data source
# top interval depth(cm)
# top of layer depth (m)
# leg
# section
# auxiliary age mnemonic
# sample depth(m)
# top of section depth(m)
# lithology
# fossil preservation
# minerals
# paleontology
# texture data
# fossil code
# top of core depth(cm)
# vesicle data
# rock name
#  describer
# structure data
# comments
# dsdp initial report volume number
# unusual occurrences
# describer
# record join code
# alteration data
# hole

# %% [markdown]
# ## JanusIODP_paleo_agemodel

# %%
path = 'raw_data/NOAA_csv/JanusIODP_paleo_agemodel'
csv_paths = glob.glob(f"{path}/**/**/**/**/**/*.csv")
print('files', len(csv_paths))
# Out:
# files 2481

# %%
contents = {}
index = len(csv_paths[0].split('/')) - 1

for path in csv_paths:
    parts = path.split('/')
    exp = parts[5]
    filename = parts[index]
    
    if exp not in contents:
        contents[exp] = {'taxa': set(),'age_model': set()}
        
    ages = ['Age_Model_Shipboard.csv', 'Age_Model_Initial_Reports.csv', 
            'Age_Model_Post_Moratorium.csv', 'Age_Model_Shipboard_Report.csv', 
            'Age_Model_Initial_Report.csv'
           ]
        
    if filename in ages:
        contents[exp]['age_model'].add(filename)
    else:
        contents[exp]['taxa'].add(filename)
    
for exp in contents.items():
    print(exp)
# Out:
# ('135', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('104', {'taxa': {'Bolboforms.csv', 'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Pollen_Spores.csv', 'Macrofossils.csv', 'Radiolarians.csv', 'Nannofossils.csv', 'Ostracodes.csv', 'Miscellaneous.csv', 'Benthic_Foraminifers.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Reports.csv'}})
# ('168', {'taxa': {'Nannofossils.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('157', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Report.csv', 'Age_Model_Shipboard.csv'}})
# ('150', {'taxa': {'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Radiolarians.csv', 'Nannofossils.csv', 'Diatoms.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('159', {'taxa': {'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Pollen_Spores.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Ostracodes.csv', 'Benthic_Foraminifers.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('166', {'taxa': {'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('161', {'taxa': {'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('105', {'taxa': set(), 'age_model': {'Age_Model_Initial_Reports.csv'}})
# ('133', {'taxa': {'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv', 'Nannofossils.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv'}})
# ('134', {'taxa': {'Pteropods.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv'}})
# ('160', {'taxa': {'Nannofossils.csv', 'Ostracodes.csv', 'Benthic_Foraminifers.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Shipboard.csv'}})
# ('145', {'taxa': {'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Pollen_Spores.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv'}})
# ('116', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('111', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('127', {'taxa': {'Pollen_Spores.csv', 'Sponge_Spicules.csv', 'Nannofossils.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('120', {'taxa': {'Bolboforms.csv', 'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Sponge_Spicules.csv', 'Pollen_Spores.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Miscellaneous.csv', 'Benthic_Foraminifers.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('144', {'taxa': {'Nannofossils.csv', 'Diatoms.csv', 'Planktonic_Foraminifers .csv', 'Ostracodes.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('172', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('121', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('119', {'taxa': {'Trace_Fossils.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Nannofossils .csv', 'Miscellaneous.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv'}})
# ('126', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('128', {'taxa': {'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('117', {'taxa': {'Nannofossils.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('154', {'taxa': {'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('162', {'taxa': {'Bolboforms.csv', 'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('165', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('131', {'taxa': {'Nannofossils.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv'}})
# ('138', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Planktonic_Foraminifers.csv', 'Silicoflagellates_Ebridians_Actiniscidians.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('190', {'taxa': {'Nannofossils.csv'}, 'age_model': {'Age_Model_Initial_Reports.csv', 'Age_Model_Shipboard.csv'}})
# ('101', {'taxa': {'Sponge_Spicules.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Dinoflagellates_Acritarchs_Prasinophytes.csv', 'Ostracodes.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv'}})
# ('108', {'taxa': {'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Pollen_Spores.csv', 'Nannofossils.csv', 'Benthic Foraminifers.csv', 'Planktonic Foraminifers.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('130', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('115', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('124', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('170', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Diatoms.csv'}, 'age_model': {'Age_Model_Initial_Report.csv', 'Age_Model_Shipboard.csv'}})
# ('125', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('114', {'taxa': {'Bolboforms.csv', 'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': {'Age_Model_Post_Moratorium.csv', 'Age_Model_Initial_Report.csv'}})
# ('113', {'taxa': set(), 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('182', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Shipboard_Report.csv'}})
# ('149', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('171', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': {'Age_Model_Initial_Report.csv'}})
# ('132', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('192', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': set()})
# ('195', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('194', {'taxa': {'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': set()})
# ('167', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Planktonic_Foraminifers.csv', 'Diatoms.csv'}, 'age_model': set()})
# ('151', {'taxa': {'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Pollen_Spores.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Ostracodes.csv', 'Benthic_Foraminifers.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('169', {'taxa': {'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('156', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv'}, 'age_model': set()})
# ('210', {'taxa': {'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('204', {'taxa': {'Nannofossils.csv', 'Diatoms.csv'}, 'age_model': set()})
# ('174', {'taxa': {'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': set()})
# ('180', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('173', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('189', {'taxa': {'Pollen_Spores.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('129', {'taxa': {'Pollen_Spores.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Benthic_Foraminifers.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv'}, 'age_model': set()})
# ('143', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Ostracodes.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('188', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('186', {'taxa': {'Nannofossils.csv', 'Diatoms.csv'}, 'age_model': set()})
# ('181', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('175', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('110', {'taxa': {'Nannofossils.csv', 'Benthic_Foraminifers.csv'}, 'age_model': set()})
# ('198', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': set()})
# ('191', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Benthic_Foraminifers.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('136', {'taxa': {'Radiolarians.csv', 'Silicoflagellates_Ebridians_Actiniscidians.csv'}, 'age_model': set()})
# ('164', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Diatoms.csv'}, 'age_model': set()})
# ('197', {'taxa': {'Nannofossils.csv'}, 'age_model': set()})
# ('155', {'taxa': {'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('199', {'taxa': {'Nannofossils.csv', 'Radiolarians.csv', 'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': set()})
# ('152', {'taxa': {'Bolboforms.csv', 'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Nannofossils.csv', 'Diatoms.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('139', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Benthic_Foraminifers.csv'}, 'age_model': set()})
# ('200', {'taxa': {'Nannofossils.csv'}, 'age_model': set()})
# ('207', {'taxa': {'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('112', {'taxa': {'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Sponge_Spicules.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Benthic_Foraminifers.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('123', {'taxa': {'Pollen_Spores.csv', 'Nannofossils.csv', 'Radiolarians.csv', 'Benthic_Foraminifers.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('184', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('177', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv'}, 'age_model': set()})
# ('183', {'taxa': {'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('141', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv', 'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Benthic_Foraminifers.csv'}, 'age_model': set()})
# ('146', {'taxa': {'Silicoflagellates_Ebridians_Actiniscidians.csv', 'Radiolarians.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('179', {'taxa': {'Nannofossils.csv'}, 'age_model': set()})
# ('122', {'taxa': {'Pollen_Spores.csv', 'Nannofossils.csv', 'Macrofossils.csv', 'Radiolarians.csv', 'Ostracodes.csv', 'Dinoflagellates_Acritarch_Prasinophytes.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})
# ('178', {'taxa': {'Radiolarians.csv', 'Planktonic_Foraminifers.csv', 'Diatoms.csv', 'Benthic_Foraminifers.csv'}, 'age_model': set()})
# ('185', {'taxa': {'Nannofossils.csv', 'Planktonic_Foraminifers.csv'}, 'age_model': set()})

# %%
unique_filenames(csv_paths)
# Out:
# unique files 25
# Sponge_Spicules.csv
# Trace_Fossils.csv
# Benthic Foraminifers.csv
# Planktonic_Foraminifers .csv
# Miscellaneous.csv
# Dinoflagellates_Acritarchs_Prasinophytes.csv
# Age_Model_Shipboard.csv
# Bolboforms.csv
# Nannofossils.csv
# Silicoflagellates_Ebridians_Actiniscidians.csv
# Radiolarians.csv
# Diatoms.csv
# Nannofossils .csv
# Benthic_Foraminifers.csv
# Dinoflagellates_Acritarch_Prasinophytes.csv
# Age_Model_Initial_Reports.csv
# Pteropods.csv
# Pollen_Spores.csv
# Macrofossils.csv
# Planktonic Foraminifers.csv
# Ostracodes.csv
# Age_Model_Post_Moratorium.csv
# Age_Model_Shipboard_Report.csv
# Age_Model_Initial_Report.csv
# Planktonic_Foraminifers.csv

# %%
# unique_columns(csv_paths)

# %% [markdown]
# ## Janus_core_data

# %%
path = 'raw_data/NOAA_csv/Janus_core_data'
csv_paths = glob.glob(f"{path}/**/**/*.csv")
print('files', len(csv_paths))
# Out:
# files 325

# %%
contents = {}

for path in csv_paths:
    parts = path.split('/')
    exp = parts[3]
    
    if exp not in contents:
        contents[exp] = {'lithology': 'xxx-delimited_pre-janus.csv'}
        
    
for exp in contents.items():
    print(exp)
# Out:
# ('104', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('103', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('105', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('116', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('111', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('118', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('120', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('121', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('119', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('126', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('110', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('117', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('107', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('101', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('108', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('112', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('115', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('123', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('124', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('125', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('122', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('114', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('113', {'lithology': 'xxx-delimited_pre-janus.csv'})
# ('124e', {'lithology': 'xxx-delimited_pre-janus.csv'})

# %%
unique_filenames(csv_paths)
# Out:
# unique files 325
# sed_lith_117_730a_delimited_pre-janus.csv
# sed_lith_121_758a_delimited_pre-janus.csv
# sed_lith_114_704b_delimited_pre-janus.csv
# sed_lith_126_790b_delimited_pre-janus.csv
# sed_lith_124e_777c_delimited_pre-janus.csv
# sed_lith_117_725c_delimited_pre-janus.csv
# sed_lith_121_752a_delimited_pre-janus.csv
# sed_lith_125_781a_delimited_pre-janus.csv
# sed_lith_118_734g_delimited_pre-janus.csv
# sed_lith_115_706a_delimited_pre-janus.csv
# sed_lith_126_790c_delimited_pre-janus.csv
# sed_lith_111_678b_delimited_pre-janus.csv
# sed_lith_108_661b_delimited_pre-janus.csv
# sed_lith_112_684c_delimited_pre-janus.csv
# sed_lith_119_741a_delimited_pre-janus.csv
# sed_lith_108_664b_delimited_pre-janus.csv
# sed_lith_108_667a_delimited_pre-janus.csv
# sed_lith_105_645g_delimited_pre-janus.csv
# sed_lith_101_632a_delimited_pre-janus.csv
# sed_lith_113_689d_delimited_pre-janus.csv
# sed_lith_107_655a_delimited_pre-janus.csv
# sed_lith_124_769b_delimited_pre-janus.csv
# sed_lith_108_658b_delimited_pre-janus.csv
# sed_lith_112_687b_delimited_pre-janus.csv
# sed_lith_114_701b_delimited_pre-janus.csv
# sed_lith_101_628a_delimited_pre-janus.csv
# sed_lith_112_681b_delimited_pre-janus.csv
# sed_lith_124_767b_delimited_pre-janus.csv
# sed_lith_112_682a_delimited_pre-janus.csv
# sed_lith_108_657b_delimited_pre-janus.csv
# sed_lith_105_645d_delimited_pre-janus.csv
# sed_lith_117_721a_delimited_pre-janus.csv
# sed_lith_112_681a_delimited_pre-janus.csv
# sed_lith_117_721c_delimited_pre-janus.csv
# sed_lith_107_654a_delimited_pre-janus.csv
# sed_lith_101_632b_delimited_pre-janus.csv
# sed_lith_126_792d_delimited_pre-janus.csv
# sed_lith_104_644a_delimited_pre-janus.csv
# sed_lith_104_642d_delimited_pre-janus.csv
# sed_lith_103_641a_delimited_pre-janus.csv
# sed_lith_101_630a_delimited_pre-janus.csv
# sed_lith_124_770b_delimited_pre-janus.csv
# sed_lith_114_702a_delimited_pre-janus.csv
# sed_lith_122_761a_delimited_pre-janus.csv
# sed_lith_121_752b_delimited_pre-janus.csv
# sed_lith_115_706c_delimited_pre-janus.csv
# sed_lith_121_757c_delimited_pre-janus.csv
# sed_lith_119_736a_delimited_pre-janus.csv
# sed_lith_103_638c_delimited_pre-janus.csv
# sed_lith_112_686b_delimited_pre-janus.csv
# sed_lith_108_659b_delimited_pre-janus.csv
# sed_lith_122_763c_delimited_pre-janus.csv
# sed_lith_105_645b_delimited_pre-janus.csv
# sed_lith_113_692a_delimited_pre-janus.csv
# sed_lith_115_705a_delimited_pre-janus.csv
# sed_lith_107_656a_delimited_pre-janus.csv
# sed_lith_124_770c_delimited_pre-janus.csv
# sed_lith_119_736c_delimited_pre-janus.csv
# sed_lith_112_679a_delimited_pre-janus.csv
# sed_lith_114_700b_delimited_pre-janus.csv
# sed_lith_125_782b_delimited_pre-janus.csv
# sed_lith_126_792e_delimited_pre-janus.csv
# sed_lith_124e_777d_delimited_pre-janus.csv
# sed_lith_125_778a_delimited_pre-janus.csv
# sed_lith_121_758c_delimited_pre-janus.csv
# sed_lith_111_677b_delimited_pre-janus.csv
# sed_lith_117_724b_delimited_pre-janus.csv
# sed_lith_113_694a_delimited_pre-janus.csv
# sed_lith_104_643a_delimited_pre-janus.csv
# sed_lith_108_664d_delimited_pre-janus.csv
# sed_lith_119_745b_delimited_pre-janus.csv
# sed_lith_117_722b_delimited_pre-janus.csv
# sed_lith_121_756d_delimited_pre-janus.csv
# sed_lith_126_793a_delimited_pre-janus.csv
# sed_lith_101_627b_delimited_pre-janus.csv
# sed_lith_113_690c_delimited_pre-janus.csv
# sed_lith_116_717b_delimited_pre-janus.csv
# sed_lith_124_768c_delimited_pre-janus.csv
# sed_lith_108_662b_delimited_pre-janus.csv
# sed_lith_116_718c_delimited_pre-janus.csv
# sed_lith_101_636a_delimited_pre-janus.csv
# sed_lith_119_736b_delimited_pre-janus.csv
# sed_lith_121_754a_delimited_pre-janus.csv
# sed_lith_105_645a_delimited_pre-janus.csv
# sed_lith_108_668b_delimited_pre-janus.csv
# sed_lith_103_641c_delimited_pre-janus.csv
# sed_lith_101_633a_delimited_pre-janus.csv
# sed_lith_117_722a_delimited_pre-janus.csv
# sed_lith_108_665a_delimited_pre-janus.csv
# sed_lith_113_693b_delimited_pre-janus.csv
# sed_lith_123_765b_delimited_pre-janus.csv
# sed_lith_112_679d_delimited_pre-janus.csv
# sed_lith_112_679e_delimited_pre-janus.csv
# sed_lith_101_626b_delimited_pre-janus.csv
# sed_lith_120_747c_delimited_pre-janus.csv
# sed_lith_112_688e_delimited_pre-janus.csv
# sed_lith_124_767a_delimited_pre-janus.csv
# sed_lith_107_650a_delimited_pre-janus.csv
# sed_lith_113_690b_delimited_pre-janus.csv
# sed_lith_113_693a_delimited_pre-janus.csv
# sed_lith_124_770a_delimited_pre-janus.csv
# sed_lith_120_747a_delimited_pre-janus.csv
# sed_lith_108_667b_delimited_pre-janus.csv
# sed_lith_103_639b_delimited_pre-janus.csv
# sed_lith_101_631a_delimited_pre-janus.csv
# sed_lith_104_642c_delimited_pre-janus.csv
# sed_lith_125_782a_delimited_pre-janus.csv
# sed_lith_115_712a_delimited_pre-janus.csv
# sed_lith_116_717c_delimited_pre-janus.csv
# sed_lith_119_744b_delimited_pre-janus.csv
# sed_lith_115_707b_delimited_pre-janus.csv
# sed_lith_117_725b_delimited_pre-janus.csv
# sed_lith_120_749b_delimited_pre-janus.csv
# sed_lith_118_734b_delimited_pre-janus.csv
# sed_lith_114_701a_delimited_pre-janus.csv
# sed_lith_122_762b_delimited_pre-janus.csv
# sed_lith_123_765c_delimited_pre-janus.csv
# sed_lith_121_757b_delimited_pre-janus.csv
# sed_lith_121_755a_delimited_pre-janus.csv
# sed_lith_114_704a_delimited_pre-janus.csv
# sed_lith_114_698a_delimited_pre-janus.csv
# sed_lith_124_769c_delimited_pre-janus.csv
# sed_lith_119_744a_delimited_pre-janus.csv
# sed_lith_104_644b_delimited_pre-janus.csv
# sed_lith_119_738c_delimited_pre-janus.csv
# sed_lith_120_749c_delimited_pre-janus.csv
# sed_lith_121_757a_delimited_pre-janus.csv
# sed_lith_107_651a_delimited_pre-janus.csv
# sed_lith_120_748b_delimited_pre-janus.csv
# sed_lith_124e_777e_delimited_pre-janus.csv
# sed_lith_101_630c_delimited_pre-janus.csv
# sed_lith_123_765a_delimited_pre-janus.csv
# sed_lith_122_761c_delimited_pre-janus.csv
# sed_lith_120_751a_delimited_pre-janus.csv
# sed_lith_114_702b_delimited_pre-janus.csv
# sed_lith_112_688a_delimited_pre-janus.csv
# sed_lith_116_718b_delimited_pre-janus.csv
# sed_lith_120_748a_delimited_pre-janus.csv
# sed_lith_126_792c_delimited_pre-janus.csv
# sed_lith_115_706b_delimited_pre-janus.csv
# sed_lith_122_760b_delimited_pre-janus.csv
# sed_lith_116_718a_delimited_pre-janus.csv
# sed_lith_107_653a_delimited_pre-janus.csv
# sed_lith_112_679b_delimited_pre-janus.csv
# sed_lith_114_700a_delimited_pre-janus.csv
# sed_lith_113_694b_delimited_pre-janus.csv
# sed_lith_112_687a_delimited_pre-janus.csv
# sed_lith_115_713a_delimited_pre-janus.csv
# sed_lith_117_723b_delimited_pre-janus.csv
# sed_lith_117_731a_delimited_pre-janus.csv
# sed_lith_122_763b_delimited_pre-janus.csv
# sed_lith_101_635a_delimited_pre-janus.csv
# sed_lith_115_708a_delimited_pre-janus.csv
# sed_lith_110_675a_delimited_pre-janus.csv
# sed_lith_112_688c_delimited_pre-janus.csv
# sed_lith_126_791b_delimited_pre-janus.csv
# sed_lith_121_756c_delimited_pre-janus.csv
# sed_lith_110_671b_delimited_pre-janus.csv
# sed_lith_117_726a_delimited_pre-janus.csv
# sed_lith_112_679c_delimited_pre-janus.csv
# sed_lith_121_756a_delimited_pre-janus.csv
# sed_lith_122_759b_delimited_pre-janus.csv
# sed_lith_113_689c_delimited_pre-janus.csv
# sed_lith_101_626c_delimited_pre-janus.csv
# sed_lith_112_684a_delimited_pre-janus.csv
# sed_lith_117_724a_delimited_pre-janus.csv
# sed_lith_126_787b_delimited_pre-janus.csv
# sed_lith_121_754b_delimited_pre-janus.csv
# sed_lith_115_709b_delimited_pre-janus.csv
# sed_lith_119_740b_delimited_pre-janus.csv
# sed_lith_119_743a_delimited_pre-janus.csv
# sed_lith_119_742a_delimited_pre-janus.csv
# sed_lith_104_642b_delimited_pre-janus.csv
# sed_lith_119_737b_delimited_pre-janus.csv
# sed_lith_117_729a_delimited_pre-janus.csv
# sed_lith_115_709a_delimited_pre-janus.csv
# sed_lith_103_639d_delimited_pre-janus.csv
# sed_lith_125_784a_delimited_pre-janus.csv
# sed_lith_124_771a_delimited_pre-janus.csv
# sed_lith_116_718d_delimited_pre-janus.csv
# sed_lith_104_642e_delimited_pre-janus.csv
# sed_lith_117_720a_delimited_pre-janus.csv
# sed_lith_105_646b_delimited_pre-janus.csv
# sed_lith_117_725a_delimited_pre-janus.csv
# sed_lith_105_646a_delimited_pre-janus.csv
# sed_lith_108_657a_delimited_pre-janus.csv
# sed_lith_113_696a_delimited_pre-janus.csv
# sed_lith_112_680a_delimited_pre-janus.csv
# sed_lith_124e_777b_delimited_pre-janus.csv
# sed_lith_101_635b_delimited_pre-janus.csv
# sed_lith_123_766a_delimited_pre-janus.csv
# sed_lith_114_703a_delimited_pre-janus.csv
# sed_lith_116_719a_delimited_pre-janus.csv
# sed_lith_113_690a_delimited_pre-janus.csv
# sed_lith_122_764b_delimited_pre-janus.csv
# sed_lith_125_783a_delimited_pre-janus.csv
# sed_lith_116_718e_delimited_pre-janus.csv
# sed_lith_126_790a_delimited_pre-janus.csv
# sed_lith_117_727b_delimited_pre-janus.csv
# sed_lith_119_739b_delimited_pre-janus.csv
# sed_lith_103_639a_delimited_pre-janus.csv
# sed_lith_124e_772a_delimited_pre-janus.csv
# sed_lith_117_723a_delimited_pre-janus.csv
# sed_lith_110_672a_delimited_pre-janus.csv
# sed_lith_115_707a_delimited_pre-janus.csv
# sed_lith_113_691a_delimited_pre-janus.csv
# sed_lith_112_683a_delimited_pre-janus.csv
# sed_lith_119_745a_delimited_pre-janus.csv
# sed_lith_110_673a_delimited_pre-janus.csv
# sed_lith_115_710a_delimited_pre-janus.csv
# sed_lith_126_787a_delimited_pre-janus.csv
# sed_lith_113_697b_delimited_pre-janus.csv
# sed_lith_108_659a_delimited_pre-janus.csv
# sed_lith_112_685a_delimited_pre-janus.csv
# sed_lith_101_626d_delimited_pre-janus.csv
# sed_lith_124e_777a_delimited_pre-janus.csv
# sed_lith_113_697a_delimited_pre-janus.csv
# sed_lith_115_707c_delimited_pre-janus.csv
# sed_lith_126_792b_delimited_pre-janus.csv
# sed_lith_113_694c_delimited_pre-janus.csv
# sed_lith_103_639c_delimited_pre-janus.csv
# sed_lith_125_785a_delimited_pre-janus.csv
# sed_lith_119_746a_delimited_pre-janus.csv
# sed_lith_101_627a_delimited_pre-janus.csv
# sed_lith_119_740a_delimited_pre-janus.csv
# sed_lith_126_793b_delimited_pre-janus.csv
# sed_lith_113_695a_delimited_pre-janus.csv
# sed_lith_108_658a_delimited_pre-janus.csv
# sed_lith_117_727a_delimited_pre-janus.csv
# sed_lith_126_788c_delimited_pre-janus.csv
# sed_lith_115_711a_delimited_pre-janus.csv
# sed_lith_120_749a_delimited_pre-janus.csv
# sed_lith_126_788d_delimited_pre-janus.csv
# sed_lith_117_721b_delimited_pre-janus.csv
# sed_lith_105_647a_delimited_pre-janus.csv
# sed_lith_115_709c_delimited_pre-janus.csv
# sed_lith_111_677a_delimited_pre-janus.csv
# sed_lith_103_639f_delimited_pre-janus.csv
# sed_lith_117_728a_delimited_pre-janus.csv
# sed_lith_110_673b_delimited_pre-janus.csv
# sed_lith_126_788a_delimited_pre-janus.csv
# sed_lith_108_666a_delimited_pre-janus.csv
# sed_lith_125_786a_delimited_pre-janus.csv
# sed_lith_124e_773b_delimited_pre-janus.csv
# sed_lith_122_762a_delimited_pre-janus.csv
# sed_lith_121_753a_delimited_pre-janus.csv
# sed_lith_121_758b_delimited_pre-janus.csv
# sed_lith_101_629a_delimited_pre-janus.csv
# sed_lith_103_640a_delimited_pre-janus.csv
# sed_lith_117_724c_delimited_pre-janus.csv
# sed_lith_110_674a_delimited_pre-janus.csv
# sed_lith_108_664a_delimited_pre-janus.csv
# sed_lith_125_780b_delimited_pre-janus.csv
# sed_lith_122_763a_delimited_pre-janus.csv
# sed_lith_122_761b_delimited_pre-janus.csv
# sed_lith_105_645e_delimited_pre-janus.csv
# sed_lith_108_665b_delimited_pre-janus.csv
# sed_lith_118_732b_delimited_pre-janus.csv
# sed_lith_119_737a_delimited_pre-janus.csv
# sed_lith_107_656b_delimited_pre-janus.csv
# sed_lith_125_779a_delimited_pre-janus.csv
# sed_lith_118_732f_delimited_pre-janus.csv
# sed_lith_104_642a_delimited_pre-janus.csv
# sed_lith_113_689b_delimited_pre-janus.csv
# sed_lith_122_762c_delimited_pre-janus.csv
# sed_lith_112_683b_delimited_pre-janus.csv
# sed_lith_115_711b_delimited_pre-janus.csv
# sed_lith_105_647b_delimited_pre-janus.csv
# sed_lith_108_664c_delimited_pre-janus.csv
# sed_lith_115_710b_delimited_pre-janus.csv
# sed_lith_108_660a_delimited_pre-janus.csv
# sed_lith_101_630b_delimited_pre-janus.csv
# sed_lith_108_663a_delimited_pre-janus.csv
# sed_lith_126_791a_delimited_pre-janus.csv
# sed_lith_108_662a_delimited_pre-janus.csv
# sed_lith_124_769a_delimited_pre-janus.csv
# sed_lith_103_638b_delimited_pre-janus.csv
# sed_lith_110_671c_delimited_pre-janus.csv
# sed_lith_117_728b_delimited_pre-janus.csv
# sed_lith_112_684b_delimited_pre-janus.csv
# sed_lith_108_668a_delimited_pre-janus.csv
# sed_lith_103_637a_delimited_pre-janus.csv
# sed_lith_112_680b_delimited_pre-janus.csv
# sed_lith_103_639e_delimited_pre-janus.csv
# sed_lith_125_780c_delimited_pre-janus.csv
# sed_lith_117_731c_delimited_pre-janus.csv
# sed_lith_126_792a_delimited_pre-janus.csv
# sed_lith_113_692b_delimited_pre-janus.csv
# sed_lith_107_652a_delimited_pre-janus.csv
# sed_lith_108_661a_delimited_pre-janus.csv
# sed_lith_116_717a_delimited_pre-janus.csv
# sed_lith_101_634a_delimited_pre-janus.csv
# sed_lith_125_779b_delimited_pre-janus.csv
# sed_lith_105_645f_delimited_pre-janus.csv
# sed_lith_108_660b_delimited_pre-janus.csv
# sed_lith_108_659c_delimited_pre-janus.csv
# sed_lith_121_756b_delimited_pre-janus.csv
# sed_lith_119_738a_delimited_pre-janus.csv
# sed_lith_114_699a_delimited_pre-janus.csv
# sed_lith_111_678a_delimited_pre-janus.csv
# sed_lith_110_671a_delimited_pre-janus.csv
# sed_lith_110_676a_delimited_pre-janus.csv
# sed_lith_107_653b_delimited_pre-janus.csv
# sed_lith_113_696b_delimited_pre-janus.csv
# sed_lith_122_764a_delimited_pre-janus.csv
# sed_lith_120_750b_delimited_pre-janus.csv
# sed_lith_120_750a_delimited_pre-janus.csv
# sed_lith_124_767c_delimited_pre-janus.csv
# sed_lith_117_731b_delimited_pre-janus.csv
# sed_lith_113_689a_delimited_pre-janus.csv
# sed_lith_122_760a_delimited_pre-janus.csv
# sed_lith_114_701c_delimited_pre-janus.csv
# sed_lith_119_744c_delimited_pre-janus.csv
# sed_lith_118_734d_delimited_pre-janus.csv
# sed_lith_125_780d_delimited_pre-janus.csv
# sed_lith_119_739c_delimited_pre-janus.csv
# sed_lith_120_748c_delimited_pre-janus.csv
# sed_lith_119_738b_delimited_pre-janus.csv
# sed_lith_112_686a_delimited_pre-janus.csv
# sed_lith_101_626a_delimited_pre-janus.csv
# sed_lith_125_780a_delimited_pre-janus.csv
# sed_lith_119_739a_delimited_pre-janus.csv
# sed_lith_120_747b_delimited_pre-janus.csv
# sed_lith_108_663b_delimited_pre-janus.csv
# sed_lith_105_645c_delimited_pre-janus.csv

# %%
unique_columns(csv_paths)
# Out:
# Unnamed: 34
# color
# Unnamed: 32
# color number
# Unnamed: 33
# sub piece top
# observer
# more data available
# code
# induration
# longitude
# bottom interval depth below sea floor
# bottom interval
# Unnamed: 31
# Unnamed: 30
# site
# drilling deformities
# depth
# piece number bottom
# core
# top interval depth below sea floor
# structures
# leg
# section
# minerals
# lithology
# coretype
# paleontology
# sub piece bottom
# unusual occurrences
# latitude
# other
# piece number top
# top interval
# hole
