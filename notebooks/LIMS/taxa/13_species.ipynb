# %% [markdown]
# # Normalize taxa list
#
# Cleanup the normalized taxa list from the eODP researchers. Add PBDB taxa data.

# %%
import sys
sys.path.append('../../../')

import pandas as pd
import numpy as np
import requests

from config import CLEAN_DATA_DIR, OUTPUT_DIR, RAW_DATA_DIR

import scripts.normalize_taxa as nt
from scripts.normalize_data import remove_whitespace
import scripts.pbdb as pbdb

from scripts.pbdb import (
    get_parent_taxa, 
    PBDB_TAXA_NAME, 
    PBDB_TAXA_ID,
    check_multiple_pbdb_id
)
from scripts.shared_utils import (
    log_df
)

# %%
date = '2022-11-08'

taxa_list_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_list_{date}.csv"

species_dir = OUTPUT_DIR/'taxa'/'draft'/'LIMS'/'species'
species_file = species_dir/f'species_list_{date}.csv'

# %% [markdown]
# ## create species csv - species and genus ranks only

# %%
taxa_df = pd.read_csv(taxa_list_file, dtype=str)
log_df(taxa_df)
# 4736
# Out:
# (4736, 25)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...             NaN               NaN
# 3             NaN                 NaN  ...             NaN               NaN
# 4             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2             NaN               NaN           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
# [5 rows x 25 columns]

# %%
taxa_df = taxa_df[taxa_df['Any taxon above genus'].isna()]
taxa_df = taxa_df[taxa_df['species name'].notna()]
log_df(taxa_df)

taxa_df.loc[~taxa_df['species name'].str.contains('spp\.|sp\..*?', regex=True), 'genus species name'] = taxa_df['genus name'] + ' ' + taxa_df['species name']

taxa_df['genus species name'] = taxa_df['genus species name'].str.strip()

log_df(taxa_df)
# 4628
# Out:
# (4628, 25)
# (4628, 26)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 6                   NaN            NaN    Nodosaria                NaN
# 7                   NaN            NaN    Cibicides                NaN
# 8                   NaN            NaN    Brizalina                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 6            NaN              NaN         spp.                 NaN
# 7            NaN              NaN         spp.                 NaN
# 8            NaN              NaN         spp.                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_name order_taxon_id  \
# 0             NaN                 NaN  ...               NaN            NaN
# 1             NaN                 NaN  ...               NaN            NaN
# 6             NaN                 NaN  ...      Nodosariidae         429322
# 7             NaN                 NaN  ...       Cibicididae            NaN
# 8             NaN                 NaN  ...       Bolivinidae            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 6      Nodosariida         428875      Nodosariata          288974
# 7              NaN            NaN              NaN          288974
# 8              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name   genus species name
# 0      Foraminifera           212476           Rhizaria   Euuvigerina miozea
# 1      Foraminifera           212476           Rhizaria  Euuvigerina rodleyi
# 6      Foraminifera           212476           Rhizaria                  NaN
# 7      Foraminifera           212476           Rhizaria                  NaN
# 8      Foraminifera           212476           Rhizaria                  NaN
#
# [5 rows x 26 columns]

# %%
species_df = taxa_df[['genus species name']].copy().dropna().drop_duplicates().reset_index(drop=True)

log_df(species_df)
# 3302
# Out:
# (3302, 1)
#                 genus species name
# 0               Euuvigerina miozea
# 1              Euuvigerina rodleyi
# 2                  Candeina nitida
# 3       Dentoglobigerina altispira
# 4  Dentoglobigerina baroemoenensis

# %%
genus_ids = {}

for index, row in species_df.iterrows(): 
    need_genus = True
    count = 0

    # if index > 10:
    #     continue
    
    if index % 50 == 0:
        print(index, end=' ')
        
    url =  PBDB_TAXA_NAME +  row['genus species name']
    
    # if row['genus species name'] != 'Charcotia actinochilus':
    #        continue
    # print('species: ', url)
        
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            species_df.at[index, 'species_taxon_id'] = str(data[0]["taxon_no"])
            species_df.at[index, 'species_taxon_name'] = data[0]["taxon_name"]
            # print(data[0])
            
            
            
            parent_id = data[0]['parent_no']
            
            if parent_id in genus_ids:
                species_df.at[index, 'tmp_genus_taxon_id'] = str(parent_id)
                species_df.at[index, 'tmp_genus_taxon_name'] = genus_ids[parent_id]
                    
                need_genus = False
            
            while need_genus:
                url =  PBDB_TAXA_ID +  parent_id
                # print(url)
                response = requests.get(url)
                if response.status_code == 200:
                    data = response.json()["records"]
                    if data[0]["taxon_rank"] == 'genus':
                        genus_id = data[0]["taxon_no"]
                        genus_ids[genus_id] = data[0]["taxon_name"]
                        species_df.at[index, 'tmp_genus_taxon_id'] = str(genus_id)
                        species_df.at[index, 'tmp_genus_taxon_name'] =  data[0]["taxon_name"]
                        # print(data[0])


                        need_genus = False
                    else:
                        parent_id = data[0]['parent_no']
                if count > 20:
                    need_genus = False
                count += 1
        else:
            print('multiple matches for: ', row['genus species name'] )
    else:
        pass
        # print('not found: ', row['genus species name'])
# Out:
# 0 50 100 150 200 250 300 350 400 450 500 550 600 650 700 750 800 850 900 950 1000 1050 1100 1150 1200 1250 1300 1350 1400 1450 1500 1550 1600 1650 1700 1750 1800 1850 1900 1950 2000 2050 2100 2150 2200 2250 2300 2350 2400 2450 2500 2550 2600 2650 2700 2750 2800 2850 2900 2950 3000 3050 3100 3150 3200 3250 3300

# %%
species_df.head(10)
# Out:
#                 genus species name species_taxon_id  \
# 0               Euuvigerina miozea              NaN
# 1              Euuvigerina rodleyi              NaN
# 2                  Candeina nitida           422278
# 3       Dentoglobigerina altispira           402661
# 4  Dentoglobigerina baroemoenensis           422289
# 5            Globigerina bulloides           113301
# 6          Globigerina falconensis           388387
# 7            Globigerina rubescens           422320
# 8            Globigerinella calida           422302
# 9       Globigerinella siphonifera           422304
#
#                 species_taxon_name tmp_genus_taxon_id tmp_genus_taxon_name
# 0                              NaN                NaN                  NaN
# 1                              NaN                NaN                  NaN
# 2                  Candeina nitida               1053             Candeina
# 3       Dentoglobigerina altispira               1264     Dentoglobigerina
# 4  Dentoglobigerina baroemoenensis               1264     Dentoglobigerina
# 5            Globigerina bulloides               1498          Globigerina
# 6          Globigerina falconensis               1498          Globigerina
# 7            Globigerina rubescens               1529   Globoturborotalita
# 8            Globigerinella calida               1501       Globigerinella
# 9       Globigerinella siphonifera               1501       Globigerinella

# %%
species_df.shape
# Out:
# (3302, 5)

# %%
species_df.to_csv(species_file, index=False)

# %% [markdown]
# ## create species csv - all ranks

# %%
taxa_df = pd.read_csv(taxa_list_file, dtype=str)
log_df(taxa_df)
# 4736
# Out:
# (4736, 29)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id  family_taxon_name  \
# 0             NaN                 NaN  ...             NaN                NaN
# 1             NaN                 NaN  ...             NaN                NaN
# 2             NaN                 NaN  ...             NaN                NaN
# 3             NaN                 NaN  ...          155922  Pleurostomellidae
# 4             NaN                 NaN  ...             NaN                NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN          22826        Ostracoda
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2          288974      Foraminifera           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
# [5 rows x 29 columns]

# %%
taxa_df = taxa_df[taxa_df['Any taxon above genus'].isna()]
taxa_df = taxa_df[taxa_df['species name'].notna()]
log_df(taxa_df)

taxa_df.loc[~taxa_df['species name'].str.contains('spp\.|sp\..*?', regex=True), 'genus species name'] = taxa_df['genus name'] + ' ' + taxa_df['species name']

taxa_df['genus species name'] = taxa_df['genus species name'].str.strip()

log_df(taxa_df)
# 4628
# Out:
# (4628, 29)
# (4628, 30)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 6                   NaN            NaN    Nodosaria                NaN
# 7                   NaN            NaN    Cibicides                NaN
# 8                   NaN            NaN    Brizalina                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 6            NaN              NaN         spp.                 NaN
# 7            NaN              NaN         spp.                 NaN
# 8            NaN              NaN         spp.                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_name order_taxon_id  \
# 0             NaN                 NaN  ...               NaN            NaN
# 1             NaN                 NaN  ...               NaN            NaN
# 6             NaN                 NaN  ...      Nodosariidae         429322
# 7             NaN                 NaN  ...       Cibicididae            NaN
# 8             NaN                 NaN  ...       Bolivinidae            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 6      Nodosariida         428875      Nodosariata          288974
# 7              NaN            NaN              NaN          288974
# 8              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name   genus species name
# 0      Foraminifera           212476           Rhizaria   Euuvigerina miozea
# 1      Foraminifera           212476           Rhizaria  Euuvigerina rodleyi
# 6      Foraminifera           212476           Rhizaria                  NaN
# 7      Foraminifera           212476           Rhizaria                  NaN
# 8      Foraminifera           212476           Rhizaria                  NaN
#
# [5 rows x 30 columns]

# %%
species_df = taxa_df[['genus species name']].copy().dropna().drop_duplicates().reset_index(drop=True)

 
log_df(species_df)
# 3302
# Out:
# (3302, 1)
#                 genus species name
# 0               Euuvigerina miozea
# 1              Euuvigerina rodleyi
# 2                  Candeina nitida
# 3       Dentoglobigerina altispira
# 4  Dentoglobigerina baroemoenensis

# %%
for index, row in species_df.iterrows(): 
    if index % 50 == 0:
        print(index, end=' ')
        
    if row['genus species name'] == 'Hirsutella hirsuta':
        row['genus species name'] = 'Globorotalia (Hirsutella) hirsuta'
        

    url =  PBDB_TAXA_NAME +  row['genus species name']
        
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            species_df.at[index, f'pbdb_taxon_id'] = str(data[0]["taxon_no"])
            species_df.at[index, f'pbdb_taxon_name'] = data[0]["taxon_name"]
            species_df.at[index, f'pbdb_taxon_rank'] = data[0]["taxon_rank"]
            
            species_df.at[index, 'species_taxon_id'] = str(data[0]["taxon_no"])
            species_df.at[index, 'species_taxon_name'] = data[0]["taxon_name"]
            
            round = 0
            get_parent_taxa(species_df, data[0]["parent_no"], data[0]["taxon_rank"], round, index, None)

# %%
log_df(species_df, 2)
# Out:
# (2, 20)
#                      genus species name pbdb_taxon_id  \
# 2280  Globorotalia (Hirsutella) hirsuta        422434
# 2281                  Hirsutella juanai        422436
#
#                         pbdb_taxon_name pbdb_taxon_rank species_taxon_id  \
# 2280  Globorotalia (Hirsutella) hirsuta         species           422434
# 2281   Globorotalia (Hirsutella) juanai         species           422436
#
#                      species_taxon_name genus_taxon_id genus_taxon_name  \
# 2280  Globorotalia (Hirsutella) hirsuta           1521     Globorotalia
# 2281   Globorotalia (Hirsutella) juanai           1521     Globorotalia
#
#      family_taxon_id family_taxon_name  order_taxon_id  order_taxon_name  \
# 2280           82192   Globorotaliidae             NaN               NaN
# 2281           82192   Globorotaliidae             NaN               NaN
#
#       class_taxon_id  class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 2280             NaN               NaN          288974      Foraminifera
# 2281             NaN               NaN          288974      Foraminifera
#
#      kingdom_taxon_id kingdom_taxon_name  unranked clade_taxon_id  \
# 2280           212476           Rhizaria                      NaN
# 2281           212476           Rhizaria                      NaN
#
#       unranked clade_taxon_name
# 2280                        NaN
# 2281                        NaN

# %%
species_df.columns
# Out:
# Index(['genus species name', 'pbdb_taxon_id', 'pbdb_taxon_name',
#        'pbdb_taxon_rank', 'species_taxon_id', 'species_taxon_name',
#        'genus_taxon_id', 'genus_taxon_name', 'family_taxon_id',
#        'family_taxon_name', 'phylum_taxon_id', 'phylum_taxon_name',
#        'kingdom_taxon_id', 'kingdom_taxon_name', 'order_taxon_id',
#        'order_taxon_name', 'class_taxon_id', 'class_taxon_name',
#        'unranked clade_taxon_id', 'unranked clade_taxon_name'],
#       dtype='object')

# %%
species_df = species_df.reindex(columns=[
    'genus species name', 
    'pbdb_taxon_id', 'pbdb_taxon_name', 'pbdb_taxon_rank',
    'species_taxon_id', 'species_taxon_name',
    'genus_taxon_id', 'genus_taxon_name',
    'family_taxon_id', 'family_taxon_name',
    'order_taxon_id', 'order_taxon_name', 
    'class_taxon_id', 'class_taxon_name',
    'phylum_taxon_id', 'phylum_taxon_name', 
    'kingdom_taxon_id', 'kingdom_taxon_name', 
    'unranked clade_taxon_id', 'unranked clade_taxon_name'
    ])

log_df(species_df, 2)
# Out:
# (2, 20)
#                      genus species name pbdb_taxon_id  \
# 2280  Globorotalia (Hirsutella) hirsuta        422434
# 2281                  Hirsutella juanai        422436
#
#                         pbdb_taxon_name pbdb_taxon_rank species_taxon_id  \
# 2280  Globorotalia (Hirsutella) hirsuta         species           422434
# 2281   Globorotalia (Hirsutella) juanai         species           422436
#
#                      species_taxon_name genus_taxon_id genus_taxon_name  \
# 2280  Globorotalia (Hirsutella) hirsuta           1521     Globorotalia
# 2281   Globorotalia (Hirsutella) juanai           1521     Globorotalia
#
#      family_taxon_id family_taxon_name  order_taxon_id  order_taxon_name  \
# 2280           82192   Globorotaliidae             NaN               NaN
# 2281           82192   Globorotaliidae             NaN               NaN
#
#       class_taxon_id  class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 2280             NaN               NaN          288974      Foraminifera
# 2281             NaN               NaN          288974      Foraminifera
#
#      kingdom_taxon_id kingdom_taxon_name  unranked clade_taxon_id  \
# 2280           212476           Rhizaria                      NaN
# 2281           212476           Rhizaria                      NaN
#
#       unranked clade_taxon_name
# 2280                        NaN
# 2281                        NaN

# %%
species_df.to_csv(species_file, index=False)

# %% [markdown]
# compare pbdb ids for

# %%
df = pd.read_csv(species_file, 
                 usecols =['genus species name', 'pbdb_taxon_id'])

df2 = pd.read_csv(str(species_file).replace(date, '2022-10-27'),
                 usecols =['genus species name', 'species_taxon_id'])


merge_df = df.merge(df2)
merge_df.fillna('', inplace=True)
merge_df[merge_df['pbdb_taxon_id'] != merge_df['species_taxon_id']]
# Out:
# Empty DataFrame
# Columns: [genus species name, pbdb_taxon_id, species_taxon_id]
# Index: []

# %% [markdown]
# ## QA species

# %%
species_df = pd.read_csv(species_file, dtype=str)
log_df(species_df)
# 3302
# Out:
# (3302, 5)
#                 genus species name species_taxon_id  \
# 0               Euuvigerina miozea              NaN
# 1              Euuvigerina rodleyi              NaN
# 2                  Candeina nitida           422278
# 3       Dentoglobigerina altispira           402661
# 4  Dentoglobigerina baroemoenensis           422289
#
#                 species_taxon_name tmp_genus_taxon_id tmp_genus_taxon_name
# 0                              NaN                NaN                  NaN
# 1                              NaN                NaN                  NaN
# 2                  Candeina nitida               1053             Candeina
# 3       Dentoglobigerina altispira               1264     Dentoglobigerina
# 4  Dentoglobigerina baroemoenensis               1264     Dentoglobigerina

# %%
taxa_df = pd.read_csv(taxa_list_file, dtype=str)
log_df(taxa_df)
# 4736
# Out:
# (4736, 25)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...             NaN               NaN
# 3             NaN                 NaN  ...             NaN               NaN
# 4             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2             NaN               NaN           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
# [5 rows x 25 columns]

# %%
taxa_df.columns
# Out:
# Index(['Any taxon above genus', 'genus modifier', 'genus name',
#        'subgenera modifier', 'subgenera name', 'species modifier',
#        'species name', 'subspecies modifier', 'subspecies name',
#        'non-taxa descriptor', 'normalized_name', 'taxon_group',
#        'pbdb_taxon_id', 'pbdb_taxon_name', 'pbdb_taxon_rank',
#        'family_taxon_id', 'family_taxon_name', 'order_taxon_id',
#        'order_taxon_name', 'class_taxon_id', 'class_taxon_name',
#        'phylum_taxon_id', 'phylum_taxon_name', 'kingdom_taxon_id',
#        'kingdom_taxon_name'],
#       dtype='object')

# %%
set(species_df['tmp_genus_taxon_id'].dropna()) - set(taxa_df['pbdb_taxon_id'])
# Out:
# {'29328'}

# %%
species_df[species_df['tmp_genus_taxon_id'] == '29328']
# Out:
#       genus species name species_taxon_id  species_taxon_name  \
# 2280  Hirsutella hirsuta           237025  Hirsutella hirsuta
#
#      tmp_genus_taxon_id tmp_genus_taxon_name
# 2280              29328           Hirsutella

# %%
tmp = pd.DataFrame([{
    'Any taxon above genus': pd.NA,
    'genus modifier': pd.NA, 
    'genus name': 'Hirsutella',
    'subgenera modifier': pd.NA, 
    'subgenera name': pd.NA, 
    'species modifier': pd.NA,
    'species name': 'hirsuta', 
    'subspecies modifier': pd.NA, 
    'subspecies name': pd.NA,
    'non-taxa descriptor': pd.NA, 
    'normalized_name': pd.NA, 
    'taxon_group': 'planktic_forams',
    'pbdb_taxon_id': '29328', 
    'pbdb_taxon_name': 'Hirsutella', 
    'pbdb_taxon_rank': 'genus',
    'genus_taxon_id': '29328', 
    'genus_taxon_name': 'Hirsutella'
}])
log_df(tmp)
# Out:
# (1, 17)
#   Any taxon above genus genus modifier  genus name subgenera modifier  \
# 0                  <NA>           <NA>  Hirsutella               <NA>
#
#   subgenera name species modifier species name subspecies modifier  \
# 0           <NA>             <NA>      hirsuta                <NA>
#
#   subspecies name non-taxa descriptor normalized_name      taxon_group  \
# 0            <NA>                <NA>            <NA>  planktic_forams
#
#   pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank genus_taxon_id  \
# 0         29328      Hirsutella           genus          29328
#
#   genus_taxon_name
# 0       Hirsutella

# %%
for index, row in tmp.iterrows(): 

    url =  PBDB_TAXA_ID +  row['genus_taxon_id']
        
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            tmp.at[index, f'pbdb_taxon_id'] = str(data[0]["taxon_no"])
            tmp.at[index, f'pbdb_taxon_name'] = data[0]["taxon_name"]
            tmp.at[index, f'pbdb_taxon_rank'] = data[0]["taxon_rank"]
            
            round = 0
            get_parent_taxa(tmp, data[0]["parent_no"], data[0]["taxon_rank"], round, index, None)

log_df(tmp)
# Out:
# (1, 27)
#   Any taxon above genus genus modifier  genus name subgenera modifier  \
# 0                  <NA>           <NA>  Hirsutella               <NA>
#
#   subgenera name species modifier species name subspecies modifier  \
# 0           <NA>             <NA>      hirsuta                <NA>
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0            <NA>                <NA>  ...          126841     Bittnerulidae
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0          83137    Spiriferinida          82921   Rhynchonellata
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0           26322       Brachiopoda           325038           Animalia
#
# [1 rows x 27 columns]

# %%
tmp.to_csv(OUTPUT_DIR/'tmp'/'Hirsutella_hirsuta.csv', index=False)

# %% [markdown]
# ## create taxa list with species

# %%
species_df = pd.read_csv(species_file, dtype=str)
log_df(species_df)
# 3302
# Out:
# (3302, 5)
#                 genus species name species_taxon_id  \
# 0               Euuvigerina miozea              NaN
# 1              Euuvigerina rodleyi              NaN
# 2                  Candeina nitida           422278
# 3       Dentoglobigerina altispira           402661
# 4  Dentoglobigerina baroemoenensis           422289
#
#                 species_taxon_name tmp_genus_taxon_id tmp_genus_taxon_name
# 0                              NaN                NaN                  NaN
# 1                              NaN                NaN                  NaN
# 2                  Candeina nitida               1053             Candeina
# 3       Dentoglobigerina altispira               1264     Dentoglobigerina
# 4  Dentoglobigerina baroemoenensis               1264     Dentoglobigerina

# %%
taxa_df = pd.read_csv(taxa_list_file, dtype=str)
log_df(taxa_df)
# Out:
# (4736, 25)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...             NaN               NaN
# 3             NaN                 NaN  ...             NaN               NaN
# 4             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2             NaN               NaN           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
# [5 rows x 25 columns]

# %%
taxa_df = taxa_df[taxa_df['Any taxon above genus'].isna()]
taxa_df = taxa_df[taxa_df['species name'].notna()]
log_df(taxa_df)

taxa_df.loc[~taxa_df['species name'].str.contains('spp\.|sp\..*?', regex=True), 'genus species name'] = taxa_df['genus name'] + ' ' + taxa_df['species name']

taxa_df['genus species name'] = taxa_df['genus species name'].str.strip()

log_df(taxa_df)
# 4628
# Out:
# (4628, 25)
# (4628, 26)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 6                   NaN            NaN    Nodosaria                NaN
# 7                   NaN            NaN    Cibicides                NaN
# 8                   NaN            NaN    Brizalina                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 6            NaN              NaN         spp.                 NaN
# 7            NaN              NaN         spp.                 NaN
# 8            NaN              NaN         spp.                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_name order_taxon_id  \
# 0             NaN                 NaN  ...               NaN            NaN
# 1             NaN                 NaN  ...               NaN            NaN
# 6             NaN                 NaN  ...      Nodosariidae         429322
# 7             NaN                 NaN  ...       Cibicididae            NaN
# 8             NaN                 NaN  ...       Bolivinidae            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 6      Nodosariida         428875      Nodosariata          288974
# 7              NaN            NaN              NaN          288974
# 8              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name   genus species name
# 0      Foraminifera           212476           Rhizaria   Euuvigerina miozea
# 1      Foraminifera           212476           Rhizaria  Euuvigerina rodleyi
# 6      Foraminifera           212476           Rhizaria                  NaN
# 7      Foraminifera           212476           Rhizaria                  NaN
# 8      Foraminifera           212476           Rhizaria                  NaN
#
# [5 rows x 26 columns]

# %%
cols = [
    'pbdb_taxon_id', 'pbdb_taxon_name',  'pbdb_taxon_rank', 
    'genus species name',
    'family_taxon_id', 'family_taxon_name', 
    'order_taxon_id', 'order_taxon_name',
    'class_taxon_id', 'class_taxon_name', 
    'phylum_taxon_id', 'phylum_taxon_name', 
    'kingdom_taxon_id', 'kingdom_taxon_name'
]

merge_df = taxa_df[cols].merge(species_df, how='left', on='genus species name')


log_df(merge_df)
# 4635
# Out:
# (4635, 18)
#   pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank   genus species name  \
# 0          1408     Euuvigerina           genus   Euuvigerina miozea
# 1          1408     Euuvigerina           genus  Euuvigerina rodleyi
# 2          1952       Nodosaria           genus                  NaN
# 3          1107       Cibicides           genus                  NaN
# 4          1017       Brizalina           genus                  NaN
#
#   family_taxon_id family_taxon_name order_taxon_id order_taxon_name  \
# 0             NaN               NaN            NaN              NaN
# 1             NaN               NaN            NaN              NaN
# 2           82197      Nodosariidae         429322      Nodosariida
# 3           82208       Cibicididae            NaN              NaN
# 4          112279       Bolivinidae            NaN              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN          288974      Foraminifera
# 1            NaN              NaN          288974      Foraminifera
# 2         428875      Nodosariata          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4            NaN              NaN          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name species_taxon_id species_taxon_name  \
# 0           212476           Rhizaria              NaN                NaN
# 1           212476           Rhizaria              NaN                NaN
# 2           212476           Rhizaria              NaN                NaN
# 3           212476           Rhizaria              NaN                NaN
# 4           212476           Rhizaria              NaN                NaN
#
#   tmp_genus_taxon_id tmp_genus_taxon_name
# 0                NaN                  NaN
# 1                NaN                  NaN
# 2                NaN                  NaN
# 3                NaN                  NaN
# 4                NaN                  NaN

# %%
merge_df.to_csv(species_dir/f'taxa_list_with_species_{date}.csv', index=False)

# %% [markdown]
# ## create mistched genus list

# %%
taxa_df = pd.read_csv(taxa_list_file, dtype=str)
log_df(taxa_df)
# Out:
# (4736, 25)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...             NaN               NaN
# 3             NaN                 NaN  ...             NaN               NaN
# 4             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2             NaN               NaN           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
# [5 rows x 25 columns]

# %%
taxa_df = taxa_df[taxa_df['Any taxon above genus'].isna()]
taxa_df = taxa_df[taxa_df['species name'].notna()]
log_df(taxa_df)

taxa_df.loc[~taxa_df['species name'].str.contains('spp\.|sp\..*?', regex=True), 'genus species name'] = taxa_df['genus name'] + ' ' + taxa_df['species name']

taxa_df['genus species name'] = taxa_df['genus species name'].str.strip()

log_df(taxa_df)
# Out:
# (4628, 25)
# (4628, 26)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 6                   NaN            NaN    Nodosaria                NaN
# 7                   NaN            NaN    Cibicides                NaN
# 8                   NaN            NaN    Brizalina                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 6            NaN              NaN         spp.                 NaN
# 7            NaN              NaN         spp.                 NaN
# 8            NaN              NaN         spp.                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_name order_taxon_id  \
# 0             NaN                 NaN  ...               NaN            NaN
# 1             NaN                 NaN  ...               NaN            NaN
# 6             NaN                 NaN  ...      Nodosariidae         429322
# 7             NaN                 NaN  ...       Cibicididae            NaN
# 8             NaN                 NaN  ...       Bolivinidae            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 6      Nodosariida         428875      Nodosariata          288974
# 7              NaN            NaN              NaN          288974
# 8              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name   genus species name
# 0      Foraminifera           212476           Rhizaria   Euuvigerina miozea
# 1      Foraminifera           212476           Rhizaria  Euuvigerina rodleyi
# 6      Foraminifera           212476           Rhizaria                  NaN
# 7      Foraminifera           212476           Rhizaria                  NaN
# 8      Foraminifera           212476           Rhizaria                  NaN
#
# [5 rows x 26 columns]

# %%
species_df = pd.read_csv(species_file, dtype=str)
log_df(species_df)
# Out:
# (3302, 5)
#                 genus species name species_taxon_id  \
# 0               Euuvigerina miozea              NaN
# 1              Euuvigerina rodleyi              NaN
# 2                  Candeina nitida           422278
# 3       Dentoglobigerina altispira           402661
# 4  Dentoglobigerina baroemoenensis           422289
#
#                 species_taxon_name tmp_genus_taxon_id tmp_genus_taxon_name
# 0                              NaN                NaN                  NaN
# 1                              NaN                NaN                  NaN
# 2                  Candeina nitida               1053             Candeina
# 3       Dentoglobigerina altispira               1264     Dentoglobigerina
# 4  Dentoglobigerina baroemoenensis               1264     Dentoglobigerina

# %%
species_filter_df = species_df.dropna(subset=['species_taxon_id'])
log_df(species_filter_df)
# 495
# Out:
# (495, 5)
#                 genus species name species_taxon_id  \
# 2                  Candeina nitida           422278
# 3       Dentoglobigerina altispira           402661
# 4  Dentoglobigerina baroemoenensis           422289
# 5            Globigerina bulloides           113301
# 6          Globigerina falconensis           388387
#
#                 species_taxon_name tmp_genus_taxon_id tmp_genus_taxon_name
# 2                  Candeina nitida               1053             Candeina
# 3       Dentoglobigerina altispira               1264     Dentoglobigerina
# 4  Dentoglobigerina baroemoenensis               1264     Dentoglobigerina
# 5            Globigerina bulloides               1498          Globigerina
# 6          Globigerina falconensis               1498          Globigerina

# %%
cols = [
    'pbdb_taxon_id', 'pbdb_taxon_name',  'pbdb_taxon_rank', 
    'genus species name',
    'family_taxon_id', 'family_taxon_name', 
    'order_taxon_id', 'order_taxon_name',
    'class_taxon_id', 'class_taxon_name', 
    'phylum_taxon_id', 'phylum_taxon_name', 
    'kingdom_taxon_id', 'kingdom_taxon_name'
]

merge_df = species_filter_df.merge(taxa_df[cols], how='left', on='genus species name')
merge_df.drop_duplicates(inplace=True)


log_df(merge_df)
# 495
# Out:
# (495, 18)
#                 genus species name species_taxon_id  \
# 0                  Candeina nitida           422278
# 1       Dentoglobigerina altispira           402661
# 3  Dentoglobigerina baroemoenensis           422289
# 4            Globigerina bulloides           113301
# 6          Globigerina falconensis           388387
#
#                 species_taxon_name tmp_genus_taxon_id tmp_genus_taxon_name  \
# 0                  Candeina nitida               1053             Candeina
# 1       Dentoglobigerina altispira               1264     Dentoglobigerina
# 3  Dentoglobigerina baroemoenensis               1264     Dentoglobigerina
# 4            Globigerina bulloides               1498          Globigerina
# 6          Globigerina falconensis               1498          Globigerina
#
#   pbdb_taxon_id   pbdb_taxon_name pbdb_taxon_rank family_taxon_id  \
# 0          1053          Candeina           genus          422277
# 1          1264  Dentoglobigerina           genus           82191
# 3          1264  Dentoglobigerina           genus           82191
# 4          1498       Globigerina           genus           82191
# 6          1498       Globigerina           genus           82191
#
#   family_taxon_name order_taxon_id order_taxon_name class_taxon_id  \
# 0       Candeinidae            NaN              NaN            NaN
# 1    Globigerinidae            NaN              NaN            NaN
# 3    Globigerinidae            NaN              NaN            NaN
# 4    Globigerinidae            NaN              NaN            NaN
# 6    Globigerinidae            NaN              NaN            NaN
#
#   class_taxon_name phylum_taxon_id phylum_taxon_name kingdom_taxon_id  \
# 0              NaN          288974      Foraminifera           212476
# 1              NaN          288974      Foraminifera           212476
# 3              NaN          288974      Foraminifera           212476
# 4              NaN          288974      Foraminifera           212476
# 6              NaN          288974      Foraminifera           212476
#
#   kingdom_taxon_name
# 0           Rhizaria
# 1           Rhizaria
# 3           Rhizaria
# 4           Rhizaria
# 6           Rhizaria

# %%
mismatch_df = merge_df[
    (merge_df['tmp_genus_taxon_id'] != merge_df['pbdb_taxon_id'])
    & (merge_df['pbdb_taxon_rank'] == 'genus')
]
log_df(mismatch_df)
# 39
# Out:
# (39, 18)
#              genus species name species_taxon_id          species_taxon_name  \
# 7         Globigerina rubescens           422320       Globigerina rubescens
# 27   Globigerinoides sacculifer           388389  Globigerinoides sacculifer
# 39        Globorotalia humerosa           402487       Globorotalia humerosa
# 100         Anomalina praeacuta           382642         Anomalina praeacuta
# 209       Actinocyclus senarius           387049       Actinocyclus senarius
#
#     tmp_genus_taxon_id tmp_genus_taxon_name pbdb_taxon_id  pbdb_taxon_name  \
# 7                 1529   Globoturborotalita          1498      Globigerina
# 27              422361           Trilobatus          1504  Globigerinoides
# 39                1917     Neogloboquadrina          1521     Globorotalia
# 100                859        Anomalinoides         86769        Anomalina
# 209              71244        Actinoptychus         82146     Actinocyclus
#
#     pbdb_taxon_rank family_taxon_id family_taxon_name order_taxon_id  \
# 7             genus           82191    Globigerinidae            NaN
# 27            genus           82191    Globigerinidae            NaN
# 39            genus           82192   Globorotaliidae            NaN
# 100           genus          103798      Anomalinidae         279579
# 209           genus           71207     Hemidiscaceae         426780
#
#     order_taxon_name class_taxon_id   class_taxon_name phylum_taxon_id  \
# 7                NaN            NaN                NaN          288974
# 27               NaN            NaN                NaN          288974
# 39               NaN            NaN                NaN          288974
# 100        Rotaliida         428504      Globothalamea          288974
# 209  Coscinodiscales          69587  Bacillariophyceae          432613
#
#     phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 7        Foraminifera           212476           Rhizaria
# 27       Foraminifera           212476           Rhizaria
# 39       Foraminifera           212476           Rhizaria
# 100      Foraminifera           212476           Rhizaria
# 209        Ochrophyta              NaN                NaN

# %%
mismatch_df.to_csv(species_dir/f'species_mistmach_genus_{date}.csv', index=False)

# %% [markdown]
# ## add genus columns to taxa file

# %%
taxa_df = pd.read_csv(taxa_list_file, dtype=str)
log_df(taxa_df)

# 4736
# Out:
# (4736, 25)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...             NaN               NaN
# 3             NaN                 NaN  ...             NaN               NaN
# 4             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2             NaN               NaN           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
# [5 rows x 25 columns]

# %%
taxa_df['species_taxon_id'] = pd.NA
taxa_df['species_taxon_name'] = pd.NA

taxa_df.loc[taxa_df['pbdb_taxon_rank'] == 'genus', 'genus_taxon_name' ] = taxa_df['pbdb_taxon_name']
taxa_df.loc[taxa_df['pbdb_taxon_rank'] == 'genus', 'genus_taxon_id' ] = taxa_df['pbdb_taxon_id']

taxa_df.loc[taxa_df['pbdb_taxon_rank'] == 'family', 'family_taxon_name' ] = taxa_df['pbdb_taxon_name']
taxa_df.loc[taxa_df['pbdb_taxon_rank'] == 'family', 'family_taxon_id' ] = taxa_df['pbdb_taxon_id']

taxa_df.loc[taxa_df['pbdb_taxon_rank'] == 'order', 'order_taxon_name' ] = taxa_df['pbdb_taxon_name']
taxa_df.loc[taxa_df['pbdb_taxon_rank'] == 'order', 'order_taxon_id' ] = taxa_df['pbdb_taxon_id']


taxa_df.loc[taxa_df['pbdb_taxon_rank'] == 'class', 'class_taxon_name' ] = taxa_df['pbdb_taxon_name']
taxa_df.loc[taxa_df['pbdb_taxon_rank'] == 'class', 'class_taxon_id' ] = taxa_df['pbdb_taxon_id']

taxa_df.loc[taxa_df['pbdb_taxon_rank'] == 'phylum', 'phylum_taxon_name' ] = taxa_df['pbdb_taxon_name']
taxa_df.loc[taxa_df['pbdb_taxon_rank'] == 'phylum', 'phylum_taxon_id' ] = taxa_df['pbdb_taxon_id']



log_df(taxa_df)
# Out:
# (4736, 29)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... class_taxon_id class_taxon_name  \
# 0             NaN                 NaN  ...            NaN              NaN
# 1             NaN                 NaN  ...            NaN              NaN
# 2             NaN                 NaN  ...            NaN              NaN
# 3             NaN                 NaN  ...            NaN              NaN
# 4             NaN                 NaN  ...          22826        Ostracoda
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2          288974      Foraminifera           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
#   species_taxon_id species_taxon_name genus_taxon_name genus_taxon_id
# 0             <NA>               <NA>      Euuvigerina           1408
# 1             <NA>               <NA>      Euuvigerina           1408
# 2             <NA>               <NA>              NaN            NaN
# 3             <NA>               <NA>              NaN            NaN
# 4             <NA>               <NA>              NaN            NaN
#
# [5 rows x 29 columns]

# %%
taxa_df.columns
# Out:
# Index(['Any taxon above genus', 'genus modifier', 'genus name',
#        'subgenera modifier', 'subgenera name', 'species modifier',
#        'species name', 'subspecies modifier', 'subspecies name',
#        'non-taxa descriptor', 'normalized_name', 'taxon_group',
#        'pbdb_taxon_id', 'pbdb_taxon_name', 'pbdb_taxon_rank',
#        'family_taxon_id', 'family_taxon_name', 'order_taxon_id',
#        'order_taxon_name', 'class_taxon_id', 'class_taxon_name',
#        'phylum_taxon_id', 'phylum_taxon_name', 'kingdom_taxon_id',
#        'kingdom_taxon_name', 'species_taxon_id', 'species_taxon_name',
#        'genus_taxon_name', 'genus_taxon_id'],
#       dtype='object')

# %%
cols = [
    'Any taxon above genus', 
    'genus modifier', 'genus name',
    'subgenera modifier', 'subgenera name', 
    'species modifier', 'species name', 
    'subspecies modifier', 'subspecies name',
    'non-taxa descriptor', 'normalized_name', 'taxon_group',
    'pbdb_taxon_id', 'pbdb_taxon_name', 'pbdb_taxon_rank',
    'species_taxon_id', 'species_taxon_name', 
    'genus_taxon_id', 'genus_taxon_name', 
    'family_taxon_id', 'family_taxon_name', 
    'order_taxon_id', 'order_taxon_name', 
    'class_taxon_id', 'class_taxon_name',
    'phylum_taxon_id', 'phylum_taxon_name', 
    'kingdom_taxon_id', 'kingdom_taxon_name'
]

taxa_df = taxa_df.reindex(columns=cols)
log_df(taxa_df)
# Out:
# (4736, 29)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id  family_taxon_name  \
# 0             NaN                 NaN  ...             NaN                NaN
# 1             NaN                 NaN  ...             NaN                NaN
# 2             NaN                 NaN  ...             NaN                NaN
# 3             NaN                 NaN  ...          155922  Pleurostomellidae
# 4             NaN                 NaN  ...             NaN                NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN          22826        Ostracoda
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2          288974      Foraminifera           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
# [5 rows x 29 columns]

# %%
taxa_df.to_csv(taxa_list_file, index=False)

# %% [markdown]
# ## add species to taxa list

# %%
species_df = pd.read_csv(species_file, dtype=str)

log_df(species_df)
# 3302
# Out:
# (3302, 20)
#                 genus species name pbdb_taxon_id  \
# 0               Euuvigerina miozea           NaN
# 1              Euuvigerina rodleyi           NaN
# 2                  Candeina nitida        422278
# 3       Dentoglobigerina altispira        402661
# 4  Dentoglobigerina baroemoenensis        422289
#
#                    pbdb_taxon_name pbdb_taxon_rank species_taxon_id  \
# 0                              NaN             NaN              NaN
# 1                              NaN             NaN              NaN
# 2                  Candeina nitida         species           422278
# 3       Dentoglobigerina altispira         species           402661
# 4  Dentoglobigerina baroemoenensis         species           422289
#
#                 species_taxon_name genus_taxon_id  genus_taxon_name  \
# 0                              NaN            NaN               NaN
# 1                              NaN            NaN               NaN
# 2                  Candeina nitida           1053          Candeina
# 3       Dentoglobigerina altispira           1264  Dentoglobigerina
# 4  Dentoglobigerina baroemoenensis           1264  Dentoglobigerina
#
#   family_taxon_id family_taxon_name order_taxon_id order_taxon_name  \
# 0             NaN               NaN            NaN              NaN
# 1             NaN               NaN            NaN              NaN
# 2          422277       Candeinidae            NaN              NaN
# 3           82191    Globigerinidae            NaN              NaN
# 4           82191    Globigerinidae            NaN              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN             NaN               NaN
# 1            NaN              NaN             NaN               NaN
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4            NaN              NaN          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 0              NaN                NaN                     NaN
# 1              NaN                NaN                     NaN
# 2           212476           Rhizaria                     NaN
# 3           212476           Rhizaria                     NaN
# 4           212476           Rhizaria                     NaN
#
#   unranked clade_taxon_name
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
taxa_df = pd.read_csv(taxa_list_file, dtype=str)

log_df(taxa_df)
# 4736
# Out:
# (4736, 29)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id  family_taxon_name  \
# 0             NaN                 NaN  ...             NaN                NaN
# 1             NaN                 NaN  ...             NaN                NaN
# 2             NaN                 NaN  ...             NaN                NaN
# 3             NaN                 NaN  ...          155922  Pleurostomellidae
# 4             NaN                 NaN  ...             NaN                NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN          22826        Ostracoda
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2          288974      Foraminifera           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
# [5 rows x 29 columns]

# %%
filter_species_df = species_df[species_df['species_taxon_id'].notna()]

log_df(filter_species_df)
# 495
# Out:
# (495, 20)
#                 genus species name pbdb_taxon_id  \
# 2                  Candeina nitida        422278
# 3       Dentoglobigerina altispira        402661
# 4  Dentoglobigerina baroemoenensis        422289
# 5            Globigerina bulloides        113301
# 6          Globigerina falconensis        388387
#
#                    pbdb_taxon_name pbdb_taxon_rank species_taxon_id  \
# 2                  Candeina nitida         species           422278
# 3       Dentoglobigerina altispira         species           402661
# 4  Dentoglobigerina baroemoenensis         species           422289
# 5            Globigerina bulloides         species           113301
# 6          Globigerina falconensis         species           388387
#
#                 species_taxon_name genus_taxon_id  genus_taxon_name  \
# 2                  Candeina nitida           1053          Candeina
# 3       Dentoglobigerina altispira           1264  Dentoglobigerina
# 4  Dentoglobigerina baroemoenensis           1264  Dentoglobigerina
# 5            Globigerina bulloides           1498       Globigerina
# 6          Globigerina falconensis           1498       Globigerina
#
#   family_taxon_id family_taxon_name order_taxon_id order_taxon_name  \
# 2          422277       Candeinidae            NaN              NaN
# 3           82191    Globigerinidae            NaN              NaN
# 4           82191    Globigerinidae            NaN              NaN
# 5           82191    Globigerinidae            NaN              NaN
# 6           82191    Globigerinidae            NaN              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4            NaN              NaN          288974      Foraminifera
# 5            NaN              NaN          288974      Foraminifera
# 6            NaN              NaN          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 2           212476           Rhizaria                     NaN
# 3           212476           Rhizaria                     NaN
# 4           212476           Rhizaria                     NaN
# 5           212476           Rhizaria                     NaN
# 6           212476           Rhizaria                     NaN
#
#   unranked clade_taxon_name
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN

# %%
filter_species_df[filter_species_df['pbdb_taxon_id'].isna()]
# Out:
# Empty DataFrame
# Columns: [genus species name, pbdb_taxon_id, pbdb_taxon_name, pbdb_taxon_rank, species_taxon_id, species_taxon_name, genus_taxon_id, genus_taxon_name, family_taxon_id, family_taxon_name, order_taxon_id, order_taxon_name, class_taxon_id, class_taxon_name, phylum_taxon_id, phylum_taxon_name, kingdom_taxon_id, kingdom_taxon_name, unranked clade_taxon_id, unranked clade_taxon_name]
# Index: []

# %%
taxa_df['species name'].fillna('', inplace=True)

taxa_df.loc[~taxa_df['species name'].str.contains('spp\.|sp\..*?', regex=True), 'genus species name'] = taxa_df['genus name'] + ' ' + taxa_df['species name']

taxa_df['genus species name'] = taxa_df['genus species name'].str.strip()

log_df(taxa_df)
# 4736
# Out:
# (4736, 30)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN                              NaN
# 3            NaN              NaN                              NaN
# 4            NaN              NaN                              NaN
#
#   subspecies name non-taxa descriptor  ...  family_taxon_name order_taxon_id  \
# 0             NaN                 NaN  ...                NaN            NaN
# 1             NaN                 NaN  ...                NaN            NaN
# 2             NaN                 NaN  ...                NaN            NaN
# 3             NaN                 NaN  ...  Pleurostomellidae            NaN
# 4             NaN                 NaN  ...                NaN            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 2              NaN            NaN              NaN          288974
# 3              NaN            NaN              NaN          288974
# 4              NaN          22826        Ostracoda           18891
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name   genus species name
# 0      Foraminifera           212476           Rhizaria   Euuvigerina miozea
# 1      Foraminifera           212476           Rhizaria  Euuvigerina rodleyi
# 2      Foraminifera           212476           Rhizaria                  NaN
# 3      Foraminifera           212476           Rhizaria                  NaN
# 4        Arthropoda           325038           Animalia                  NaN
#
# [5 rows x 30 columns]

# %%
fields = [
    'species_taxon_name', 'species_taxon_id',
    'genus_taxon_name', 'genus_taxon_id',
    'family_taxon_name', 'family_taxon_id',
    'order_taxon_name', 'order_taxon_id',
    'class_taxon_name', 'class_taxon_id',
    'phylum_taxon_name', 'phylum_taxon_id',
    'kingdom_taxon_name', 'kingdom_taxon_id',
    
]

for index, row in filter_species_df.iterrows():
    if pd.isna(row['pbdb_taxon_id']):
        continue
        
    taxa_df.loc[taxa_df['genus species name'] == row['genus species name'], 'pbdb_taxon_id' ] = row['species_taxon_id']
    taxa_df.loc[taxa_df['genus species name'] == row['genus species name'], 'pbdb_taxon_name' ] = row['species_taxon_name']
    taxa_df.loc[taxa_df['genus species name'] == row['genus species name'], 'pbdb_taxon_rank' ] = 'species'

        
    for field in fields:
        taxa_df.loc[taxa_df['genus species name'] == row['genus species name'], field] = row[field]

# %%
del taxa_df['genus species name']

log_df(taxa_df)
# Out:
# (4736, 29)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN                              NaN
# 3            NaN              NaN                              NaN
# 4            NaN              NaN                              NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id  family_taxon_name  \
# 0             NaN                 NaN  ...             NaN                NaN
# 1             NaN                 NaN  ...             NaN                NaN
# 2             NaN                 NaN  ...             NaN                NaN
# 3             NaN                 NaN  ...          155922  Pleurostomellidae
# 4             NaN                 NaN  ...             NaN                NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN          22826        Ostracoda
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2          288974      Foraminifera           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
# [5 rows x 29 columns]

# %%
taxa_df.to_csv(taxa_list_file, index=False)
