# %% [markdown]
# # Normalize taxa list
#
# Cleanup the normalized taxa list from the eODP researchers. Add PBDB taxa data.

# %%
import sys
sys.path.append('../../../')

import pandas as pd
import numpy as np
import requests

from config import CLEAN_DATA_DIR, OUTPUT_DIR, RAW_DATA_DIR

import scripts.normalize_taxa as nt
import scripts.pbdb as pbdb

from scripts.pbdb import get_parent_taxa, PBDB_TAXA_NAME, PBDB_TAXA_ID

# %%
date = '2022-04-08-13'

input_file = RAW_DATA_DIR/'PI_processed_files'/f'LIMS Micropal_CSV_4_taxa_{date}.csv'

pi_taxa_file_pbdb = OUTPUT_DIR /'taxa'/'LIMS'/f'PI_normalized_taxa_list_with_pbdb_{date}.csv'
crosswalk_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_crosswalk_{date}.csv"
taxa_list_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_list_{date}.csv"

genus_pbdb_file = OUTPUT_DIR/'taxa'/'LIMS'/f"genera_pbdb_{date}.csv"
higher_taxa_pbdb_file = OUTPUT_DIR/'taxa'/'LIMS'/f"higher_taxa_pbdb_{date}.csv"

genus_letter_old_file= OUTPUT_DIR/'taxa'/'draft'/'LIMS'/f"micropal_4_genus_letter_2022-02-24.csv"
genus_letter_file= OUTPUT_DIR/'taxa'/'draft'/'LIMS'/f"micropal_4_genus_letter_{date}.csv"

lims_1_3_crosswalk_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_crosswalk_2022-02-22.csv"
lims_1_3_taxa_list_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_list_2022-02-22.csv"

# %%
def log_df(df, row_count=5):
    print(df.shape)
    return df.head(row_count)

# %% [markdown]
# ## fix abbreviated genus

# %%
df = pd.read_csv(input_file, dtype=str)
log_df(df)
# Out:
# (681, 32)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                        Name           Comment  \
# 0        Textulariia indet.               NaN
# 1        Textulariia indet.               NaN
# 2                       NaN               NaN
# 3             Alabamina sp.  genus misspelled
# 4  Alabaminella weddelensis  genus misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... order_taxon_id  \
# 0           NaN                NaN            NaN  ...            NaN
# 1           NaN                NaN            NaN  ...            NaN
# 2  Alabaminella                NaN            NaN  ...            NaN
# 3     Alabamina                NaN            NaN  ...            NaN
# 4  Alabaminella                NaN            NaN  ...            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN             NaN
# 1              NaN            NaN              NaN             NaN
# 2              NaN            NaN              NaN          288974
# 3              NaN            NaN              NaN             NaN
# 4              NaN            NaN              NaN             NaN
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0               NaN              NaN                NaN
# 1               NaN              NaN                NaN
# 2      Foraminifera           212476           Rhizaria
# 3               NaN              NaN                NaN
# 4               NaN              NaN                NaN
#
#   unranked clade_taxon_id unranked clade_taxon_name
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
# [5 rows x 32 columns]

# %%
genus_df = pd.read_csv(genus_letter_old_file, dtype=str, usecols=['verbatim_name'])
genus_df['abbrev_genus'] = True
log_df(genus_df)
# Out:
# (34, 2)
#                              verbatim_name  abbrev_genus
# 0  Calc. Hyaline Foram. gen. et sp. indet.          True
# 1                        Gen. et sp. indet          True
# 2              O. centrocarpum var. Arctic          True
# 3     O. centrocarpum var. short processes          True
# 4        O. centrocarpum-Arctic morphotype          True

# %%
df = df.merge(genus_df, on ='verbatim_name', how='left')
df.loc[df['abbrev_genus'].isna(), 'abbrev_genus'] = False

log_df(df)
# Out:
# (681, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                        Name           Comment  \
# 0        Textulariia indet.               NaN
# 1        Textulariia indet.               NaN
# 2                       NaN               NaN
# 3             Alabamina sp.  genus misspelled
# 4  Alabaminella weddelensis  genus misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... order_taxon_name  \
# 0           NaN                NaN            NaN  ...              NaN
# 1           NaN                NaN            NaN  ...              NaN
# 2  Alabaminella                NaN            NaN  ...              NaN
# 3     Alabamina                NaN            NaN  ...              NaN
# 4  Alabaminella                NaN            NaN  ...              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN             NaN               NaN
# 1            NaN              NaN             NaN               NaN
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN             NaN               NaN
# 4            NaN              NaN             NaN               NaN
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 0              NaN                NaN                     NaN
# 1              NaN                NaN                     NaN
# 2           212476           Rhizaria                     NaN
# 3              NaN                NaN                     NaN
# 4              NaN                NaN                     NaN
#
#   unranked clade_taxon_name abbrev_genus
# 0                       NaN        False
# 1                       NaN        False
# 2                       NaN        False
# 3                       NaN        False
# 4                       NaN        False
#
# [5 rows x 33 columns]

# %% [markdown]
# set name parts columns to null; reparse name parts column

# %%
columns = [
    'genus modifier', 'genus name', 'subgenera modifier', 'subgenera name',
    'species modifier', 'species name', 'subspecies modifier',
    'subspecies name', 'non-taxa descriptor', 'pbdb_taxon_id',
     'pbdb_taxon_name', 'pbdb_taxon_rank',
    'family_taxon_id', 'family_taxon_name', 'order_taxon_id',
    'order_taxon_name', 'class_taxon_id', 'class_taxon_name',
    'phylum_taxon_id', 'phylum_taxon_name', 'kingdom_taxon_id',
    'kingdom_taxon_name', 'unranked clade_taxon_id',
    'unranked clade_taxon_name'
]

for index, row in df[df['abbrev_genus'] & df['Name'].notna()].iterrows():    
    taxon_name_parts = nt.taxon_name_parser(row['Name'])
    
    for col in columns:
        df.at[index, col] = np.nan

    for rank in taxon_name_parts:
        df.at[index, rank] = taxon_name_parts[rank]

# %% [markdown]
# add pbdb id

# %%
for index, row in df[df['abbrev_genus'] & df['Name'].notna()].iterrows():    
    url =  PBDB_TAXA_NAME +  row['genus name']
        
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            df.at[index, f'pbdb_taxon_id'] = str(data[0]["taxon_no"])
            df.at[index, f'pbdb_taxon_name'] = data[0]["taxon_name"]
            df.at[index, f'pbdb_taxon_rank'] = data[0]["taxon_rank"]

            round = 0
            get_parent_taxa(df, data[0]["parent_no"], data[0]["taxon_rank"], round, index, None)

# %%
# df.sort_values(['taxon_group', 'verbatim_name'], inplace=True)

# %%
df.to_csv( pi_taxa_file_pbdb,index=False)

# %% [markdown]
# ## fix incorect pbdb_taxon_id
#
# incorported  pbdb_taxon_id that the PIs corrected into the taxalist.

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)
df = df.dropna(how="all", axis="index")
df['corrected'] = False

log_df(df)
# Out:
# (681, 34)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                        Name           Comment  \
# 0        Textulariia indet.               NaN
# 1        Textulariia indet.               NaN
# 2                       NaN               NaN
# 3             Alabamina sp.  genus misspelled
# 4  Alabaminella weddelensis  genus misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... class_taxon_id  \
# 0           NaN                NaN            NaN  ...            NaN
# 1           NaN                NaN            NaN  ...            NaN
# 2  Alabaminella                NaN            NaN  ...            NaN
# 3     Alabamina                NaN            NaN  ...            NaN
# 4  Alabaminella                NaN            NaN  ...            NaN
#
#   class_taxon_name phylum_taxon_id phylum_taxon_name kingdom_taxon_id  \
# 0              NaN          288974      Foraminifera           212476
# 1              NaN          288974      Foraminifera           212476
# 2              NaN          288974      Foraminifera           212476
# 3              NaN          288974      Foraminifera           212476
# 4              NaN          288974      Foraminifera           212476
#
#   kingdom_taxon_name unranked clade_taxon_id unranked clade_taxon_name  \
# 0           Rhizaria                     NaN                       NaN
# 1           Rhizaria                     NaN                       NaN
# 2           Rhizaria                     NaN                       NaN
# 3           Rhizaria                     NaN                       NaN
# 4           Rhizaria                     NaN                       NaN
#
#   abbrev_genus corrected
# 0        FALSE     False
# 1        FALSE     False
# 2        FALSE     False
# 3        FALSE     False
# 4        FALSE     False
#
# [5 rows x 34 columns]

# %%
tmp = df[df['Corrections to pbdb_taxon_id'].notna() & (df['corrected'] == False)]
tmp['Corrections to pbdb_taxon_id'].unique()
# Out:
# array(['1064', '432650', '68421', '71266', '421517', '54452', '2894',
#        '71284', '82180'], dtype=object)

# %%
pbdb.fix_pbdb_id(df, '1064', 1064)
pbdb.fix_pbdb_id(df, '432650', 432650)
pbdb.fix_pbdb_id(df, '68421', 68421)
pbdb.fix_pbdb_id(df, '71266', 71266)
pbdb.fix_pbdb_id(df, '421517', 421517)
pbdb.fix_pbdb_id(df, '71284', 71284)
pbdb.fix_pbdb_id(df, '82180', 82180)
pbdb.fix_pbdb_id(df, '54452', 54452)
pbdb.fix_pbdb_id(df, '2894', 2894)
# Out:
# 1064
# 432650
# 68421
# 71266
# 421517
# 71284
# 82180
# 54452
# 2894

# %%
df.shape
# Out:
# (681, 34)

# %%
del df['corrected']

# %%
# df.sort_values(['taxon_group', 'verbatim_name'], inplace=True)

# %%
df.to_csv(pi_taxa_file_pbdb, index=False)

# %% [markdown]
# ## add missing pbdb id

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)


log_df(df, 3)
# Out:
# (681, 33)
#       taxon_group                           verbatim_name                Name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.  Textulariia indet.
# 1  benthic_forams                     Agglutinated indet.  Textulariia indet.
# 2  benthic_forams                Alabaminella weddelensis                 NaN
#
#   Comment Notes (change to Internal only notes?) Any taxon above genus  \
# 0     NaN                                    NaN    Textulariia indet.
# 1     NaN                                    NaN    Textulariia indet.
# 2     NaN                                    NaN                   NaN
#
#   genus modifier    genus name subgenera modifier subgenera name  ...  \
# 0            NaN           NaN                NaN            NaN  ...
# 1            NaN           NaN                NaN            NaN  ...
# 2            NaN  Alabaminella                NaN            NaN  ...
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 2              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0      Foraminifera           212476           Rhizaria
# 1      Foraminifera           212476           Rhizaria
# 2      Foraminifera           212476           Rhizaria
#
#   unranked clade_taxon_id unranked clade_taxon_name abbrev_genus
# 0                     NaN                       NaN        FALSE
# 1                     NaN                       NaN        FALSE
# 2                     NaN                       NaN        FALSE
#
# [3 rows x 33 columns]

# %%
tmp = df[df['pbdb_taxon_id'].isna() & df['Any taxon above genus'].isna() ]

log_df(tmp)
# Out:
# (13, 33)
#         taxon_group                                     verbatim_name Name  \
# 25   benthic_forams                                        Bathymetry  NaN
# 283         diatoms  Diatom Zone (NPD) in Yanagisawa and Akiba (1998)  NaN
# 284         diatoms          Diatom Zone (Yanagisawa and Akiba, 1998)  NaN
# 299         diatoms                                 Gen. et sp. indet  NaN
# 307         diatoms                                            Marine  NaN
#
#     Comment             Notes (change to Internal only notes?)  \
# 25      NaN       keep and move to eODP unified data structure
# 283     NaN       keep and move to eODP unified data structure
# 284     NaN       keep and move to eODP unified data structure
# 299  DELETE                   JAS: Not useful, delete? AF: Yes
# 307  DELETE  “Marine” only appears in one file and has abun...
#
#     Any taxon above genus genus modifier genus name subgenera modifier  \
# 25                    NaN            NaN        NaN                NaN
# 283                   NaN            NaN        NaN                NaN
# 284                   NaN            NaN        NaN                NaN
# 299                   NaN            NaN        NaN                NaN
# 307                   NaN            NaN        NaN                NaN
#
#     subgenera name  ... order_taxon_name class_taxon_id class_taxon_name  \
# 25             NaN  ...              NaN            NaN              NaN
# 283            NaN  ...              NaN            NaN              NaN
# 284            NaN  ...              NaN            NaN              NaN
# 299            NaN  ...              NaN            NaN              NaN
# 307            NaN  ...              NaN            NaN              NaN
#
#     phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 25              NaN               NaN              NaN                NaN
# 283             NaN               NaN              NaN                NaN
# 284             NaN               NaN              NaN                NaN
# 299             NaN               NaN              NaN                NaN
# 307             NaN               NaN              NaN                NaN
#
#     unranked clade_taxon_id unranked clade_taxon_name abbrev_genus
# 25                      NaN                       NaN        FALSE
# 283                     NaN                       NaN        FALSE
# 284                     NaN                       NaN        FALSE
# 299                     NaN                       NaN         TRUE
# 307                     NaN                       NaN        FALSE
#
# [5 rows x 33 columns]

# %%
genus_df = pd.DataFrame(tmp['genus name'].dropna().unique(), columns=['genus name'])
log_df(genus_df)
# Out:
# (0, 1)
# Empty DataFrame
# Columns: [genus name]
# Index: []

# %%
for index, row in genus_df.iterrows():  
    if index % 50 == 0:
        print(index, end=' ')
        
    url =  PBDB_TAXA_NAME +  row['genus name']
        
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            genus_df.at[index, f'pbdb_taxon_id'] = str(data[0]["taxon_no"])
            genus_df.at[index, f'pbdb_taxon_name'] = data[0]["taxon_name"]
            genus_df.at[index, f'pbdb_taxon_rank'] = data[0]["taxon_rank"]
            
            round = 0
            get_parent_taxa(genus_df, data[0]["parent_no"], data[0]["taxon_rank"], round, index, None)
# Out:
# 0

# %%
log_df(genus_df)
# Out:
# (1, 14)
#      genus name pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank family_taxon_id  \
# 0  Gephyrocapsa        421973    Gephyrocapsa           genus          419747
#
#   family_taxon_name order_taxon_id order_taxon_name class_taxon_id  \
# 0  Noelaerhabdaceae         418931   Isochrysidales         418920
#
#     class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0  Coccolithophyceae           87644        Haptophyta
#
#   unranked clade_taxon_id unranked clade_taxon_name
# 0                   28595                      Life

# %%
genus_df.to_csv(genus_pbdb_file, index=False)

# %%
genus_df.columns
# Out:
# Index(['genus name', 'pbdb_taxon_id', 'pbdb_taxon_name', 'pbdb_taxon_rank',
#        'family_taxon_id', 'family_taxon_name', 'order_taxon_id',
#        'order_taxon_name', 'class_taxon_id', 'class_taxon_name',
#        'phylum_taxon_id', 'phylum_taxon_name', 'unranked clade_taxon_id',
#        'unranked clade_taxon_name'],
#       dtype='object')

# %%
columns = [
    
     'pbdb_taxon_name', 'pbdb_taxon_rank',
    'family_taxon_id', 'family_taxon_name', 'order_taxon_id',
    'order_taxon_name', 'class_taxon_id', 'class_taxon_name',
    'phylum_taxon_id', 'phylum_taxon_name', 'kingdom_taxon_id',
    'kingdom_taxon_name', 'unranked clade_taxon_id',
    'unranked clade_taxon_name', 'pbdb_taxon_id',
    
]

for index, row  in genus_df.iterrows():
    for col in columns:
        if col not in genus_df:
            continue
        df.loc[ (df['pbdb_taxon_id'].isna()) & (df['genus name'] == row['genus name']), col] = row[col]

# %%
log_df(df)
# Out:
# (681, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                        Name           Comment  \
# 0        Textulariia indet.               NaN
# 1        Textulariia indet.               NaN
# 2                       NaN               NaN
# 3             Alabamina sp.  genus misspelled
# 4  Alabaminella weddelensis  genus misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... order_taxon_name  \
# 0           NaN                NaN            NaN  ...              NaN
# 1           NaN                NaN            NaN  ...              NaN
# 2  Alabaminella                NaN            NaN  ...              NaN
# 3     Alabamina                NaN            NaN  ...              NaN
# 4  Alabaminella                NaN            NaN  ...              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN          288974      Foraminifera
# 1            NaN              NaN          288974      Foraminifera
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4            NaN              NaN          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 0           212476           Rhizaria                     NaN
# 1           212476           Rhizaria                     NaN
# 2           212476           Rhizaria                     NaN
# 3           212476           Rhizaria                     NaN
# 4           212476           Rhizaria                     NaN
#
#   unranked clade_taxon_name abbrev_genus
# 0                       NaN        FALSE
# 1                       NaN        FALSE
# 2                       NaN        FALSE
# 3                       NaN        FALSE
# 4                       NaN        FALSE
#
# [5 rows x 33 columns]

# %%
df.to_csv(pi_taxa_file_pbdb, index=False)

# %% [markdown]
# ## higher taxa

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)
log_df(df, 3)
# Out:
# (681, 33)
#       taxon_group                           verbatim_name                Name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.  Textulariia indet.
# 1  benthic_forams                     Agglutinated indet.  Textulariia indet.
# 2  benthic_forams                Alabaminella weddelensis                 NaN
#
#   Comment Notes (change to Internal only notes?) Any taxon above genus  \
# 0     NaN                                    NaN    Textulariia indet.
# 1     NaN                                    NaN    Textulariia indet.
# 2     NaN                                    NaN                   NaN
#
#   genus modifier    genus name subgenera modifier subgenera name  ...  \
# 0            NaN           NaN                NaN            NaN  ...
# 1            NaN           NaN                NaN            NaN  ...
# 2            NaN  Alabaminella                NaN            NaN  ...
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 2              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0      Foraminifera           212476           Rhizaria
# 1      Foraminifera           212476           Rhizaria
# 2      Foraminifera           212476           Rhizaria
#
#   unranked clade_taxon_id unranked clade_taxon_name abbrev_genus
# 0                     NaN                       NaN        FALSE
# 1                     NaN                       NaN        FALSE
# 2                     NaN                       NaN        FALSE
#
# [3 rows x 33 columns]

# %%
tmp = df[df['pbdb_taxon_id'].isna() & df['Any taxon above genus'].notna() ]

higher_df = pd.DataFrame(tmp['Any taxon above genus'].str.strip().dropna().unique(), columns=['Any taxon above genus']) 
higher_df.replace('', np.nan, inplace=True)
higher_df.dropna(inplace=True)
higher_df
# Out:
#                           Any taxon above genus
# 0                                 "Fish scales"
# 1                                  "Fish teeth"
# 2                                    "Otoliths"
# 3          "Undifferentiated pollen from herbs"
# 4                     "Undifferentiated pollen"
# 5         "Undifferentiated pollen from shrubs"
# 6          "Undifferentiated pollen from trees"
# 7                       "Reworked palynomorphs"
# 8  "Undifferentiated spores from moss or ferns"

# %%
for index, row in higher_df.iterrows():        
    if index % 20 == 0:
        print(index)
        
    name = row['Any taxon above genus'].replace(' indet.', '')

  
    url =  PBDB_TAXA_NAME +  name
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            higher_df.at[index, f'pbdb_taxon_id'] = str(data[0]["taxon_no"])
            higher_df.at[index, f'pbdb_taxon_name'] = data[0]["taxon_name"]
            higher_df.at[index, f'pbdb_taxon_rank'] = data[0]["taxon_rank"]
            
            round = 0
            get_parent_taxa(higher_df, data[0]["parent_no"], data[0]["taxon_rank"], round, index, None)
        else:
            print(name, len(data), ' found')
    else:
        print(name, ' not found')
# Out:
# 0
# "Fish scales"  not found
# "Fish teeth"  not found
# "Otoliths"  not found
# "Undifferentiated pollen from herbs"  not found
# "Undifferentiated pollen"  not found
# "Undifferentiated pollen from shrubs"  not found
# "Undifferentiated pollen from trees"  not found
# "Reworked palynomorphs"  not found
# "Undifferentiated spores from moss or ferns"  not found

# %%
higher_df.to_csv(higher_taxa_pbdb_file, index=False)

# %%
higher_df.columns
# Out:
# Index(['Any taxon above genus'], dtype='object')

# %%
columns = [
    
     'pbdb_taxon_name', 'pbdb_taxon_rank',
    'order_taxon_id', 'order_taxon_name', 
    'class_taxon_id', 'class_taxon_name',
    'phylum_taxon_id', 'phylum_taxon_name', 
    'kingdom_taxon_id', 'kingdom_taxon_name', 
    'unranked clade_taxon_id',  'unranked clade_taxon_name', 'pbdb_taxon_id',
    
]

for index, row  in higher_df.iterrows():
    for col in columns:
        if col not in higher_df.columns:
            continue
        df.loc[ (df['pbdb_taxon_id'].isna()) & (df['Any taxon above genus'] == row['Any taxon above genus']), col] = row[col]

# %%
log_df(df)
# Out:
# (681, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                        Name           Comment  \
# 0        Textulariia indet.               NaN
# 1        Textulariia indet.               NaN
# 2                       NaN               NaN
# 3             Alabamina sp.  genus misspelled
# 4  Alabaminella weddelensis  genus misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... order_taxon_name  \
# 0           NaN                NaN            NaN  ...              NaN
# 1           NaN                NaN            NaN  ...              NaN
# 2  Alabaminella                NaN            NaN  ...              NaN
# 3     Alabamina                NaN            NaN  ...              NaN
# 4  Alabaminella                NaN            NaN  ...              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN          288974      Foraminifera
# 1            NaN              NaN          288974      Foraminifera
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4            NaN              NaN          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 0           212476           Rhizaria                     NaN
# 1           212476           Rhizaria                     NaN
# 2           212476           Rhizaria                     NaN
# 3           212476           Rhizaria                     NaN
# 4           212476           Rhizaria                     NaN
#
#   unranked clade_taxon_name abbrev_genus
# 0                       NaN        FALSE
# 1                       NaN        FALSE
# 2                       NaN        FALSE
# 3                       NaN        FALSE
# 4                       NaN        FALSE
#
# [5 rows x 33 columns]

# %%
df.to_csv(pi_taxa_file_pbdb, index=False)

# %% [markdown]
# ## Create crosswalk csv

# %%
existing_crosswalk = pd.read_csv(lims_1_3_crosswalk_file, dtype=str)
log_df(existing_crosswalk, 3)
# Out:
# (4590, 14)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor      normalized_name     taxon_group  \
# 0             NaN                 NaN   Euuvigerina miozea  benthic_forams
# 1             NaN                 NaN  Euuvigerina rodleyi  benthic_forams
# 2             NaN                 NaN  Foraminifera indet.  benthic_forams
#
#                        verbatim_name                    comments
# 0  Euuvigerina miozea (group) >100 m                >100 m group
# 1  Euuvigerina rodleyi (group) >50 m                 >50 m group
# 2                             Others  other benthic foraminifera

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)
log_df(df, 3)
# Out:
# (681, 33)
#       taxon_group                           verbatim_name                Name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.  Textulariia indet.
# 1  benthic_forams                     Agglutinated indet.  Textulariia indet.
# 2  benthic_forams                Alabaminella weddelensis                 NaN
#
#   Comment Notes (change to Internal only notes?) Any taxon above genus  \
# 0     NaN                                    NaN    Textulariia indet.
# 1     NaN                                    NaN    Textulariia indet.
# 2     NaN                                    NaN                   NaN
#
#   genus modifier    genus name subgenera modifier subgenera name  ...  \
# 0            NaN           NaN                NaN            NaN  ...
# 1            NaN           NaN                NaN            NaN  ...
# 2            NaN  Alabaminella                NaN            NaN  ...
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 2              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0      Foraminifera           212476           Rhizaria
# 1      Foraminifera           212476           Rhizaria
# 2      Foraminifera           212476           Rhizaria
#
#   unranked clade_taxon_id unranked clade_taxon_name abbrev_genus
# 0                     NaN                       NaN        FALSE
# 1                     NaN                       NaN        FALSE
# 2                     NaN                       NaN        FALSE
#
# [3 rows x 33 columns]

# %%
fields = nt.taxa_rank_fields + nt.taxa_fields + nt.metadata_fields  
fields
# Out:
# ['Any taxon above genus',
#  'genus modifier',
#  'genus name',
#  'subgenera modifier',
#  'subgenera name',
#  'species modifier',
#  'species name',
#  'subspecies modifier',
#  'subspecies name',
#  'non-taxa descriptor',
#  'normalized_name',
#  'taxon_group',
#  'verbatim_name',
#  'comments']

# %%
filtered_taxa = pd.DataFrame(df, columns=fields)
log_df(filtered_taxa, 2)
# Out:
# (681, 14)
#   Any taxon above genus genus modifier genus name subgenera modifier  \
# 0    Textulariia indet.            NaN        NaN                NaN
# 1    Textulariia indet.            NaN        NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN          NaN                 NaN
# 1            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  normalized_name     taxon_group  \
# 0             NaN                 NaN              NaN  benthic_forams
# 1             NaN                 NaN              NaN  benthic_forams
#
#                             verbatim_name comments
# 0  Agglutinated Foram. gen. et sp. indet.      NaN
# 1                     Agglutinated indet.      NaN

# %%
nt.add_normalized_name_column(filtered_taxa)
log_df(filtered_taxa)

filtered_taxa = filtered_taxa.drop(filtered_taxa[filtered_taxa['normalized_name'] == ''].index)
log_df(filtered_taxa)

filtered_taxa.drop_duplicates(keep='first', inplace=True, subset =['verbatim_name', 'normalized_name'])
log_df(filtered_taxa)
# Out:
# (681, 14)
# (668, 14)
# (662, 14)
#   Any taxon above genus genus modifier    genus name subgenera modifier  \
# 0    Textulariia indet.            NaN           NaN                NaN
# 1    Textulariia indet.            NaN           NaN                NaN
# 2                   NaN            NaN  Alabaminella                NaN
# 3                   NaN            NaN     Alabamina                NaN
# 4                   NaN            NaN  Alabaminella                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN          NaN                 NaN
# 1            NaN              NaN          NaN                 NaN
# 2            NaN              NaN  weddelensis                 NaN
# 3            NaN              NaN          sp.                 NaN
# 4            NaN              NaN  weddelensis                 NaN
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 0             NaN                 NaN        Textulariia indet.
# 1             NaN                 NaN        Textulariia indet.
# 2             NaN                 NaN  Alabaminella weddelensis
# 3             NaN                 NaN             Alabamina sp.
# 4             NaN                 NaN  Alabaminella weddelensis
#
#       taxon_group                           verbatim_name comments
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.      NaN
# 1  benthic_forams                     Agglutinated indet.      NaN
# 2  benthic_forams                Alabaminella weddelensis      NaN
# 3  benthic_forams                          Alabammina sp.      NaN
# 4  benthic_forams               Alabamminella weddelensis      NaN

# %%
existing_crosswalk.columns == filtered_taxa.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
combine_df = pd.concat([existing_crosswalk, filtered_taxa])
combine_df.shape
# Out:
# (5252, 14)

# %%
combine_df.to_csv(crosswalk_file, index=False)

# %% [markdown]
# ## Create taxa csv

# %%
existing_taxa = pd.read_csv(lims_1_3_taxa_list_file, dtype=str)
log_df(existing_taxa, 3)
# Out:
# (4205, 25)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2             NaN               NaN           212476           Rhizaria
#
# [3 rows x 25 columns]

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)
log_df(df, 3)
# Out:
# (681, 33)
#       taxon_group                           verbatim_name                Name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.  Textulariia indet.
# 1  benthic_forams                     Agglutinated indet.  Textulariia indet.
# 2  benthic_forams                Alabaminella weddelensis                 NaN
#
#   Comment Notes (change to Internal only notes?) Any taxon above genus  \
# 0     NaN                                    NaN    Textulariia indet.
# 1     NaN                                    NaN    Textulariia indet.
# 2     NaN                                    NaN                   NaN
#
#   genus modifier    genus name subgenera modifier subgenera name  ...  \
# 0            NaN           NaN                NaN            NaN  ...
# 1            NaN           NaN                NaN            NaN  ...
# 2            NaN  Alabaminella                NaN            NaN  ...
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 2              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0      Foraminifera           212476           Rhizaria
# 1      Foraminifera           212476           Rhizaria
# 2      Foraminifera           212476           Rhizaria
#
#   unranked clade_taxon_id unranked clade_taxon_name abbrev_genus
# 0                     NaN                       NaN        FALSE
# 1                     NaN                       NaN        FALSE
# 2                     NaN                       NaN        FALSE
#
# [3 rows x 33 columns]

# %%
fields = nt.taxa_rank_fields  + nt.taxa_fields + nt.pdbd_fields + ['verbatim_name']
fields
# Out:
# ['Any taxon above genus',
#  'genus modifier',
#  'genus name',
#  'subgenera modifier',
#  'subgenera name',
#  'species modifier',
#  'species name',
#  'subspecies modifier',
#  'subspecies name',
#  'non-taxa descriptor',
#  'normalized_name',
#  'taxon_group',
#  'pbdb_taxon_id',
#  'pbdb_taxon_name',
#  'pbdb_taxon_rank',
#  'family_taxon_id',
#  'family_taxon_name',
#  'order_taxon_id',
#  'order_taxon_name',
#  'class_taxon_id',
#  'class_taxon_name',
#  'phylum_taxon_id',
#  'phylum_taxon_name',
#  'kingdom_taxon_id',
#  'kingdom_taxon_name',
#  'verbatim_name']

# %%
filtered_taxa = pd.DataFrame(df, columns=fields)
log_df(filtered_taxa, 2)
# Out:
# (681, 26)
#   Any taxon above genus genus modifier genus name subgenera modifier  \
# 0    Textulariia indet.            NaN        NaN                NaN
# 1    Textulariia indet.            NaN        NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN          NaN                 NaN
# 1            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ...  family_taxon_name order_taxon_id  \
# 0             NaN                 NaN  ...                NaN            NaN
# 1             NaN                 NaN  ...                NaN            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0      Foraminifera           212476           Rhizaria
# 1      Foraminifera           212476           Rhizaria
#
#                             verbatim_name
# 0  Agglutinated Foram. gen. et sp. indet.
# 1                     Agglutinated indet.
#
# [2 rows x 26 columns]

# %%
nt.add_normalized_name_column(filtered_taxa)
log_df(filtered_taxa)

filtered_taxa = filtered_taxa.drop(filtered_taxa[filtered_taxa['normalized_name'] == ''].index)
log_df(filtered_taxa)

filtered_taxa.drop_duplicates(keep='first', inplace=True, subset =['verbatim_name', 'normalized_name'])
log_df(filtered_taxa)
# Out:
# (681, 26)
# (668, 26)
# (662, 26)
#   Any taxon above genus genus modifier    genus name subgenera modifier  \
# 0    Textulariia indet.            NaN           NaN                NaN
# 1    Textulariia indet.            NaN           NaN                NaN
# 2                   NaN            NaN  Alabaminella                NaN
# 3                   NaN            NaN     Alabamina                NaN
# 4                   NaN            NaN  Alabaminella                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN          NaN                 NaN
# 1            NaN              NaN          NaN                 NaN
# 2            NaN              NaN  weddelensis                 NaN
# 3            NaN              NaN          sp.                 NaN
# 4            NaN              NaN  weddelensis                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_name order_taxon_id  \
# 0             NaN                 NaN  ...               NaN            NaN
# 1             NaN                 NaN  ...               NaN            NaN
# 2             NaN                 NaN  ...        Eponididae            NaN
# 3             NaN                 NaN  ...      Alabaminidae            NaN
# 4             NaN                 NaN  ...        Eponididae            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 2              NaN            NaN              NaN          288974
# 3              NaN            NaN              NaN          288974
# 4              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0      Foraminifera           212476           Rhizaria
# 1      Foraminifera           212476           Rhizaria
# 2      Foraminifera           212476           Rhizaria
# 3      Foraminifera           212476           Rhizaria
# 4      Foraminifera           212476           Rhizaria
#
#                             verbatim_name
# 0  Agglutinated Foram. gen. et sp. indet.
# 1                     Agglutinated indet.
# 2                Alabaminella weddelensis
# 3                          Alabammina sp.
# 4               Alabamminella weddelensis
#
# [5 rows x 26 columns]

# %%
fields.remove('verbatim_name')
taxa_df = pd.DataFrame(filtered_taxa, columns=fields)
taxa_df = taxa_df.drop_duplicates() 

log_df(taxa_df)
# Out:
# (594, 25)
#   Any taxon above genus genus modifier    genus name subgenera modifier  \
# 0    Textulariia indet.            NaN           NaN                NaN
# 2                   NaN            NaN  Alabaminella                NaN
# 3                   NaN            NaN     Alabamina                NaN
# 5                   NaN            NaN    Ammodiscus                NaN
# 6                   NaN            NaN       Ammonia                NaN
#
#   subgenera name species modifier   species name subspecies modifier  \
# 0            NaN              NaN            NaN                 NaN
# 2            NaN              NaN    weddelensis                 NaN
# 3            NaN              NaN            sp.                 NaN
# 5            NaN              NaN          latus                 NaN
# 6            NaN              NaN  parkinsoniana                  f.
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...          241423        Eponididae
# 3             NaN                 NaN  ...           82213      Alabaminidae
# 5             NaN                 NaN  ...          112199      Ammodiscidae
# 6         aoteana                 NaN  ...          103768        Rotaliidae
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 5            NaN              NaN            NaN              NaN
# 6            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 2          288974      Foraminifera           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 5          288974      Foraminifera           212476           Rhizaria
# 6          288974      Foraminifera           212476           Rhizaria
#
# [5 rows x 25 columns]

# %%
combine_df = pd.concat([existing_taxa, taxa_df])
combine_df.shape
# Out:
# (4799, 25)

# %%
combine_df.to_csv(taxa_list_file, index=False)
