# %% [markdown]
# # Normalize LIMS taxa

# %%
import sys
sys.path.append('../../../')
import glob
import re
import os.path
import hashlib

import pandas as pd
import numpy as np

from config import CLEAN_DATA_DIR, OUTPUT_DIR, RAW_DATA_DIR

from scripts.normalize_data import (
    csv_cleanup,
    update_metadata,
    get_taxonomy_columns,
    clean_taxon_name,
    get_non_taxa_fields,
    remove_whitespace
)
import scripts.normalize_taxa as nt

# %%
# metadata_file = OUTPUT_DIR/'metadata'/'LIMS'/'Micropal_changes.csv' 
metadata_file = OUTPUT_DIR/'metadata'/'LIMS'/'Micropal_changes_4.csv'

normalized_fields_path =  OUTPUT_DIR/'normalized_data'/f'eODP_unified_data_structure_2022_02_21.csv'


clean_data_path = CLEAN_DATA_DIR

additional_taxa_path = RAW_DATA_DIR/'PI_processed_files'/'LIMS_Micropal_CSV_4_taxa_ADDTL_TAXA.csv'


date = '2022-04-28'

crosswalk_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_crosswalk_{date}.csv"
taxa_list_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_list_{date}.csv"

# %%
dex_sin_taxa = {
    "Dextral:Sinistral _N. acostaensis_": ['Neogloboquadrina acostaensis (dextral)', 'Neogloboquadrina acostaensis (sinistral)'],
    "Dextral:Sinistral _P. finalis_": ['Pulleniatina finalis (dextral)', 'Pulleniatina finalis (sinistral)'],
    "Dextral:Sinistral _P. obliquiloculata_": ['Pulleniatina obliquiloculata (dextral)', 'Pulleniatina obliquiloculata (sinistral)'],
    "Dextral:Sinistral _P. praecursor_": ['Pulleniatina praecursor (dextral)', 'Pulleniatina praecursor (sinistral)'],
    "Dextral:Sinistral _P. praespectabilis_": ['Pulleniatina praespectabilis (dextral)', 'Pulleniatina praespectabilis (sinistral)'],
    "Dextral:Sinistral _P. primalis_": ['Pulleniatina primalis (dextral)', 'Pulleniatina primalis (sinistral)'],
    "Dextral:Sinistral _P. spectabilis_": ['Pulleniatina spectabilis (dextral)', 'Pulleniatina spectabilis (sinistral)']
}

# %%
def log_df(df, row_count=5):
    print(df.shape)
    return df.head(row_count)

# %% [markdown]
# ## Clean up taxa values

# %% [markdown]
# Look for taxa columns that have "code [extra text]", and remove "[extra text]".

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0    320_U1334_benthic_forams.csv
# 1     361_U1479B_nannofossils.csv
# 2  372_U1517C_planktic_forams.csv
# 3   317_U1352_planktic_forams.csv
# 4        323_U1339_palynology.csv
#
#                                                 path      taxon_group  \
# 0   LIMS/Micropal_CSV_4/320_U1334_benthic_forams.csv   benthic_forams
# 1    LIMS/Micropal_CSV_4/361_U1479B_nannofossils.csv     nannofossils
# 2  LIMS/Micropal_CSV_4/372_U1517C_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_4/317_U1352_planktic_forams.csv  planktic_forams
# 4       LIMS/Micropal_CSV_4/323_U1339_palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                  True                   True              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4           True                  False                     False
#
#    update_sample_col  update_top_bottom  add_missing_cols  \
# 0               True              False             False
# 1              False              False             False
# 2              False              False             False
# 3               True              False             False
# 4               True              False             False
#
#    add_expedition_section_cols
# 0                        False
# 1                         True
# 2                         True
# 3                        False
# 4                        False

# %%
taxa_df = pd.read_csv(crosswalk_file, dtype=str)
taxa_df.head()
# Out:
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 0             NaN                 NaN        Euuvigerina miozea
# 1             NaN                 NaN       Euuvigerina rodleyi
# 2             NaN                 NaN       Foraminifera indet.
# 3             NaN                 NaN  Pleurostomellidae indet.
# 4             NaN                 NaN          Ostracoda indet.
#
#       taxon_group                      verbatim_name name comment field  \
# 0  benthic_forams  Euuvigerina miozea (group) >100 m                NaN
# 1  benthic_forams  Euuvigerina rodleyi (group) >50 m                NaN
# 2  benthic_forams                             Others                NaN
# 3  benthic_forams           Pleurostomellids comment                NaN
# 4  benthic_forams                     Ostracoda spp.     Ostracoda spp.
#
#            Comment             Notes (change to Internal only notes?)  \
# 0            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 1            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 2       not a taxa                                               Andy
# 3       not a taxa                                               Andy
# 4  group abundance  Summer 2020: go in as Ostracoda indet, and the...
#
#                      comments additional species comments eodp_id
# 0                >100 m group                         NaN       0
# 1                 >50 m group                         NaN       1
# 2  other benthic foraminifera                         NaN       2
# 3                         NaN                         NaN       3
# 4                         NaN                         NaN       4

# %%
taxa_list = set(taxa_df['verbatim_name'].unique())
len(taxa_list)
# Out:
# 5256

# %%
def clean_up_taxa_values(file):
    path = f"{clean_data_path}/{file}"
    content = pd.read_csv(path)
    
    taxa_cols = list(set(content.columns).intersection(taxa_list))
    filter_df = content[taxa_cols]
    content[list(taxa_cols)] = filter_df.replace(to_replace =' *\[.*\] *', value = '', regex = True) 
    
    # get rid of NAs in order to compare two dataframes   
    changed = not filter_df.fillna('').equals(content[taxa_cols].fillna(''))

    if changed:
        content = csv_cleanup(content, path)
        content.to_csv(path, index=False)

    return changed
    
change_columns = [clean_up_taxa_values(file) for file in metadata['path']]

# %% [markdown]
# ### Update metadata

# %%
dict = {"clean_up_taxa_values": change_columns}
new_metadata = update_metadata(metadata, dict)
new_metadata.head()
# Out:
#                              file  \
# 0    320_U1334_benthic_forams.csv
# 1     361_U1479B_nannofossils.csv
# 2  372_U1517C_planktic_forams.csv
# 3   317_U1352_planktic_forams.csv
# 4        323_U1339_palynology.csv
#
#                                                 path      taxon_group  \
# 0   LIMS/Micropal_CSV_4/320_U1334_benthic_forams.csv   benthic_forams
# 1    LIMS/Micropal_CSV_4/361_U1479B_nannofossils.csv     nannofossils
# 2  LIMS/Micropal_CSV_4/372_U1517C_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_4/317_U1352_planktic_forams.csv  planktic_forams
# 4       LIMS/Micropal_CSV_4/323_U1339_palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                  True                   True              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4           True                  False                     False
#
#    update_sample_col  update_top_bottom  add_missing_cols  \
# 0               True              False             False
# 1              False              False             False
# 2              False              False             False
# 3               True              False             False
# 4               True              False             False
#
#    add_expedition_section_cols  clean_up_taxa_values
# 0                        False                 False
# 1                         True                 False
# 2                         True                 False
# 3                        False                 False
# 4                        False                 False

# %%
new_metadata.to_csv(metadata_file, index=False)

# %% [markdown]
# ## Clean up non-taxa metadata values

# %% [markdown]
# Look for non-taxa metadata columns that have "code [extra text]", and remove "[extra text]".

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0    320_U1334_benthic_forams.csv
# 1     361_U1479B_nannofossils.csv
# 2  372_U1517C_planktic_forams.csv
# 3   317_U1352_planktic_forams.csv
# 4        323_U1339_palynology.csv
#
#                                                 path      taxon_group  \
# 0   LIMS/Micropal_CSV_4/320_U1334_benthic_forams.csv   benthic_forams
# 1    LIMS/Micropal_CSV_4/361_U1479B_nannofossils.csv     nannofossils
# 2  LIMS/Micropal_CSV_4/372_U1517C_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_4/317_U1352_planktic_forams.csv  planktic_forams
# 4       LIMS/Micropal_CSV_4/323_U1339_palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                  True                   True              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4           True                  False                     False
#
#    update_sample_col  update_top_bottom  add_missing_cols  \
# 0               True              False             False
# 1              False              False             False
# 2              False              False             False
# 3               True              False             False
# 4               True              False             False
#
#    add_expedition_section_cols  clean_up_taxa_values
# 0                        False                 False
# 1                         True                 False
# 2                         True                 False
# 3                        False                 False
# 4                        False                 False

# %%
cols = ['normalized', 'taxa_317-present']
non_taxa_df = pd.read_csv(normalized_fields_path, dtype=str, header=5, usecols=cols)
non_taxa_df.head()
# Out:
#    normalized  taxa_317-present
# 0      Sample  Label ID; Sample
# 1  Expedition               Exp
# 2        Site              Site
# 3        Hole              Hole
# 4        Core              Core

# %%
non_taxa_dict = get_non_taxa_fields(non_taxa_df, 'taxa_317-present')
non_taxa_list = set(non_taxa_dict.keys())

# %%
non_taxa_list
# Out:
# {'% Planktic Foraminifera within whole sample',
#  'A/W',
#  'Abundance',
#  'Additional zone name',
#  'Additional zone name (short)',
#  'Age',
#  'Aspect comment (etching)',
#  'BF Group abundance',
#  'BF Preservation',
#  'BF comment',
#  'BF preservation',
#  'Bottom Depth [m]',
#  'Bottom Depth[m] [m]',
#  'Bottom [cm]',
#  'Bottom depth [m]',
#  'Bottom offset [cm]',
#  'Bottom[cm] [cm]',
#  'COMMENTS',
#  'Comment',
#  'Comment (general)',
#  'Comments',
#  'Core',
#  'Datum age average [Ma]',
#  'Datum age maximum (Ma)',
#  'Datum age minimum (Ma)',
#  'Datum author year',
#  'Datum name',
#  'Datum name generic',
#  'Datum region',
#  'Datum type',
#  'Diatom abundance',
#  'Diatom preservation dissolution',
#  'Diatom preservation fragmentation',
#  'Diatoms group abundance',
#  'Exp',
#  'Extra Sample ID Data',
#  'Foram abundance',
#  'General comment',
#  'Genus/species (upper zone)',
#  'Genus/species lower zone)',
#  'Group Abundance',
#  'Group abundance',
#  'Group abundance (%)',
#  'Group preservation',
#  'Hole',
#  'Label ID',
#  'Large Benthic Forams [%]',
#  'Lower boundary age av. [Ma]',
#  'Mixing',
#  'Nannofossil comment',
#  'No. specimens/tray',
#  'Organic matter',
#  'PALEO WATER DEPTH (IS=inner shelf, MS=middle shelf, OS=outer shelf)',
#  'PF Group Abundance',
#  'PF Preservation',
#  'PF Zone',
#  'PF group abundance',
#  'PF preservation',
#  'Percentage of benthic forams in total foram assemblage [%]',
#  'Percentage of non-calcareous agglutinated forams in total foram assemblage [%]',
#  'Percentage of planktic forams in total foram assemblage [%]',
#  'Planktonic Benthic ratio (P:B)',
#  'Pyrite',
#  'Reworking comment (1= <1%, 2= light 1-10%, 3= >10%)',
#  'Reworking comment (1= <1%, 2=light 1-10%, 3= >10%)',
#  'Sample',
#  'Sample comment',
#  'Sample preparation comment',
#  'Section',
#  'Silicoflagellates group abundance',
#  'Sillicoflagellate abundance',
#  'Site',
#  'Temperature Range',
#  'Terrestrial organic matter',
#  'Top Depth [m]',
#  'Top Depth[m] [m]',
#  'Top [cm]',
#  'Top depth [m]',
#  'Top offset [cm]',
#  'Top[cm] [cm]',
#  'Total in situ dinocysts',
#  'Type',
#  'Type (lower zone)',
#  'Type (upper zone)',
#  'Upper boundary age av. [Ma]',
#  'Upper boundary age min [Ma]',
#  'XBroken',
#  'XCorroded',
#  'XCrumpled',
#  'Zone author (year)',
#  'Zone comment',
#  'Zone name',
#  'Zone name (short)',
#  'comments',
#  'count',
#  'count_type'}

# %%
def clean_up_taxa_meta_values(file):
    path = f"{clean_data_path}/{file}"
    content = pd.read_csv(path)
    
    nontaxa_cols = list(set(content.columns).intersection(non_taxa_list))
    filter_df = content[nontaxa_cols]
    content[list(nontaxa_cols)] = filter_df.replace(to_replace =' *\[.*\] *', value = '', regex = True) 
    
    # get rid of NAs in order to compare two dataframes   
    changed = not filter_df.fillna('').equals(content[nontaxa_cols].fillna(''))

    if changed:
        content = csv_cleanup(content, path)
        content.to_csv(path, index=False)

    return changed
    
change_columns = [clean_up_taxa_meta_values(file) for file in metadata['path']]

# %% [markdown]
# ### Update metadata

# %%
dict = {"clean_up_taxa_metadata_values": change_columns}
new_metadata = update_metadata(metadata, dict)
new_metadata.head()
# Out:
#                              file  \
# 0    320_U1334_benthic_forams.csv
# 1     361_U1479B_nannofossils.csv
# 2  372_U1517C_planktic_forams.csv
# 3   317_U1352_planktic_forams.csv
# 4        323_U1339_palynology.csv
#
#                                                 path      taxon_group  \
# 0   LIMS/Micropal_CSV_4/320_U1334_benthic_forams.csv   benthic_forams
# 1    LIMS/Micropal_CSV_4/361_U1479B_nannofossils.csv     nannofossils
# 2  LIMS/Micropal_CSV_4/372_U1517C_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_4/317_U1352_planktic_forams.csv  planktic_forams
# 4       LIMS/Micropal_CSV_4/323_U1339_palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                  True                   True              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4           True                  False                     False
#
#    update_sample_col  update_top_bottom  add_missing_cols  \
# 0               True              False             False
# 1              False              False             False
# 2              False              False             False
# 3               True              False             False
# 4               True              False             False
#
#    add_expedition_section_cols  clean_up_taxa_values  \
# 0                        False                 False
# 1                         True                 False
# 2                         True                 False
# 3                        False                 False
# 4                        False                 False
#
#    clean_up_taxa_metadata_values
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False

# %%
new_metadata.to_csv(metadata_file, index=False)

# %% [markdown]
# ## Add eodp_id

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0    320_U1334_benthic_forams.csv
# 1     361_U1479B_nannofossils.csv
# 2  372_U1517C_planktic_forams.csv
# 3   317_U1352_planktic_forams.csv
# 4        323_U1339_palynology.csv
#
#                                                 path      taxon_group  \
# 0   LIMS/Micropal_CSV_4/320_U1334_benthic_forams.csv   benthic_forams
# 1    LIMS/Micropal_CSV_4/361_U1479B_nannofossils.csv     nannofossils
# 2  LIMS/Micropal_CSV_4/372_U1517C_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_4/317_U1352_planktic_forams.csv  planktic_forams
# 4       LIMS/Micropal_CSV_4/323_U1339_palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                  True                   True              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4           True                  False                     False
#
#    update_sample_col  update_top_bottom  add_missing_cols  \
# 0               True              False             False
# 1              False              False             False
# 2              False              False             False
# 3               True              False             False
# 4               True              False             False
#
#    add_expedition_section_cols  clean_up_taxa_values  \
# 0                        False                 False
# 1                         True                 False
# 2                         True                 False
# 3                        False                 False
# 4                        False                 False
#
#    clean_up_taxa_metadata_values
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False

# %%
def add_eodp_id(file):
    path = f"{clean_data_path}/{file}"
    content = pd.read_csv(path, dtype=str)
    content.dropna(how='all', axis='rows', inplace=True)
    
    def add_hash_id(id):
        return hashlib.md5(f'{file}{id}'.encode()).hexdigest()
            
    content['eodp_id'] = content.index 
    content['eodp_id'] = content['eodp_id'].apply(add_hash_id)
    
    
    content.to_csv(path, index=False)

res = [add_eodp_id(file) for file in metadata['path']]

# %% [markdown]
# ## split Dextral:Sinistral taxa
#
# split  Dextral:Sinistral column into two columns.

# %%
cols = ['normalized_name', 'verbatim_name', 'non-taxa descriptor']
taxa_df = pd.read_csv(crosswalk_file, dtype=str, usecols=cols)
taxa_df = taxa_df[taxa_df.duplicated(subset=['verbatim_name'])]
taxa_df = taxa_df[taxa_df['non-taxa descriptor'].notna()]

taxa_df
# Out:
#      non-taxa descriptor                           normalized_name  \
# 3090           sinistral  Neogloboquadrina acostaensis (sinistral)
# 3092           sinistral          Pulleniatina finalis (sinistral)
# 3094           sinistral  Pulleniatina obliquiloculata (sinistral)
# 3096           sinistral       Pulleniatina praecursor (sinistral)
# 3098           sinistral  Pulleniatina praespectabilis (sinistral)
# 3100           sinistral         Pulleniatina primalis (sinistral)
# 3102           sinistral      Pulleniatina spectabilis (sinistral)
#
#                                verbatim_name
# 3090      Dextral:Sinistral _N. acostaensis_
# 3092          Dextral:Sinistral _P. finalis_
# 3094  Dextral:Sinistral _P. obliquiloculata_
# 3096       Dextral:Sinistral _P. praecursor_
# 3098  Dextral:Sinistral _P. praespectabilis_
# 3100         Dextral:Sinistral _P. primalis_
# 3102      Dextral:Sinistral _P. spectabilis_

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0    320_U1334_benthic_forams.csv
# 1     361_U1479B_nannofossils.csv
# 2  372_U1517C_planktic_forams.csv
# 3   317_U1352_planktic_forams.csv
# 4        323_U1339_palynology.csv
#
#                                                 path      taxon_group  \
# 0   LIMS/Micropal_CSV_4/320_U1334_benthic_forams.csv   benthic_forams
# 1    LIMS/Micropal_CSV_4/361_U1479B_nannofossils.csv     nannofossils
# 2  LIMS/Micropal_CSV_4/372_U1517C_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_4/317_U1352_planktic_forams.csv  planktic_forams
# 4       LIMS/Micropal_CSV_4/323_U1339_palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                  True                   True              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4           True                  False                     False
#
#    update_sample_col  update_top_bottom  add_missing_cols  \
# 0               True              False             False
# 1              False              False             False
# 2              False              False             False
# 3               True              False             False
# 4               True              False             False
#
#    add_expedition_section_cols  clean_up_taxa_values  \
# 0                        False                 False
# 1                         True                 False
# 2                         True                 False
# 3                        False                 False
# 4                        False                 False
#
#    clean_up_taxa_metadata_values
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False

# %%
def split_dextral_sinistral(file):
    path = f"{clean_data_path}/{file}"

    changed = False
    df_0 = pd.read_csv(path, dtype=str, nrows=0)
    
    file_target_taxa = set(df_0.columns).intersection(set(dex_sin_taxa.keys()))
    if len(file_target_taxa) > 0:
        changed = True
        df = pd.read_csv(path, dtype=str)
        for taxon in file_target_taxa:
            new_columns = dex_sin_taxa[taxon]
            split_columns = df[taxon].str.split(':', expand=True)
            if split_columns.shape[1] == 1:
                for col in new_columns:
                    df[col] = np.nan
            else:
                df[new_columns] = split_columns
            
            del df[taxon]

        df = csv_cleanup(df, path)
        df.to_csv(path, index=False)

    return changed 
            

change_columns = [split_dextral_sinistral(file) for file in metadata['path']]

# %%
dict = {"split_dextral_sinistral": change_columns}
new_metadata = update_metadata(metadata, dict)
new_metadata.head()
# Out:
#                              file  \
# 0    320_U1334_benthic_forams.csv
# 1     361_U1479B_nannofossils.csv
# 2  372_U1517C_planktic_forams.csv
# 3   317_U1352_planktic_forams.csv
# 4        323_U1339_palynology.csv
#
#                                                 path      taxon_group  \
# 0   LIMS/Micropal_CSV_4/320_U1334_benthic_forams.csv   benthic_forams
# 1    LIMS/Micropal_CSV_4/361_U1479B_nannofossils.csv     nannofossils
# 2  LIMS/Micropal_CSV_4/372_U1517C_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_4/317_U1352_planktic_forams.csv  planktic_forams
# 4       LIMS/Micropal_CSV_4/323_U1339_palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                  True                   True              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4           True                  False                     False
#
#    update_sample_col  update_top_bottom  add_missing_cols  \
# 0               True              False             False
# 1              False              False             False
# 2              False              False             False
# 3               True              False             False
# 4               True              False             False
#
#    add_expedition_section_cols  clean_up_taxa_values  \
# 0                        False                 False
# 1                         True                 False
# 2                         True                 False
# 3                        False                 False
# 4                        False                 False
#
#    clean_up_taxa_metadata_values  split_dextral_sinistral
# 0                          False                    False
# 1                          False                    False
# 2                          False                    False
# 3                          False                    False
# 4                          False                    False

# %%
new_metadata.to_csv(metadata_file, index=False)

# %% [markdown]
# ## clean up  additional species file
#  add path and normalized_name columns

# %%
metadata = pd.read_csv(metadata_file, dtype=str)
metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#   change_file_encoding remove_bad_characters remove_empty_rows remove_spaces  \
# 0                False                 False             False          True
# 1                False                 False             False          True
# 2                False                 False             False          True
# 3                False                 False             False          True
# 4                False                 False             False         False
#
#   delete_duplicate_rows delete_duplicate_columns add_expedition_section_cols  \
# 0                 False                    False                        True
# 1                 False                    False                       False
# 2                 False                    False                        True
# 3                 False                    False                       False
# 4                 False                    False                       False
#
#   update_sample_col update_top_bottom add_missing_cols clean_up_taxa_values  \
# 0             False             False            False                False
# 1              True             False            False                False
# 2             False             False            False                False
# 3              True             False            False                False
# 4              True             False            False                False
#
#   clean_up_taxa_metadata_values split_dextral_sinistral
# 0                          True                   False
# 1                         False                   False
# 2                         False                   False
# 3                         False                   False
# 4                         False                   False

# %%
df = pd.read_csv(additional_taxa_path, dtype=str)
log_df(df)
# Out:
# (30, 36)
#   sample_id                         file                      sample  \
# 0    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 1    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 2    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 3    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 4    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
#
#     taxon_group                                verbatim_name code  \
# 0  radiolarians                        Lonchosphaera spicata  NaN
# 1  radiolarians                            Poulpus spp.-like  NaN
# 2  radiolarians                      Lithostrobus cuspidatus  NaN
# 3  radiolarians                          Gondwanaria dogieli  NaN
# 4  radiolarians  Tetraplecta pinigera/Euscenium corynephorum  NaN
#
#                      Name Comment Notes (change to Internal only notes?)  \
# 0                     NaN     NaN                                    NaN
# 1            Poulpus spp.     NaN                                    NaN
# 2                     NaN     NaN                                    NaN
# 3                     NaN     NaN                                    NaN
# 4  Plagiacanthidae indet.     NaN                                    NaN
#
#     Any taxon above genus  ... order_taxon_id order_taxon_name class_taxon_id  \
# 0                     NaN  ...            NaN              NaN            NaN
# 1                     NaN  ...            NaN              NaN            NaN
# 2                     NaN  ...            NaN              NaN            NaN
# 3                     NaN  ...            NaN              NaN            NaN
# 4  Plagiacanthidae indet.  ...            NaN              NaN            NaN
#
#   class_taxon_name phylum_taxon_id phylum_taxon_name kingdom_taxon_id  \
# 0              NaN             NaN               NaN              NaN
# 1              NaN             NaN               NaN              NaN
# 2              NaN             NaN               NaN              NaN
# 3              NaN             NaN               NaN              NaN
# 4              NaN             NaN               NaN              NaN
#
#   kingdom_taxon_name unranked clade_taxon_id unranked clade_taxon_name
# 0                NaN                     NaN                       NaN
# 1                NaN                     NaN                       NaN
# 2                NaN                     NaN                       NaN
# 3                NaN                     NaN                       NaN
# 4                NaN                     NaN                       NaN
#
# [5 rows x 36 columns]

# %%
set(df['taxon_group'])
# Out:
# {'planktic_forams', 'radiolarians'}

# %%
for index, row in df.iterrows():
    path = metadata[metadata['file'] == row['file']]['path'].values[0]
    df.loc[df['file'] == row['file'], 'path'] = path
    
    nt.add_normalized_name_column(df)

log_df(df)
# Out:
# (30, 38)
#   sample_id                         file                      sample  \
# 0    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 1    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 2    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 3    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 4    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
#
#     taxon_group                                verbatim_name code  \
# 0  radiolarians                        Lonchosphaera spicata  NaN
# 1  radiolarians                            Poulpus spp.-like  NaN
# 2  radiolarians                      Lithostrobus cuspidatus  NaN
# 3  radiolarians                          Gondwanaria dogieli  NaN
# 4  radiolarians  Tetraplecta pinigera/Euscenium corynephorum  NaN
#
#                      Name Comment Notes (change to Internal only notes?)  \
# 0                     NaN     NaN                                    NaN
# 1            Poulpus spp.     NaN                                    NaN
# 2                     NaN     NaN                                    NaN
# 3                     NaN     NaN                                    NaN
# 4  Plagiacanthidae indet.     NaN                                    NaN
#
#     Any taxon above genus  ... class_taxon_id class_taxon_name  \
# 0                     NaN  ...            NaN              NaN
# 1                     NaN  ...            NaN              NaN
# 2                     NaN  ...            NaN              NaN
# 3                     NaN  ...            NaN              NaN
# 4  Plagiacanthidae indet.  ...            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
# 2             NaN               NaN              NaN                NaN
# 3             NaN               NaN              NaN                NaN
# 4             NaN               NaN              NaN                NaN
#
#   unranked clade_taxon_id unranked clade_taxon_name  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#                                               path          normalized_name
# 0  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv    Lonchosphaera spicata
# 1  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv             Poulpus spp.
# 2  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv  Lithostrobus cuspidatus
# 3  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv      Gondwanaria dogieli
# 4  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv   Plagiacanthidae indet.
#
# [5 rows x 38 columns]

# %%
df.to_csv(additional_taxa_path, index=False)

# %% [markdown]
# ## add additional species taxa to crosswalk taxa list

# %%
existing_crosswalk = pd.read_csv(crosswalk_file, dtype=str)
log_df(existing_crosswalk, 3)
# 5250
# Out:
# (5250, 17)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor      normalized_name     taxon_group  \
# 0             NaN                 NaN   Euuvigerina miozea  benthic_forams
# 1             NaN                 NaN  Euuvigerina rodleyi  benthic_forams
# 2             NaN                 NaN  Foraminifera indet.  benthic_forams
#
#                        verbatim_name name comment field     Comment  \
# 0  Euuvigerina miozea (group) >100 m                NaN       group
# 1  Euuvigerina rodleyi (group) >50 m                NaN       group
# 2                             Others                NaN  not a taxa
#
#               Notes (change to Internal only notes?)  \
# 0  Summer 2020: enter "Euuvigerina miozea" and re...
# 1  Summer 2020: enter "Euuvigerina miozea" and re...
# 2                                               Andy
#
#                      comments
# 0                >100 m group
# 1                 >50 m group
# 2  other benthic foraminifera

# %%
df = pd.read_csv(additional_taxa_path, dtype=str)
log_df(df)
# Out:
# (30, 38)
#   sample_id                         file                      sample  \
# 0    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 1    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 2    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 3    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 4    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
#
#     taxon_group                                verbatim_name code  \
# 0  radiolarians                        Lonchosphaera spicata  NaN
# 1  radiolarians                            Poulpus spp.-like  NaN
# 2  radiolarians                      Lithostrobus cuspidatus  NaN
# 3  radiolarians                          Gondwanaria dogieli  NaN
# 4  radiolarians  Tetraplecta pinigera/Euscenium corynephorum  NaN
#
#                      Name Comment Notes (change to Internal only notes?)  \
# 0                     NaN     NaN                                    NaN
# 1            Poulpus spp.     NaN                                    NaN
# 2                     NaN     NaN                                    NaN
# 3                     NaN     NaN                                    NaN
# 4  Plagiacanthidae indet.     NaN                                    NaN
#
#     Any taxon above genus  ... class_taxon_id class_taxon_name  \
# 0                     NaN  ...            NaN              NaN
# 1                     NaN  ...            NaN              NaN
# 2                     NaN  ...            NaN              NaN
# 3                     NaN  ...            NaN              NaN
# 4  Plagiacanthidae indet.  ...            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
# 2             NaN               NaN              NaN                NaN
# 3             NaN               NaN              NaN                NaN
# 4             NaN               NaN              NaN                NaN
#
#   unranked clade_taxon_id unranked clade_taxon_name  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#                                               path          normalized_name
# 0  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv    Lonchosphaera spicata
# 1  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv             Poulpus spp.
# 2  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv  Lithostrobus cuspidatus
# 3  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv      Gondwanaria dogieli
# 4  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv   Plagiacanthidae indet.
#
# [5 rows x 38 columns]

# %% [markdown]
# set verbatim_name to normalized_name since we are using normalized_name as the columns names

# %%
df['verbatim_name'] = df['normalized_name']

# %%
fields = nt.taxa_rank_fields + nt.taxa_fields + nt.metadata_fields 
fields
# Out:
# ['Any taxon above genus',
#  'genus modifier',
#  'genus name',
#  'subgenera modifier',
#  'subgenera name',
#  'species modifier',
#  'species name',
#  'subspecies modifier',
#  'subspecies name',
#  'non-taxa descriptor',
#  'normalized_name',
#  'taxon_group',
#  'verbatim_name',
#  'name comment field',
#  'Comment',
#  'Notes (change to Internal only notes?)',
#  'comments']

# %%
filtered_taxa = pd.DataFrame(df, columns=fields)
log_df(filtered_taxa, 2)
# Out:
# (30, 17)
#   Any taxon above genus genus modifier     genus name subgenera modifier  \
# 0                   NaN            NaN  Lonchosphaera                NaN
# 1                   NaN            NaN        Poulpus                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN      spicata                 NaN
# 1            NaN              NaN         spp.                 NaN
#
#   subspecies name non-taxa descriptor        normalized_name   taxon_group  \
# 0             NaN                 NaN  Lonchosphaera spicata  radiolarians
# 1             NaN                 NaN           Poulpus spp.  radiolarians
#
#            verbatim_name  name comment field Comment  \
# 0  Lonchosphaera spicata                 NaN     NaN
# 1           Poulpus spp.                 NaN     NaN
#
#   Notes (change to Internal only notes?)  comments
# 0                                    NaN       NaN
# 1                                    NaN       NaN

# %%
filtered_taxa = filtered_taxa.drop(filtered_taxa[filtered_taxa['normalized_name'] == ''].index)
log_df(filtered_taxa)

filtered_taxa.drop_duplicates(keep='first', inplace=True, subset =['verbatim_name', 'normalized_name'])
log_df(filtered_taxa)
# Out:
# (30, 17)
# (20, 17)
#     Any taxon above genus genus modifier     genus name subgenera modifier  \
# 0                     NaN            NaN  Lonchosphaera                NaN
# 1                     NaN            NaN        Poulpus                NaN
# 2                     NaN            NaN   Lithostrobus                NaN
# 3                     NaN            NaN    Gondwanaria                NaN
# 4  Plagiacanthidae indet.            NaN            NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN      spicata                 NaN
# 1            NaN              NaN         spp.                 NaN
# 2            NaN              NaN   cuspidatus                 NaN
# 3            NaN              NaN      dogieli                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor          normalized_name   taxon_group  \
# 0             NaN                 NaN    Lonchosphaera spicata  radiolarians
# 1             NaN                 NaN             Poulpus spp.  radiolarians
# 2             NaN                 NaN  Lithostrobus cuspidatus  radiolarians
# 3             NaN                 NaN      Gondwanaria dogieli  radiolarians
# 4             NaN                 NaN   Plagiacanthidae indet.  radiolarians
#
#              verbatim_name  name comment field Comment  \
# 0    Lonchosphaera spicata                 NaN     NaN
# 1             Poulpus spp.                 NaN     NaN
# 2  Lithostrobus cuspidatus                 NaN     NaN
# 3      Gondwanaria dogieli                 NaN     NaN
# 4   Plagiacanthidae indet.                 NaN     NaN
#
#   Notes (change to Internal only notes?)  comments
# 0                                    NaN       NaN
# 1                                    NaN       NaN
# 2                                    NaN       NaN
# 3                                    NaN       NaN
# 4                                    NaN       NaN

# %%
existing_crosswalk.columns == filtered_taxa.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
combine_df = pd.concat([existing_crosswalk, filtered_taxa])
remove_whitespace(combine_df)

combine_df.shape
# Out:
# (5270, 17)

# %%
combine_df.drop_duplicates(keep='first', inplace=True, subset =['verbatim_name', 'normalized_name'])
log_df(combine_df)
# 5264
# Out:
# (5264, 17)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                                           Euuvigerina
# 1                                           Euuvigerina
# 2       Foraminifera indet.
# 3  Pleurostomellidae indet.
# 4          Ostracoda indet.
#
#   subgenera name species modifier species name subspecies modifier  \
# 0                                       miozea
# 1                                      rodleyi
# 2
# 3
# 4
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 0                                            Euuvigerina miozea
# 1                                           Euuvigerina rodleyi
# 2                                           Foraminifera indet.
# 3                                      Pleurostomellidae indet.
# 4                                              Ostracoda indet.
#
#       taxon_group                      verbatim_name name comment field  \
# 0  benthic_forams  Euuvigerina miozea (group) >100 m
# 1  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 2  benthic_forams                             Others
# 3  benthic_forams           Pleurostomellids comment
# 4  benthic_forams                     Ostracoda spp.     Ostracoda spp.
#
#            Comment             Notes (change to Internal only notes?)  \
# 0            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 1            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 2       not a taxa                                               Andy
# 3       not a taxa                                               Andy
# 4  group abundance  Summer 2020: go in as Ostracoda indet, and the...
#
#                      comments
# 0                >100 m group
# 1                 >50 m group
# 2  other benthic foraminifera
# 3
# 4

# %%
comments_df = df[['additional species comments', 'verbatim_name']].copy()
comments_df.drop_duplicates(inplace=True)
log_df(comments_df)
# Out:
# (20, 2)
#                          additional species comments            verbatim_name
# 0  Taxa which are "Indeterminate due to data sour...    Lonchosphaera spicata
# 1  Taxa which are "Indeterminate due to data sour...             Poulpus spp.
# 2  Taxa which are "Indeterminate due to data sour...  Lithostrobus cuspidatus
# 3  Taxa which are "Indeterminate due to data sour...      Gondwanaria dogieli
# 4  Taxa which are "Indeterminate due to data sour...   Plagiacanthidae indet.

# %%
combine_df = combine_df.merge(comments_df, how='left')
log_df(combine_df)
# 5264
# Out:
# (5264, 18)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                                           Euuvigerina
# 1                                           Euuvigerina
# 2       Foraminifera indet.
# 3  Pleurostomellidae indet.
# 4          Ostracoda indet.
#
#   subgenera name species modifier species name subspecies modifier  \
# 0                                       miozea
# 1                                      rodleyi
# 2
# 3
# 4
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 0                                            Euuvigerina miozea
# 1                                           Euuvigerina rodleyi
# 2                                           Foraminifera indet.
# 3                                      Pleurostomellidae indet.
# 4                                              Ostracoda indet.
#
#       taxon_group                      verbatim_name name comment field  \
# 0  benthic_forams  Euuvigerina miozea (group) >100 m
# 1  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 2  benthic_forams                             Others
# 3  benthic_forams           Pleurostomellids comment
# 4  benthic_forams                     Ostracoda spp.     Ostracoda spp.
#
#            Comment             Notes (change to Internal only notes?)  \
# 0            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 1            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 2       not a taxa                                               Andy
# 3       not a taxa                                               Andy
# 4  group abundance  Summer 2020: go in as Ostracoda indet, and the...
#
#                      comments additional species comments
# 0                >100 m group                         NaN
# 1                 >50 m group                         NaN
# 2  other benthic foraminifera                         NaN
# 3                                                     NaN
# 4                                                     NaN

# %%
combine_df.to_csv(crosswalk_file, index=False)

# %% [markdown]
# ## add additional species taxa to taxa list

# %%
existing_taxa = pd.read_csv(taxa_list_file, dtype=str)
log_df(existing_taxa, 3)
# 4662
# Out:
# (4662, 25)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2             NaN               NaN           212476           Rhizaria
#
# [3 rows x 25 columns]

# %%
df = pd.read_csv(additional_taxa_path, dtype=str)
log_df(df)
# Out:
# (30, 38)
#   sample_id                         file                      sample  \
# 0    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 1    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 2    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 3    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 4    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
#
#     taxon_group                                verbatim_name code  \
# 0  radiolarians                        Lonchosphaera spicata  NaN
# 1  radiolarians                            Poulpus spp.-like  NaN
# 2  radiolarians                      Lithostrobus cuspidatus  NaN
# 3  radiolarians                          Gondwanaria dogieli  NaN
# 4  radiolarians  Tetraplecta pinigera/Euscenium corynephorum  NaN
#
#                      Name Comment Notes (change to Internal only notes?)  \
# 0                     NaN     NaN                                    NaN
# 1            Poulpus spp.     NaN                                    NaN
# 2                     NaN     NaN                                    NaN
# 3                     NaN     NaN                                    NaN
# 4  Plagiacanthidae indet.     NaN                                    NaN
#
#     Any taxon above genus  ... class_taxon_id class_taxon_name  \
# 0                     NaN  ...            NaN              NaN
# 1                     NaN  ...            NaN              NaN
# 2                     NaN  ...            NaN              NaN
# 3                     NaN  ...            NaN              NaN
# 4  Plagiacanthidae indet.  ...            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
# 2             NaN               NaN              NaN                NaN
# 3             NaN               NaN              NaN                NaN
# 4             NaN               NaN              NaN                NaN
#
#   unranked clade_taxon_id unranked clade_taxon_name  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#                                               path          normalized_name
# 0  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv    Lonchosphaera spicata
# 1  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv             Poulpus spp.
# 2  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv  Lithostrobus cuspidatus
# 3  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv      Gondwanaria dogieli
# 4  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv   Plagiacanthidae indet.
#
# [5 rows x 38 columns]

# %%
fields = nt.taxa_rank_fields  + nt.taxa_fields + nt.pdbd_fields
fields
# Out:
# ['Any taxon above genus',
#  'genus modifier',
#  'genus name',
#  'subgenera modifier',
#  'subgenera name',
#  'species modifier',
#  'species name',
#  'subspecies modifier',
#  'subspecies name',
#  'non-taxa descriptor',
#  'normalized_name',
#  'taxon_group',
#  'pbdb_taxon_id',
#  'pbdb_taxon_name',
#  'pbdb_taxon_rank',
#  'family_taxon_id',
#  'family_taxon_name',
#  'order_taxon_id',
#  'order_taxon_name',
#  'class_taxon_id',
#  'class_taxon_name',
#  'phylum_taxon_id',
#  'phylum_taxon_name',
#  'kingdom_taxon_id',
#  'kingdom_taxon_name']

# %%
filtered_taxa = pd.DataFrame(df, columns=fields)
log_df(filtered_taxa, 2)
# Out:
# (30, 25)
#   Any taxon above genus genus modifier     genus name subgenera modifier  \
# 0                   NaN            NaN  Lonchosphaera                NaN
# 1                   NaN            NaN        Poulpus                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN      spicata                 NaN
# 1            NaN              NaN         spp.                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
#
# [2 rows x 25 columns]

# %%
filtered_taxa = filtered_taxa.drop(filtered_taxa[filtered_taxa['normalized_name'] == ''].index)
log_df(filtered_taxa)

filtered_taxa.drop_duplicates(keep='first', inplace=True, subset =[ 'normalized_name', 'taxon_group'])
log_df(filtered_taxa)
# Out:
# (30, 25)
# (20, 25)
#     Any taxon above genus genus modifier     genus name subgenera modifier  \
# 0                     NaN            NaN  Lonchosphaera                NaN
# 1                     NaN            NaN        Poulpus                NaN
# 2                     NaN            NaN   Lithostrobus                NaN
# 3                     NaN            NaN    Gondwanaria                NaN
# 4  Plagiacanthidae indet.            NaN            NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN      spicata                 NaN
# 1            NaN              NaN         spp.                 NaN
# 2            NaN              NaN   cuspidatus                 NaN
# 3            NaN              NaN      dogieli                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...             NaN               NaN
# 3             NaN                 NaN  ...             NaN               NaN
# 4             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
# 2             NaN               NaN              NaN                NaN
# 3             NaN               NaN              NaN                NaN
# 4             NaN               NaN              NaN                NaN
#
# [5 rows x 25 columns]

# %%
existing_taxa.columns == filtered_taxa.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
combine_df = pd.concat([existing_taxa, filtered_taxa])
remove_whitespace(combine_df)
combine_df.shape

# 4682
# Out:
# (4682, 25)

# %%
combine_df.drop_duplicates(inplace=True, subset =[ 'normalized_name', 'taxon_group'] )
log_df(combine_df)
# 4676
# Out:
# (4676, 25)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                                           Euuvigerina
# 1                                           Euuvigerina
# 2       Foraminifera indet.
# 3  Pleurostomellidae indet.
# 4          Ostracoda indet.
#
#   subgenera name species modifier species name subspecies modifier  \
# 0                                       miozea
# 1                                      rodleyi
# 2
# 3
# 4
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0                                      ...
# 1                                      ...
# 2                                      ...
# 3                                      ...
# 4                                      ...
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0
# 1
# 2
# 3
# 4
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2                                             212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
# [5 rows x 25 columns]

# %%
combine_df.to_csv(taxa_list_file, index=False)

# %% [markdown]
# ## add additional species taxa to data files

# %%
df = pd.read_csv(additional_taxa_path, dtype=str)
log_df(df)
# Out:
# (30, 38)
#   sample_id                         file                      sample  \
# 0    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 1    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 2    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 3    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 4    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
#
#     taxon_group                                verbatim_name code  \
# 0  radiolarians                        Lonchosphaera spicata  NaN
# 1  radiolarians                            Poulpus spp.-like  NaN
# 2  radiolarians                      Lithostrobus cuspidatus  NaN
# 3  radiolarians                          Gondwanaria dogieli  NaN
# 4  radiolarians  Tetraplecta pinigera/Euscenium corynephorum  NaN
#
#                      Name Comment Notes (change to Internal only notes?)  \
# 0                     NaN     NaN                                    NaN
# 1            Poulpus spp.     NaN                                    NaN
# 2                     NaN     NaN                                    NaN
# 3                     NaN     NaN                                    NaN
# 4  Plagiacanthidae indet.     NaN                                    NaN
#
#     Any taxon above genus  ... class_taxon_id class_taxon_name  \
# 0                     NaN  ...            NaN              NaN
# 1                     NaN  ...            NaN              NaN
# 2                     NaN  ...            NaN              NaN
# 3                     NaN  ...            NaN              NaN
# 4  Plagiacanthidae indet.  ...            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
# 2             NaN               NaN              NaN                NaN
# 3             NaN               NaN              NaN                NaN
# 4             NaN               NaN              NaN                NaN
#
#   unranked clade_taxon_id unranked clade_taxon_name  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#                                               path          normalized_name
# 0  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv    Lonchosphaera spicata
# 1  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv             Poulpus spp.
# 2  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv  Lithostrobus cuspidatus
# 3  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv      Gondwanaria dogieli
# 4  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv   Plagiacanthidae indet.
#
# [5 rows x 38 columns]

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0    320_U1334_benthic_forams.csv
# 1     361_U1479B_nannofossils.csv
# 2  372_U1517C_planktic_forams.csv
# 3   317_U1352_planktic_forams.csv
# 4        323_U1339_palynology.csv
#
#                                                 path      taxon_group  \
# 0   LIMS/Micropal_CSV_4/320_U1334_benthic_forams.csv   benthic_forams
# 1    LIMS/Micropal_CSV_4/361_U1479B_nannofossils.csv     nannofossils
# 2  LIMS/Micropal_CSV_4/372_U1517C_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_4/317_U1352_planktic_forams.csv  planktic_forams
# 4       LIMS/Micropal_CSV_4/323_U1339_palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                  True                   True              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4           True                  False                     False
#
#    update_sample_col  update_top_bottom  add_missing_cols  \
# 0               True              False             False
# 1              False              False             False
# 2              False              False             False
# 3               True              False             False
# 4               True              False             False
#
#    add_expedition_section_cols  clean_up_taxa_values  \
# 0                        False                 False
# 1                         True                 False
# 2                         True                 False
# 3                        False                 False
# 4                        False                 False
#
#    clean_up_taxa_metadata_values  split_dextral_sinistral
# 0                          False                    False
# 1                          False                    False
# 2                          False                    False
# 3                          False                    False
# 4                          False                    False

# %%
for index, row in df.iterrows():
    tmp_df = metadata[metadata['file'] == row['file']]
    if len(tmp_df) > 0:
        path = tmp_df['path'].values[0]
        temp_df = pd.read_csv(clean_data_path/path, dtype=str)

        temp_df.loc[temp_df['Sample'] == row['sample'], row['normalized_name']] = 'Indeterminate due to data source'

        temp_df = csv_cleanup(temp_df, path)
        temp_df.to_csv(clean_data_path/path, index=False)

# %% [markdown]
# ## add eodp_id to taxa crosswalk

# %%
df = pd.read_csv(crosswalk_file, dtype=str)
log_df(df, 3)
# 5264
# Out:
# (5264, 18)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor      normalized_name     taxon_group  \
# 0             NaN                 NaN   Euuvigerina miozea  benthic_forams
# 1             NaN                 NaN  Euuvigerina rodleyi  benthic_forams
# 2             NaN                 NaN  Foraminifera indet.  benthic_forams
#
#                        verbatim_name name comment field     Comment  \
# 0  Euuvigerina miozea (group) >100 m                NaN       group
# 1  Euuvigerina rodleyi (group) >50 m                NaN       group
# 2                             Others                NaN  not a taxa
#
#               Notes (change to Internal only notes?)  \
# 0  Summer 2020: enter "Euuvigerina miozea" and re...
# 1  Summer 2020: enter "Euuvigerina miozea" and re...
# 2                                               Andy
#
#                      comments additional species comments
# 0                >100 m group                         NaN
# 1                 >50 m group                         NaN
# 2  other benthic foraminifera                         NaN

# %%
df['eodp_id'] = df.index
log_df(df, 3)
# Out:
# (5264, 19)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor      normalized_name     taxon_group  \
# 0             NaN                 NaN   Euuvigerina miozea  benthic_forams
# 1             NaN                 NaN  Euuvigerina rodleyi  benthic_forams
# 2             NaN                 NaN  Foraminifera indet.  benthic_forams
#
#                        verbatim_name name comment field     Comment  \
# 0  Euuvigerina miozea (group) >100 m                NaN       group
# 1  Euuvigerina rodleyi (group) >50 m                NaN       group
# 2                             Others                NaN  not a taxa
#
#               Notes (change to Internal only notes?)  \
# 0  Summer 2020: enter "Euuvigerina miozea" and re...
# 1  Summer 2020: enter "Euuvigerina miozea" and re...
# 2                                               Andy
#
#                      comments additional species comments  eodp_id
# 0                >100 m group                         NaN        0
# 1                 >50 m group                         NaN        1
# 2  other benthic foraminifera                         NaN        2

# %%
df.to_csv(crosswalk_file, index=False)
