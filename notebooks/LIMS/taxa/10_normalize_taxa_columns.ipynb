# %% [markdown]
# # Normalize LIMS taxa

# %%
import sys
sys.path.append('../../../')
import glob
import re
import os.path
import hashlib

import pandas as pd
import numpy as np

from config import CLEAN_DATA_DIR, OUTPUT_DIR

from scripts.normalize_data import (
    csv_cleanup,
    update_metadata,
    get_taxonomy_columns,
    clean_taxon_name,
    get_non_taxa_fields,
    delete_duplicate_colums_with_spaces
)

# %%
taxa_list_path = OUTPUT_DIR /'taxa'/'LIMS'/'PI_normalized_taxa_list_with_pbdb_2022-02-22.csv'
normalized_fields_path =  OUTPUT_DIR/'normalized_data'/'eODP_unified_data_structure_2022_02_21.csv'
metadata_file = OUTPUT_DIR/'metadata'/'LIMS'/'Micropal_changes.csv' 
clean_data_path = CLEAN_DATA_DIR

# %% [markdown]
# ## Clean up taxa values

# %% [markdown]
# Look for taxa columns that have "code [extra text]", and remove "[extra text]".

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path  change_file_encoding  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv                 False
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv                 False
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...                 False
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv                 False
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv                 False
#
#    remove_empty_rows  delete_duplicate_colums_with_spaces  \
# 0              False                                False
# 1              False                                False
# 2              False                                False
# 3              False                                False
# 4              False                                False
#
#    delete_duplicate_rows  delete_renamed_duplicate_columns  \
# 0                  False                             False
# 1                  False                             False
# 2                  False                             False
# 3                  False                             False
# 4                  False                             False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
taxa_df = pd.read_csv(taxa_list_path, dtype=str)
taxa_df.head()
# Out:
#       taxon_group                      verbatim_name  \
# 0  benthic_forams  Euuvigerina miozea (group) >100 m
# 1  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 2  benthic_forams                             Others
# 3  benthic_forams           Pleurostomellids comment
# 4  benthic_forams                     Ostracoda spp.
#
#                                 name name to use (if different from "name")  \
# 0  Euuvigerina miozea (group) >100 m                     Euuvigerina miozea
# 1  Euuvigerina rodleyi (group) >50 m                    Euuvigerina rodleyi
# 2                             Others                    Foraminifera indet.
# 3           Pleurostomellids comment                 Pleurostomellia indet.
# 4                     Ostracoda spp.                       Ostracoda indet.
#
#   name comment field          Comment  \
# 0                NaN            group
# 1                NaN            group
# 2                NaN       not a taxa
# 3                NaN       not a taxa
# 4     Ostracoda spp.  group abundance
#
#                                                notes  \
# 0  Summer 2020: enter "Euuvigerina miozea" and re...
# 1  Summer 2020: enter "Euuvigerina miozea" and re...
# 2                                               Andy
# 3                                               Andy
# 4  Summer 2020: go in as Ostracoda indet, and the...
#
#       Any taxon above genus genus modifier   genus name  ... order_taxon_id  \
# 0                       NaN            NaN  Euuvigerina  ...            NaN
# 1                       NaN            NaN  Euuvigerina  ...            NaN
# 2       Foraminifera indet.            NaN          NaN  ...            NaN
# 3  Pleurostomellidae indet.            NaN          NaN  ...            NaN
# 4          Ostracoda indet.            NaN          NaN  ...            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 2              NaN            NaN              NaN             NaN
# 3              NaN            NaN              NaN          288974
# 4              NaN            NaN              NaN           18891
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0      Foraminifera           212476           Rhizaria
# 1      Foraminifera           212476           Rhizaria
# 2               NaN           212476           Rhizaria
# 3      Foraminifera           212476           Rhizaria
# 4        Arthropoda           325038           Animalia
#
#   unranked clade_taxon_id unranked clade_taxon_name
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
# [5 rows x 34 columns]

# %%
taxa_list = set(taxa_df['verbatim_name'].unique())
len(taxa_list)
# Out:
# 4588

# %%
def clean_up_taxa_values(file):
    path = f"{clean_data_path}/{file}"
    content = pd.read_csv(path)
    
    taxa_cols = set(content.columns).intersection(taxa_list)
    filter_df = content[taxa_cols]
    content[list(taxa_cols)] = filter_df.replace(to_replace =' *\[.*\] *', value = '', regex = True) 
    
    # get rid of NAs in order to compare two dataframes   
    changed = not filter_df.fillna('').equals(content[taxa_cols].fillna(''))

    if changed:
        content = csv_cleanup(content, path)
        content.to_csv(path, index=False)

    return changed
    
change_columns = [clean_up_taxa_values(file) for file in metadata['path']]

# %% [markdown]
# ### Update metadata

# %%
dict = {"clean_up_taxa_values": change_columns}
new_metadata = update_metadata(metadata, dict)
new_metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path  change_file_encoding  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv                 False
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv                 False
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...                 False
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv                 False
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv                 False
#
#    remove_empty_rows  delete_duplicate_colums_with_spaces  \
# 0              False                                False
# 1              False                                False
# 2              False                                False
# 3              False                                False
# 4              False                                False
#
#    delete_duplicate_rows  delete_renamed_duplicate_columns  \
# 0                  False                             False
# 1                  False                             False
# 2                  False                             False
# 3                  False                             False
# 4                  False                             False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values
# 0             False                 False
# 1             False                  True
# 2             False                 False
# 3             False                  True
# 4             False                  True

# %%
new_metadata.to_csv(metadata_file, index=False)

# %% [markdown]
# ## Clean up non-taxa metadata values

# %% [markdown]
# Look for non-taxa metadata columns that have "code [extra text]", and remove "[extra text]".

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path  change_file_encoding  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv                 False
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv                 False
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...                 False
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv                 False
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv                 False
#
#    remove_empty_rows  delete_duplicate_colums_with_spaces  \
# 0              False                                False
# 1              False                                False
# 2              False                                False
# 3              False                                False
# 4              False                                False
#
#    delete_duplicate_rows  delete_renamed_duplicate_columns  \
# 0                  False                             False
# 1                  False                             False
# 2                  False                             False
# 3                  False                             False
# 4                  False                             False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                  True                          False
# 2             False                 False                          False
# 3             False                  True                          False
# 4             False                  True                          False
#
#    split_dextral_sinistral
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
cols = ['normalized', 'taxa_317-present']
non_taxa_df = pd.read_csv(normalized_fields_path, dtype=str, header=5, usecols=cols)
non_taxa_df.head()
# Out:
#    normalized  taxa_317-present
# 0      Sample  Label ID; Sample
# 1  Expedition               Exp
# 2        Site              Site
# 3        Hole              Hole
# 4        Core              Core

# %%
non_taxa_dict = get_non_taxa_fields(non_taxa_df, 'taxa_317-present')
non_taxa_list = set(non_taxa_dict.keys())

# %%
non_taxa_list
# Out:
# {'% Planktic Foraminifera within whole sample',
#  'A/W',
#  'Abundance',
#  'Additional zone name',
#  'Additional zone name (short)',
#  'Age',
#  'Aspect comment (etching)',
#  'BF Group abundance',
#  'BF Preservation',
#  'BF comment',
#  'BF preservation',
#  'Bottom Depth [m]',
#  'Bottom Depth[m] [m]',
#  'Bottom [cm]',
#  'Bottom depth [m]',
#  'Bottom offset [cm]',
#  'Bottom[cm] [cm]',
#  'COMMENTS',
#  'Comment',
#  'Comment (general)',
#  'Comments',
#  'Core',
#  'Datum age average [Ma]',
#  'Datum age maximum (Ma)',
#  'Datum age minimum (Ma)',
#  'Datum author year',
#  'Datum name',
#  'Datum name generic',
#  'Datum region',
#  'Datum type',
#  'Diatom abundance',
#  'Diatom preservation dissolution',
#  'Diatom preservation fragmentation',
#  'Diatoms group abundance',
#  'Exp',
#  'Extra Sample ID Data',
#  'Foram abundance',
#  'General comment',
#  'Genus/species (upper zone)',
#  'Genus/species lower zone)',
#  'Group Abundance',
#  'Group abundance',
#  'Group abundance (%)',
#  'Group preservation',
#  'Hole',
#  'Label ID',
#  'Large Benthic Forams [%]',
#  'Lower boundary age av. [Ma]',
#  'Mixing',
#  'Nannofossil comment',
#  'No. specimens/tray',
#  'Organic matter',
#  'PALEO WATER DEPTH (IS=inner shelf, MS=middle shelf, OS=outer shelf)',
#  'PF Group Abundance',
#  'PF Preservation',
#  'PF Zone',
#  'PF group abundance',
#  'PF preservation',
#  'Percentage of benthic forams in total foram assemblage [%]',
#  'Percentage of non-calcareous agglutinated forams in total foram assemblage [%]',
#  'Percentage of planktic forams in total foram assemblage [%]',
#  'Planktonic Benthic ratio (P:B)',
#  'Pyrite',
#  'Reworking comment (1= <1%, 2= light 1-10%, 3= >10%)',
#  'Reworking comment (1= <1%, 2=light 1-10%, 3= >10%)',
#  'Sample',
#  'Sample comment',
#  'Sample preparation comment',
#  'Section',
#  'Silicoflagellates group abundance',
#  'Sillicoflagellate abundance',
#  'Site',
#  'Temperature Range',
#  'Terrestrial organic matter',
#  'Top Depth [m]',
#  'Top Depth[m] [m]',
#  'Top [cm]',
#  'Top depth [m]',
#  'Top offset [cm]',
#  'Top[cm] [cm]',
#  'Total in situ dinocysts',
#  'Type',
#  'Type (lower zone)',
#  'Type (upper zone)',
#  'Upper boundary age av. [Ma]',
#  'Upper boundary age min [Ma]',
#  'XBroken',
#  'XCorroded',
#  'XCrumpled',
#  'Zone author (year)',
#  'Zone comment',
#  'Zone name',
#  'Zone name (short)',
#  'comments',
#  'count',
#  'count_type'}

# %%
def clean_up_taxa_meta_values(file):
    path = f"{clean_data_path}/{file}"
    content = pd.read_csv(path)
    
    nontaxa_cols = set(content.columns).intersection(non_taxa_list)
    filter_df = content[nontaxa_cols]
    content[list(nontaxa_cols)] = filter_df.replace(to_replace =' *\[.*\] *', value = '', regex = True) 
    
    # get rid of NAs in order to compare two dataframes   
    changed = not filter_df.fillna('').equals(content[nontaxa_cols].fillna(''))

    if changed:
        content = csv_cleanup(content, path)
        content.to_csv(path, index=False)

    return changed
    
change_columns = [clean_up_taxa_meta_values(file) for file in metadata['path']]

# %% [markdown]
# ### Update metadata

# %%
dict = {"clean_up_taxa_metadata_values": change_columns}
new_metadata = update_metadata(metadata, dict)
new_metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path  change_file_encoding  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv                 False
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv                 False
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...                 False
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv                 False
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv                 False
#
#    remove_empty_rows  delete_duplicate_colums_with_spaces  \
# 0              False                                False
# 1              False                                False
# 2              False                                False
# 3              False                                False
# 4              False                                False
#
#    delete_duplicate_rows  delete_renamed_duplicate_columns  \
# 0                  False                             False
# 1                  False                             False
# 2                  False                             False
# 3                  False                             False
# 4                  False                             False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values
# 0             False                 False                           True
# 1             False                  True                          False
# 2             False                 False                          False
# 3             False                  True                          False
# 4             False                  True                          False

# %%
new_metadata.to_csv(metadata_file, index=False)

# %% [markdown]
# ## Add eodp_id

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path  change_file_encoding  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv                 False
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv                 False
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...                 False
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv                 False
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv                 False
#
#    remove_empty_rows  delete_duplicate_colums_with_spaces  \
# 0              False                                False
# 1              False                                False
# 2              False                                False
# 3              False                                False
# 4              False                                False
#
#    delete_duplicate_rows  delete_renamed_duplicate_columns  \
# 0                  False                             False
# 1                  False                             False
# 2                  False                             False
# 3                  False                             False
# 4                  False                             False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values
# 0             False                 False                           True
# 1             False                  True                          False
# 2             False                 False                          False
# 3             False                  True                          False
# 4             False                  True                          False

# %%
def add_eodp_id(file):
    path = f"{clean_data_path}/{file}"
    content = pd.read_csv(path, dtype=str)
    content.dropna(how='all', axis='rows', inplace=True)
    
    def add_hash_id(id):
        return hashlib.md5(f'{file}{id}'.encode()).hexdigest()
            
    content['eodp_id'] = content.index 
    content['eodp_id'] = content['eodp_id'].apply(add_hash_id)
    
    
    content.to_csv(path, index=False)

res = [add_eodp_id(file) for file in metadata['path']]

# %% [markdown]
# ## split Dextral:Sinistral taxa
#
# split  Dextral:Sinistral column into two columns.

# %%
target_taxa = {
    "Dextral:Sinistral _N. acostaensis_": ['Neogloboquadrina acostaensis (dextral)', 'Neogloboquadrina acostaensis (sinistral)'],
    "Dextral:Sinistral _P. finalis_": ['Pulleniatina finalis (dextral)', 'Pulleniatina finalis (sinistral)'],
    "Dextral:Sinistral _P. obliquiloculata_": ['Pulleniatina obliquiloculata (dextral)', 'Pulleniatina obliquiloculata (sinistral)'],
    "Dextral:Sinistral _P. praecursor_": ['Pulleniatina praecursor (dextral)', 'Pulleniatina praecursor (sinistral)'],
    "Dextral:Sinistral _P. praespectabilis_": ['Pulleniatina praespectabilis (dextral)', 'Pulleniatina praespectabilis (sinistral)'],
    "Dextral:Sinistral _P. primalis_": ['Pulleniatina primalis (dextral)', 'Pulleniatina primalis (sinistral)'],
    "Dextral:Sinistral _P. spectabilis_": ['Pulleniatina spectabilis (dextral)', 'Pulleniatina spectabilis (sinistral)']
}

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path  change_file_encoding  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv                 False
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv                 False
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...                 False
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv                 False
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv                 False
#
#    remove_empty_rows  delete_duplicate_colums_with_spaces  \
# 0              False                                False
# 1              False                                False
# 2              False                                False
# 3              False                                False
# 4              False                                False
#
#    delete_duplicate_rows  delete_renamed_duplicate_columns  \
# 0                  False                             False
# 1                  False                             False
# 2                  False                             False
# 3                  False                             False
# 4                  False                             False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values
# 0             False                 False                           True
# 1             False                  True                          False
# 2             False                 False                          False
# 3             False                  True                          False
# 4             False                  True                          False

# %%
def split_dextral_sinistral(file):
    path = f"{clean_data_path}/{file}"

    changed = False
    df_0 = pd.read_csv(path, dtype=str, nrows=0)
    
    file_target_taxa = set(df_0.columns).intersection(set(target_taxa.keys()))
    if len(file_target_taxa) > 0:
        changed = True
        df = pd.read_csv(path, dtype=str)
        for taxon in file_target_taxa:
            new_columns = target_taxa[taxon]
            split_columns = df[taxon].str.split(':', expand=True)
            if split_columns.shape[1] == 1:
                for col in new_columns:
                    df[col] = np.nan
            else:
                df[new_columns] = split_columns
            
            del df[taxon]

        df = csv_cleanup(df, path)
        df.to_csv(path, index=False)

    return changed 
            

change_columns = [split_dextral_sinistral(file) for file in metadata['path']]

# %%
dict = {"split_dextral_sinistral": change_columns}
new_metadata = update_metadata(metadata, dict)
new_metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path  change_file_encoding  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv                 False
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv                 False
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...                 False
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv                 False
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv                 False
#
#    remove_empty_rows  delete_duplicate_colums_with_spaces  \
# 0              False                                False
# 1              False                                False
# 2              False                                False
# 3              False                                False
# 4              False                                False
#
#    delete_duplicate_rows  delete_renamed_duplicate_columns  \
# 0                  False                             False
# 1                  False                             False
# 2                  False                             False
# 3                  False                             False
# 4                  False                             False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                  True                          False
# 2             False                 False                          False
# 3             False                  True                          False
# 4             False                  True                          False
#
#    split_dextral_sinistral
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
new_metadata.to_csv(metadata_file, index=False)
