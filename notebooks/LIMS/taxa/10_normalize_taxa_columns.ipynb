# %% [markdown]
# # Normalize LIMS taxa

# %%
import sys
sys.path.append('../../../')
import glob
import re
import os.path
import hashlib
from pathlib import Path

import pandas as pd
import numpy as np

from config import CLEAN_DATA_DIR, OUTPUT_DIR, RAW_DATA_DIR

from scripts.normalize_data import (
    csv_cleanup,
    update_metadata,
    get_taxonomy_columns,
    clean_taxon_name,
    get_non_taxa_fields,
    remove_whitespace
)
import scripts.normalize_taxa as nt

# %%
metadata_file = OUTPUT_DIR/'metadata'/'LIMS'/'Micropal_changes.csv' 
# metadata_file = OUTPUT_DIR/'metadata'/'LIMS'/'Micropal_changes_4.csv'

normalized_fields_path =  OUTPUT_DIR/'normalized_data'/f'eODP_unified_data_structure_2022_02_21.csv'


clean_data_path = CLEAN_DATA_DIR

PI_additional_taxa_path = RAW_DATA_DIR/'PI_processed_files'/'LIMS_Micropal_CSV_4_taxa_ADDTL_TAXA.csv'
additional_taxa_path = OUTPUT_DIR/'taxa'/'LIMS'/'addtional_species.csv'


date = '2022-08-08'

crosswalk_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_crosswalk_{date}.csv"
taxa_list_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_list_{date}.csv"
PI_file = RAW_DATA_DIR/'PI_processed_files'/f'LIMS_Micropal_headers_PBDB_Taxonomy_notes_taxa_list_{date}.csv'

date='2021-11-29'
noaa_crosswalk_file = OUTPUT_DIR/'taxa'/'NOAA'/f"taxa_crosswalk_{date}.csv"
noaa_taxa_list_file = OUTPUT_DIR/'taxa'/'NOAA'/f"taxa_list_{date}.csv"

# %%
def log_df(df, row_count=5):
    print(df.shape)
    return df.head(row_count)

# %% [markdown]
# ## Clean up taxa values in data files
# Look for taxa columns that have "code [extra text]", and remove "[extra text]".

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
taxa_df = pd.read_csv(crosswalk_file, dtype=str)
taxa_df.head()
# Out:
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 0             NaN                 NaN        Euuvigerina miozea
# 1             NaN                 NaN       Euuvigerina rodleyi
# 2             NaN                 NaN       Foraminifera indet.
# 3             NaN                 NaN  Pleurostomellidae indet.
# 4             NaN                 NaN          Ostracoda indet.
#
#       taxon_group                      verbatim_name name comment field  \
# 0  benthic_forams  Euuvigerina miozea (group) >100 m                NaN
# 1  benthic_forams  Euuvigerina rodleyi (group) >50 m                NaN
# 2  benthic_forams                             Others                NaN
# 3  benthic_forams           Pleurostomellids comment                NaN
# 4  benthic_forams                     Ostracoda spp.     Ostracoda spp.
#
#            Comment             Notes (change to Internal only notes?)  \
# 0            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 1            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 2       not a taxa                                               Andy
# 3       not a taxa                                               Andy
# 4  group abundance  Summer 2020: go in as Ostracoda indet, and the...
#
#                      comments
# 0                >100 m group
# 1                 >50 m group
# 2  other benthic foraminifera
# 3                         NaN
# 4                         NaN

# %%
taxa_list = set(taxa_df['verbatim_name'].unique())
len(taxa_list)
# Out:
# 4587

# %%
def clean_up_taxa_values(file):
    path = f"{clean_data_path}/{file}"
    content = pd.read_csv(path)
    
    taxa_cols = list(set(content.columns).intersection(taxa_list))
    filter_df = content[taxa_cols]
    content[list(taxa_cols)] = filter_df.replace(to_replace =' *\[.*\] *', value = '', regex = True) 
    
    # get rid of NAs in order to compare two dataframes   
    changed = not filter_df.fillna('').equals(content[taxa_cols].fillna(''))

    if changed:
        content = csv_cleanup(content, path)
        content.to_csv(path, index=False)

    return changed
    
change_columns = [clean_up_taxa_values(file) for file in metadata['path']]

# %% [markdown]
# ### Update metadata

# %%
dict = {"clean_up_taxa_values": change_columns}
new_metadata = update_metadata(metadata, dict)
new_metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
new_metadata.to_csv(metadata_file, index=False)

# %% [markdown]
# ## Clean up non-taxa metadata values in data files
# Look for non-taxa metadata columns that have "code [extra text]", and remove "[extra text]".

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
cols = ['normalized', 'taxa_317-present']
non_taxa_df = pd.read_csv(normalized_fields_path, dtype=str, header=5, usecols=cols)
non_taxa_df.head()
# Out:
#    normalized  taxa_317-present
# 0      Sample  Label ID; Sample
# 1  Expedition               Exp
# 2        Site              Site
# 3        Hole              Hole
# 4        Core              Core

# %%
non_taxa_dict = get_non_taxa_fields(non_taxa_df, 'taxa_317-present')
non_taxa_list = set(non_taxa_dict.keys())

# %%
non_taxa_list
# Out:
# {'% Planktic Foraminifera within whole sample',
#  'A/W',
#  'Abundance',
#  'Additional zone name',
#  'Additional zone name (short)',
#  'Age',
#  'Aspect comment (etching)',
#  'BF Group abundance',
#  'BF Preservation',
#  'BF comment',
#  'BF preservation',
#  'Bottom Depth [m]',
#  'Bottom Depth[m] [m]',
#  'Bottom [cm]',
#  'Bottom depth [m]',
#  'Bottom offset [cm]',
#  'Bottom[cm] [cm]',
#  'COMMENTS',
#  'Comment',
#  'Comment (general)',
#  'Comments',
#  'Core',
#  'Datum age average [Ma]',
#  'Datum age maximum (Ma)',
#  'Datum age minimum (Ma)',
#  'Datum author year',
#  'Datum name',
#  'Datum name generic',
#  'Datum region',
#  'Datum type',
#  'Diatom abundance',
#  'Diatom preservation dissolution',
#  'Diatom preservation fragmentation',
#  'Diatoms group abundance',
#  'Exp',
#  'Extra Sample ID Data',
#  'Foram abundance',
#  'General comment',
#  'Genus/species (upper zone)',
#  'Genus/species lower zone)',
#  'Group Abundance',
#  'Group abundance',
#  'Group abundance (%)',
#  'Group preservation',
#  'Hole',
#  'Label ID',
#  'Large Benthic Forams [%]',
#  'Lower boundary age av. [Ma]',
#  'Mixing',
#  'Nannofossil comment',
#  'No. specimens/tray',
#  'Organic matter',
#  'PALEO WATER DEPTH (IS=inner shelf, MS=middle shelf, OS=outer shelf)',
#  'PF Group Abundance',
#  'PF Preservation',
#  'PF Zone',
#  'PF group abundance',
#  'PF preservation',
#  'Percentage of benthic forams in total foram assemblage [%]',
#  'Percentage of non-calcareous agglutinated forams in total foram assemblage [%]',
#  'Percentage of planktic forams in total foram assemblage [%]',
#  'Planktonic Benthic ratio (P:B)',
#  'Pyrite',
#  'Reworking comment (1= <1%, 2= light 1-10%, 3= >10%)',
#  'Reworking comment (1= <1%, 2=light 1-10%, 3= >10%)',
#  'Sample',
#  'Sample comment',
#  'Sample preparation comment',
#  'Section',
#  'Silicoflagellates group abundance',
#  'Sillicoflagellate abundance',
#  'Site',
#  'Temperature Range',
#  'Terrestrial organic matter',
#  'Top Depth [m]',
#  'Top Depth[m] [m]',
#  'Top [cm]',
#  'Top depth [m]',
#  'Top offset [cm]',
#  'Top[cm] [cm]',
#  'Total in situ dinocysts',
#  'Type',
#  'Type (lower zone)',
#  'Type (upper zone)',
#  'Upper boundary age av. [Ma]',
#  'Upper boundary age min [Ma]',
#  'XBroken',
#  'XCorroded',
#  'XCrumpled',
#  'Zone author (year)',
#  'Zone comment',
#  'Zone name',
#  'Zone name (short)',
#  'comments',
#  'count',
#  'count_type'}

# %%
def clean_up_taxa_meta_values(file):
    path = f"{clean_data_path}/{file}"
    content = pd.read_csv(path)
    
    nontaxa_cols = list(set(content.columns).intersection(non_taxa_list))
    filter_df = content[nontaxa_cols]
    content[list(nontaxa_cols)] = filter_df.replace(to_replace =' *\[.*\] *', value = '', regex = True) 
    
    # get rid of NAs in order to compare two dataframes   
    changed = not filter_df.fillna('').equals(content[nontaxa_cols].fillna(''))

    if changed:
        content = csv_cleanup(content, path)
        content.to_csv(path, index=False)

    return changed
    
change_columns = [clean_up_taxa_meta_values(file) for file in metadata['path']]

# %% [markdown]
# ### Update metadata

# %%
dict = {"clean_up_taxa_metadata_values": change_columns}
new_metadata = update_metadata(metadata, dict)
new_metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
new_metadata.to_csv(metadata_file, index=False)

# %% [markdown]
# ## Add eodp_id to data files
# add hash eodp_id to each row in data files

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
def add_eodp_id(file):
    path = f"{clean_data_path}/{file}"
    content = pd.read_csv(path, dtype=str)
    content.dropna(how='all', axis='rows', inplace=True)
    
    def add_hash_id(id):
        return hashlib.md5(f'{file}{id}'.encode()).hexdigest()
            
    content['eodp_id'] = content.index 
    content['eodp_id'] = content['eodp_id'].apply(add_hash_id)
    
    content = csv_cleanup(content, path)
    content.to_csv(path, index=False)

res = [add_eodp_id(file) for file in metadata['path']]

# %% [markdown]
# ## split Dextral:Sinistral taxa in data files
#
# split  Dextral:Sinistral column into two columns.

# %%
dex_sin_files = [
'363-U1482A-planktic_forams.csv',
 '363-U1482B-planktic_forams.csv',
 '363-U1482C-planktic_forams.csv',
 '363-U1483A-planktic_forams.csv',
 '363-U1483C-planktic_forams.csv',
 '363-U1484A-planktic_forams.csv',
 '363-U1485A-planktic_forams.csv',
 '363-U1486B-planktic_forams.csv',
 '363-U1487A-planktic_forams.csv',
 '363-U1488A-planktic_forams.csv',
 '363-U1489B-planktic_forams.csv',
 '363-U1489C-planktic_forams.csv',
 '363-U1489D-planktic_forams.csv',
 '363-U1490A-planktic_forams.csv'
]
len(dex_sin_files)
# Out:
# 14

# %%
cols = ['normalized_name', 'verbatim_name', 'name comment field']
taxa_df = pd.read_csv(crosswalk_file, dtype=str, usecols=cols)
taxa_df = taxa_df[taxa_df['name comment field'] == 'this will be two output fields']

taxa_df
# Out:
#                                normalized_name                 verbatim_name  \
# 3092    Neogloboquadrina acostaensis (dextral)        Dextral N. acostaensis
# 3093  Neogloboquadrina acostaensis (sinistral)      Sinistral N. acostaensis
# 3094            Pulleniatina finalis (dextral)            Dextral P. finalis
# 3095          Pulleniatina finalis (sinistral)          Sinistral P. finalis
# 3096    Pulleniatina obliquiloculata (dextral)    Dextral P. obliquiloculata
# 3097  Pulleniatina obliquiloculata (sinistral)  Sinistral P. obliquiloculata
# 3098         Pulleniatina praecursor (dextral)         Dextral P. praecursor
# 3099       Pulleniatina praecursor (sinistral)       Sinistral P. praecursor
# 3100    Pulleniatina praespectabilis (dextral)    Dextral P. praespectabilis
# 3101  Pulleniatina praespectabilis (sinistral)  Sinistral P. praespectabilis
# 3102           Pulleniatina primalis (dextral)           Dextral P. primalis
# 3103         Pulleniatina primalis (sinistral)         Sinistral P. primalis
# 3104        Pulleniatina spectabilis (dextral)        Dextral P. spectabilis
# 3105      Pulleniatina spectabilis (sinistral)      Sinistral P. spectabilis
#
#                   name comment field
# 3092  this will be two output fields
# 3093  this will be two output fields
# 3094  this will be two output fields
# 3095  this will be two output fields
# 3096  this will be two output fields
# 3097  this will be two output fields
# 3098  this will be two output fields
# 3099  this will be two output fields
# 3100  this will be two output fields
# 3101  this will be two output fields
# 3102  this will be two output fields
# 3103  this will be two output fields
# 3104  this will be two output fields
# 3105  this will be two output fields

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
def split_dextral_sinistral(file):
    path = Path(clean_data_path/file)
    if path.name not in dex_sin_files:
        return
    
    changed = False
    df_0 = pd.read_csv(path, dtype=str, nrows=0)
    
    file_target_taxa = set(df_0.columns).intersection(set(nt.dex_sin_conversion_2.keys()))
    if len(file_target_taxa) > 0:
        changed = True
        df = pd.read_csv(path, dtype=str)
        for taxon in file_target_taxa:
            new_columns = nt.dex_sin_conversion_2[taxon]
            split_columns = df[taxon].str.split(':', expand=True)
            if split_columns.shape[1] == 1:
                for col in new_columns:
                    df[col] = np.nan
            else:
                df[new_columns] = split_columns
            
        df = csv_cleanup(df, path)
        df.to_csv(path, index=False)

    return changed 
            

change_columns = [split_dextral_sinistral(file) for file in metadata['path']]

# %%
dict = {"split_dextral_sinistral": change_columns}
new_metadata = update_metadata(metadata, dict)
new_metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
new_metadata.to_csv(metadata_file, index=False)

# %% [markdown]
# ## clean up  additional species file
#  add path and normalized_name columns

# %%
metadata = pd.read_csv(metadata_file, dtype=str)
metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#   change_file_encoding remove_bad_characters remove_empty_rows remove_spaces  \
# 0                False                 False             False          True
# 1                False                 False             False          True
# 2                False                 False             False          True
# 3                False                 False             False          True
# 4                False                 False             False         False
#
#   delete_duplicate_rows delete_duplicate_columns add_expedition_section_cols  \
# 0                 False                    False                        True
# 1                 False                    False                       False
# 2                 False                    False                        True
# 3                 False                    False                       False
# 4                 False                    False                       False
#
#   update_sample_col update_top_bottom add_missing_cols clean_up_taxa_values  \
# 0             False             False            False                False
# 1              True             False            False                False
# 2             False             False            False                False
# 3              True             False            False                False
# 4              True             False            False                False
#
#   clean_up_taxa_metadata_values split_dextral_sinistral
# 0                          True                   False
# 1                         False                   False
# 2                         False                   False
# 3                         False                   False
# 4                         False                   False

# %%
df = pd.read_csv(PI_additional_taxa_path, dtype=str)
log_df(df)
# Out:
# (30, 36)
#   sample_id                         file                      sample  \
# 0    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 1    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 2    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 3    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 4    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
#
#     taxon_group                                verbatim_name code  \
# 0  radiolarians                        Lonchosphaera spicata  NaN
# 1  radiolarians                            Poulpus spp.-like  NaN
# 2  radiolarians                      Lithostrobus cuspidatus  NaN
# 3  radiolarians                          Gondwanaria dogieli  NaN
# 4  radiolarians  Tetraplecta pinigera/Euscenium corynephorum  NaN
#
#                      Name Comment Notes (change to Internal only notes?)  \
# 0                     NaN     NaN                                    NaN
# 1            Poulpus spp.     NaN                                    NaN
# 2                     NaN     NaN                                    NaN
# 3                     NaN     NaN                                    NaN
# 4  Plagiacanthidae indet.     NaN                                    NaN
#
#     Any taxon above genus  ... order_taxon_id order_taxon_name class_taxon_id  \
# 0                     NaN  ...            NaN              NaN            NaN
# 1                     NaN  ...            NaN              NaN            NaN
# 2                     NaN  ...            NaN              NaN            NaN
# 3                     NaN  ...            NaN              NaN            NaN
# 4  Plagiacanthidae indet.  ...            NaN              NaN            NaN
#
#   class_taxon_name phylum_taxon_id phylum_taxon_name kingdom_taxon_id  \
# 0              NaN             NaN               NaN              NaN
# 1              NaN             NaN               NaN              NaN
# 2              NaN             NaN               NaN              NaN
# 3              NaN             NaN               NaN              NaN
# 4              NaN             NaN               NaN              NaN
#
#   kingdom_taxon_name unranked clade_taxon_id unranked clade_taxon_name
# 0                NaN                     NaN                       NaN
# 1                NaN                     NaN                       NaN
# 2                NaN                     NaN                       NaN
# 3                NaN                     NaN                       NaN
# 4                NaN                     NaN                       NaN
#
# [5 rows x 36 columns]

# %%
set(df['taxon_group'])
# Out:
# {'planktic_forams', 'radiolarians'}

# %%
nt.add_normalized_name_column(df)

df['verbatim_name'] = 'additional species: ' + df['verbatim_name']

# %%
for index, row in df.iterrows():
    path = metadata[metadata['file'] == row['file']]['path'].values[0]
    df.loc[df['file'] == row['file'], 'path'] = path
        
log_df(df)
# Out:
# (30, 38)
#   sample_id                         file                      sample  \
# 0    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 1    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 2    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 3    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 4    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
#
#     taxon_group                                      verbatim_name code  \
# 0  radiolarians          additional species: Lonchosphaera spicata  NaN
# 1  radiolarians              additional species: Poulpus spp.-like  NaN
# 2  radiolarians        additional species: Lithostrobus cuspidatus  NaN
# 3  radiolarians            additional species: Gondwanaria dogieli  NaN
# 4  radiolarians  additional species: Tetraplecta pinigera/Eusce...  NaN
#
#                      Name Comment Notes (change to Internal only notes?)  \
# 0                     NaN     NaN                                    NaN
# 1            Poulpus spp.     NaN                                    NaN
# 2                     NaN     NaN                                    NaN
# 3                     NaN     NaN                                    NaN
# 4  Plagiacanthidae indet.     NaN                                    NaN
#
#     Any taxon above genus  ... class_taxon_id class_taxon_name  \
# 0                     NaN  ...            NaN              NaN
# 1                     NaN  ...            NaN              NaN
# 2                     NaN  ...            NaN              NaN
# 3                     NaN  ...            NaN              NaN
# 4  Plagiacanthidae indet.  ...            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
# 2             NaN               NaN              NaN                NaN
# 3             NaN               NaN              NaN                NaN
# 4             NaN               NaN              NaN                NaN
#
#   unranked clade_taxon_id unranked clade_taxon_name          normalized_name  \
# 0                     NaN                       NaN    Lonchosphaera spicata
# 1                     NaN                       NaN             Poulpus spp.
# 2                     NaN                       NaN  Lithostrobus cuspidatus
# 3                     NaN                       NaN      Gondwanaria dogieli
# 4                     NaN                       NaN   Plagiacanthidae indet.
#
#                                               path
# 0  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 1  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 2  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 3  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 4  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
#
# [5 rows x 38 columns]

# %%
df.to_csv(additional_taxa_path, index=False)

# %% [markdown]
# ## add additional species taxa to data files

# %%
df = pd.read_csv(additional_taxa_path, dtype=str)
log_df(df)
# Out:
# (30, 38)
#   sample_id                         file                      sample  \
# 0    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 1    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 2    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 3    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 4    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
#
#     taxon_group                                      verbatim_name code  \
# 0  radiolarians          additional species: Lonchosphaera spicata  NaN
# 1  radiolarians              additional species: Poulpus spp.-like  NaN
# 2  radiolarians        additional species: Lithostrobus cuspidatus  NaN
# 3  radiolarians            additional species: Gondwanaria dogieli  NaN
# 4  radiolarians  additional species: Tetraplecta pinigera/Eusce...  NaN
#
#                      Name Comment Notes (change to Internal only notes?)  \
# 0                     NaN     NaN                                    NaN
# 1            Poulpus spp.     NaN                                    NaN
# 2                     NaN     NaN                                    NaN
# 3                     NaN     NaN                                    NaN
# 4  Plagiacanthidae indet.     NaN                                    NaN
#
#     Any taxon above genus  ... class_taxon_id class_taxon_name  \
# 0                     NaN  ...            NaN              NaN
# 1                     NaN  ...            NaN              NaN
# 2                     NaN  ...            NaN              NaN
# 3                     NaN  ...            NaN              NaN
# 4  Plagiacanthidae indet.  ...            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
# 2             NaN               NaN              NaN                NaN
# 3             NaN               NaN              NaN                NaN
# 4             NaN               NaN              NaN                NaN
#
#   unranked clade_taxon_id unranked clade_taxon_name          normalized_name  \
# 0                     NaN                       NaN    Lonchosphaera spicata
# 1                     NaN                       NaN             Poulpus spp.
# 2                     NaN                       NaN  Lithostrobus cuspidatus
# 3                     NaN                       NaN      Gondwanaria dogieli
# 4                     NaN                       NaN   Plagiacanthidae indet.
#
#                                               path
# 0  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 1  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 2  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 3  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 4  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
#
# [5 rows x 38 columns]

# %%
metadata = pd.read_csv(metadata_file)
metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
for index, row in df.iterrows():
    # only process that has additional species
    tmp_df = metadata[metadata['file'] == row['file']]
    if len(tmp_df) > 0:
        path = tmp_df['path'].values[0]
        temp_df = pd.read_csv(clean_data_path/path, dtype=str)

        temp_df.loc[
            (temp_df['Sample'] == row['sample']) & (pd.isna(row['code'])), 
            row['verbatim_name']
        ] = 'Indeterminate due to data source'
        
        temp_df.loc[
            (temp_df['Sample'] == row['sample']) & (pd.notna(row['code'])), 
            row['verbatim_name']
        ] = row['code']

        
        temp_df = csv_cleanup(temp_df, path)
        temp_df.to_csv(clean_data_path/path, index=False)

# %% [markdown]
# ## add additional species taxa to crosswalk taxa list

# %%
existing_crosswalk = pd.read_csv(crosswalk_file, dtype=str)
log_df(existing_crosswalk, 3)
# 5276
# Out:
# (5276, 17)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor      normalized_name     taxon_group  \
# 0             NaN                 NaN   Euuvigerina miozea  benthic_forams
# 1             NaN                 NaN  Euuvigerina rodleyi  benthic_forams
# 2             NaN                 NaN  Foraminifera indet.  benthic_forams
#
#                        verbatim_name name comment field     Comment  \
# 0  Euuvigerina miozea (group) >100 m                NaN       group
# 1  Euuvigerina rodleyi (group) >50 m                NaN       group
# 2                             Others                NaN  not a taxa
#
#               Notes (change to Internal only notes?)  \
# 0  Summer 2020: enter "Euuvigerina miozea" and re...
# 1  Summer 2020: enter "Euuvigerina miozea" and re...
# 2                                               Andy
#
#                      comments
# 0                >100 m group
# 1                 >50 m group
# 2  other benthic foraminifera

# %%
df = pd.read_csv(additional_taxa_path, dtype=str)
log_df(df)
# Out:
# (30, 38)
#   sample_id                         file                      sample  \
# 0    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 1    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 2    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 3    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 4    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
#
#     taxon_group                                      verbatim_name code  \
# 0  radiolarians          additional species: Lonchosphaera spicata  NaN
# 1  radiolarians              additional species: Poulpus spp.-like  NaN
# 2  radiolarians        additional species: Lithostrobus cuspidatus  NaN
# 3  radiolarians            additional species: Gondwanaria dogieli  NaN
# 4  radiolarians  additional species: Tetraplecta pinigera/Eusce...  NaN
#
#                      Name Comment Notes (change to Internal only notes?)  \
# 0                     NaN     NaN                                    NaN
# 1            Poulpus spp.     NaN                                    NaN
# 2                     NaN     NaN                                    NaN
# 3                     NaN     NaN                                    NaN
# 4  Plagiacanthidae indet.     NaN                                    NaN
#
#     Any taxon above genus  ... class_taxon_id class_taxon_name  \
# 0                     NaN  ...            NaN              NaN
# 1                     NaN  ...            NaN              NaN
# 2                     NaN  ...            NaN              NaN
# 3                     NaN  ...            NaN              NaN
# 4  Plagiacanthidae indet.  ...            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
# 2             NaN               NaN              NaN                NaN
# 3             NaN               NaN              NaN                NaN
# 4             NaN               NaN              NaN                NaN
#
#   unranked clade_taxon_id unranked clade_taxon_name          normalized_name  \
# 0                     NaN                       NaN    Lonchosphaera spicata
# 1                     NaN                       NaN             Poulpus spp.
# 2                     NaN                       NaN  Lithostrobus cuspidatus
# 3                     NaN                       NaN      Gondwanaria dogieli
# 4                     NaN                       NaN   Plagiacanthidae indet.
#
#                                               path
# 0  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 1  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 2  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 3  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 4  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
#
# [5 rows x 38 columns]

# %%
filtered_taxa = nt.create_taxa_crosswalk_df(df)
# 30
# 30
# 20
# Out:
# fields: ['Any taxon above genus', 'genus modifier', 'genus name', 'subgenera modifier', 'subgenera name', 'species modifier', 'species name', 'subspecies modifier', 'subspecies name', 'non-taxa descriptor', 'normalized_name', 'taxon_group', 'verbatim_name', 'name comment field', 'Comment', 'Notes (change to Internal only notes?)', 'comments']
# initial df:  (30, 17)
# remove nontaxa df:  (30, 17)
# drop duplicates df:  (20, 17)

# %%
existing_crosswalk.columns == filtered_taxa.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
combine_df = pd.concat([existing_crosswalk, filtered_taxa])
remove_whitespace(combine_df)

combine_df.shape
# 5296
# Out:
# (5296, 17)

# %%
combine_df.drop_duplicates(subset=['normalized_name', 'taxon_group', 'verbatim_name'], inplace=True)
log_df(combine_df)
# 5295
# Out:
# (5295, 17)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                                           Euuvigerina
# 1                                           Euuvigerina
# 2       Foraminifera indet.
# 3  Pleurostomellidae indet.
# 4          Ostracoda indet.
#
#   subgenera name species modifier species name subspecies modifier  \
# 0                                       miozea
# 1                                      rodleyi
# 2
# 3
# 4
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 0                                            Euuvigerina miozea
# 1                                           Euuvigerina rodleyi
# 2                                           Foraminifera indet.
# 3                                      Pleurostomellidae indet.
# 4                                              Ostracoda indet.
#
#       taxon_group                      verbatim_name name comment field  \
# 0  benthic_forams  Euuvigerina miozea (group) >100 m
# 1  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 2  benthic_forams                             Others
# 3  benthic_forams           Pleurostomellids comment
# 4  benthic_forams                     Ostracoda spp.     Ostracoda spp.
#
#            Comment             Notes (change to Internal only notes?)  \
# 0            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 1            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 2       not a taxa                                               Andy
# 3       not a taxa                                               Andy
# 4  group abundance  Summer 2020: go in as Ostracoda indet, and the...
#
#                      comments
# 0                >100 m group
# 1                 >50 m group
# 2  other benthic foraminifera
# 3
# 4

# %%
combine_df.to_csv(crosswalk_file, index=False)

# %% [markdown]
# ## add additional species taxa to taxa list

# %%
existing_taxa = pd.read_csv(taxa_list_file, dtype=str)
log_df(existing_taxa, 3)
# 4646
# Out:
# (4646, 25)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2             NaN               NaN           212476           Rhizaria
#
# [3 rows x 25 columns]

# %%
df = pd.read_csv(additional_taxa_path, dtype=str)
log_df(df)
# Out:
# (30, 38)
#   sample_id                         file                      sample  \
# 0    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 1    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 2    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 3    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
# 4    203528  374_U1525A_radiolarians.csv  374-U1525A-1H-1-IW_MUDLINE
#
#     taxon_group                                      verbatim_name code  \
# 0  radiolarians          additional species: Lonchosphaera spicata  NaN
# 1  radiolarians              additional species: Poulpus spp.-like  NaN
# 2  radiolarians        additional species: Lithostrobus cuspidatus  NaN
# 3  radiolarians            additional species: Gondwanaria dogieli  NaN
# 4  radiolarians  additional species: Tetraplecta pinigera/Eusce...  NaN
#
#                      Name Comment Notes (change to Internal only notes?)  \
# 0                     NaN     NaN                                    NaN
# 1            Poulpus spp.     NaN                                    NaN
# 2                     NaN     NaN                                    NaN
# 3                     NaN     NaN                                    NaN
# 4  Plagiacanthidae indet.     NaN                                    NaN
#
#     Any taxon above genus  ... class_taxon_id class_taxon_name  \
# 0                     NaN  ...            NaN              NaN
# 1                     NaN  ...            NaN              NaN
# 2                     NaN  ...            NaN              NaN
# 3                     NaN  ...            NaN              NaN
# 4  Plagiacanthidae indet.  ...            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
# 2             NaN               NaN              NaN                NaN
# 3             NaN               NaN              NaN                NaN
# 4             NaN               NaN              NaN                NaN
#
#   unranked clade_taxon_id unranked clade_taxon_name          normalized_name  \
# 0                     NaN                       NaN    Lonchosphaera spicata
# 1                     NaN                       NaN             Poulpus spp.
# 2                     NaN                       NaN  Lithostrobus cuspidatus
# 3                     NaN                       NaN      Gondwanaria dogieli
# 4                     NaN                       NaN   Plagiacanthidae indet.
#
#                                               path
# 0  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 1  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 2  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 3  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
# 4  LIMS/Micropal_CSV_2/374_U1525A_radiolarians.csv
#
# [5 rows x 38 columns]

# %%
filtered_taxa = nt.create_taxa_list_df(df)
# 30
# 30
# 20
# Out:
# fields: ['Any taxon above genus', 'genus modifier', 'genus name', 'subgenera modifier', 'subgenera name', 'species modifier', 'species name', 'subspecies modifier', 'subspecies name', 'non-taxa descriptor', 'normalized_name', 'taxon_group', 'pbdb_taxon_id', 'pbdb_taxon_name', 'pbdb_taxon_rank', 'family_taxon_id', 'family_taxon_name', 'order_taxon_id', 'order_taxon_name', 'class_taxon_id', 'class_taxon_name', 'phylum_taxon_id', 'phylum_taxon_name', 'kingdom_taxon_id', 'kingdom_taxon_name']
# initial df:  (30, 25)
# remove nontaxa df:  (30, 25)
# drop duplicates df:  (20, 25)

# %%
existing_taxa.columns == filtered_taxa.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
combine_df = pd.concat([existing_taxa, filtered_taxa])
remove_whitespace(combine_df)
combine_df.shape

# 4666
# Out:
# (4666, 25)

# %%
combine_df.drop_duplicates(inplace=True, subset =[ 'normalized_name', 'taxon_group'] )
log_df(combine_df)
# 4660
# Out:
# (4660, 25)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                                           Euuvigerina
# 1                                           Euuvigerina
# 2       Foraminifera indet.
# 3  Pleurostomellidae indet.
# 4          Ostracoda indet.
#
#   subgenera name species modifier species name subspecies modifier  \
# 0                                       miozea
# 1                                      rodleyi
# 2
# 3
# 4
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0                                      ...
# 1                                      ...
# 2                                      ...
# 3                                      ...
# 4                                      ...
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0
# 1
# 2
# 3
# 4
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2                                             212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4           18891        Arthropoda           325038           Animalia
#
# [5 rows x 25 columns]

# %%
combine_df.to_csv(taxa_list_file, index=False)

# %% [markdown]
# ## add matching NOAA taxa to LIMS taxa
#
# add NOAA taxa that match LIMS taxa to LIMS taxa

# %%
metadata = pd.read_csv(metadata_file)
log_df(metadata)
# Out:
# (1253, 16)
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False

# %%
all_columns = set()
for path in metadata['path']:
    df = pd.read_csv(clean_data_path/path, dtype=str)
    df = csv_cleanup(df, clean_data_path/path)
    df = df.dropna(how='all', axis='columns')
    all_columns.update([col.strip() for col in df.columns])

# %%
len(all_columns)
# 5552
# Out:
# 5552

# %%
existing_taxa_df = pd.read_csv(taxa_list_file)
existing_taxa_df.columns
# Out:
# Index(['Any taxon above genus', 'genus modifier', 'genus name',
#        'subgenera modifier', 'subgenera name', 'species modifier',
#        'species name', 'subspecies modifier', 'subspecies name',
#        'non-taxa descriptor', 'normalized_name', 'taxon_group',
#        'pbdb_taxon_id', 'pbdb_taxon_name', 'pbdb_taxon_rank',
#        'family_taxon_id', 'family_taxon_name', 'order_taxon_id',
#        'order_taxon_name', 'class_taxon_id', 'class_taxon_name',
#        'phylum_taxon_id', 'phylum_taxon_name', 'kingdom_taxon_id',
#        'kingdom_taxon_name'],
#       dtype='object')

# %%
existing_LIMS_taxa = set()

taxa_df = pd.read_csv(crosswalk_file)
for index, row in taxa_df.iterrows():
    existing_LIMS_taxa.add(row['verbatim_name'])

len(existing_LIMS_taxa)
# 5283
# Out:
# 5283

# %%
existing_NOAA_taxa = set()

noaa_taxa_df = pd.read_csv(noaa_crosswalk_file)
for index, row in noaa_taxa_df.iterrows():
    existing_NOAA_taxa.add(row['verbatim_name'])

len(existing_NOAA_taxa)
# 7758
# Out:
# 7758

# %%
nontaxa = all_columns - existing_LIMS_taxa - existing_NOAA_taxa 
len(nontaxa)
# 188
# Out:
# 188

# %%
nontaxa
# Out:
# {'',
#  '% Planktic Foraminifera within whole sample',
#  '342-U1408A-2H-2-W 100/102-FORAM',
#  'A/W',
#  'ADDITIONAL SPECIES',
#  'Abundance',
#  'Abundance (%)',
#  'Abundances',
#  'Additional zone name',
#  'Additional zone name (short)',
#  'Age',
#  'Age:',
#  'Aspect comment (etching)',
#  'BF Group abundance',
#  'BF Preservation',
#  'BF comment',
#  'BF preservation',
#  'Bathymetry',
#  'Benthic abundance',
#  'Biozone name',
#  'Biozone name (short)',
#  'Bottom Depth [m]',
#  'Bottom Offset (cm) on Parent Sample',
#  'Bottom [cm]',
#  'COMMENTS',
#  'Chrysophyte cyst group abundance',
#  'Comment',
#  'Comment (general)',
#  'Comments',
#  'Core',
#  'Core Type - Section',
#  'Core,    section',
#  'Core, Section',
#  'Core, Section, Interval',
#  'Core, Type, Section',
#  'Core, section',
#  'Core, section, interval',
#  'Core, section, interval (cm)',
#  'Core-Sect',
#  'Datum age average (Ma)',
#  'Datum age average [Ma]',
#  'Datum age maximum [Ma]',
#  'Datum age minimum [Ma]',
#  'Datum author year',
#  'Datum comment',
#  'Datum group',
#  'Datum group code',
#  'Datum name',
#  'Datum name generic',
#  'Datum region',
#  'Datum type',
#  'Depth (cm)',
#  'Depth Method',
#  'Dextral:Sinistral _N. acostaensis_',
#  'Dextral:Sinistral _P. finalis_',
#  'Dextral:Sinistral _P. obliquiloculata_',
#  'Dextral:Sinistral _P. praecursor_',
#  'Dextral:Sinistral _P. praespectabilis_',
#  'Dextral:Sinistral _P. primalis_',
#  'Dextral:Sinistral _P. spectabilis_',
#  'Diatom Zone (NPD) in Yanagisawa and Akiba (1998)',
#  'Diatom Zone (Yanagisawa and Akiba, 1998)',
#  'Diatom abundance',
#  'Diatom preservation - pyritization2',
#  'Diatom preservation dissolution',
#  'Diatom preservation fragmentation',
#  'Diatoms and siliceous plankton comment',
#  'Diatoms group abundance',
#  'Ebridian group abundance',
#  'Exotic',
#  'Exp',
#  'Expedition, site, hole, core, section, interval (cm):',
#  'Extra Sample ID Data',
#  'File Data',
#  'Foram abundance',
#  'Foraminferal preservation',
#  'Foraminiferal abundance',
#  'Foraminiferal preservation',
#  'Fragmentation',
#  'Fragmentation rank [auto-pop]',
#  'Gen. et sp. indet',
#  'General comment',
#  'Genus/species (upper zone)',
#  'Genus/species lower zone)',
#  'Group Abundance',
#  'Group abundance',
#  'Group abundance (%)',
#  'Group preservation',
#  'Half',
#  'Hole',
#  'Hole, Core, Section',
#  'IRD',
#  'Labl ID',
#  'Large Benthic Forams [%]',
#  'Lower boundary age av. [Ma]',
#  'Marine',
#  'Martini (1971) Zone',
#  'Miscellaneous',
#  'Mixing',
#  'Nannofossil Zone',
#  'Nannofossil abundance',
#  'Nannofossil comment',
#  'No. specimens/tray',
#  'Oberservations',
#  'Observations',
#  'Organic matter',
#  'Original Bottom Depth (m)',
#  'Original Top Depth (m)',
#  'Other fossil material',
#  'Other observations',
#  'Other taxa',
#  'PALEO WATER DEPTH (IS=inner shelf, MS=middle shelf, OS=outer shelf)',
#  'PF Group Abundance',
#  'PF Preservation',
#  'PF Zone',
#  'PF group abundance',
#  'PF preservation',
#  'Percentage of benthic forams in total foram assemblage [%]',
#  'Percentage of non-calcareous agglutinated forams in total foram assemblage [%]',
#  'Percentage of planktic forams in total foram assemblage [%]',
#  'Piece',
#  'Planktic foraminiferal %',
#  'Planktic foraminiferal (%)',
#  'Planktonic Benthic ratio (P:B)',
#  'Preservation',
#  'Preservation palynofacies',
#  'Presevation',
#  'Pteropod group abundance',
#  'Pyrite',
#  'REMARKS',
#  'Radiolarian zone',
#  'Radiolarian zone/subzone',
#  'Remarks',
#  'Reworking comment (1= <1%, 2= light 1-10%, 3= >10%)',
#  'Reworking comment (1= <1%, 2=light 1-10%, 3= >10%)',
#  'Sample',
#  'Sample comment',
#  'Sample preparation comment',
#  'Section',
#  'Section Half',
#  'Secton Half',
#  'Ship File Links',
#  'Shore File Links',
#  'Silicoflagellate Zone in Ling (1992)',
#  'Silicoflagellates group abundance',
#  'Sillicoflagellate abundance',
#  'Site',
#  'Temperature Range',
#  'Terrestrial organic matter',
#  'Top Depth [m]',
#  'Top Offset (cm) on Parent Sample',
#  'Top [cm]',
#  'Total in situ dinocysts',
#  'Total pollen',
#  'Total radiolarians',
#  'Type',
#  'Type (lower zone)',
#  'Type (upper zone)',
#  'Upper boundary age av. [Ma]',
#  'Upper boundary age min [Ma]',
#  'XBroken',
#  'XCorroded',
#  'XCrumpled',
#  'Zone',
#  'Zone author (year)',
#  'Zone comment',
#  'Zone group',
#  'Zone in Ling (1992)',
#  'Zone name',
#  'Zone name (short)',
#  'Zone name [short]',
#  'Zone/Subzone',
#  'comments',
#  'constituent',
#  'core, section',
#  'count',
#  'count_type',
#  'dupes and comments',
#  'eodp_id',
#  'fossil',
#  'fossil_group',
#  'interval (cm)',
#  'mean depth (mbsf)',
#  'pc_abundance_name_mode',
#  'pc_fossil_group',
#  'pc_fossil_name',
#  'physical_constituent_name',
#  'preservation'}

# %%
noaa_lims_taxa = all_columns - existing_LIMS_taxa - nontaxa
len(noaa_lims_taxa)
# Out:
# 85

# %%
noaa_crosswalk = pd.read_csv(noaa_crosswalk_file, dtype=str)
noaa_crosswalk['eodp_id'] = np.nan
noaa_crosswalk['name comment field'] = np.nan

log_df(noaa_crosswalk, 3)
# 7763
# Out:
# (7763, 37)
#       taxon_group           verbatim_name name Comment  \
# 0  benthic_forams       Abyssamina incisa  NaN     NaN
# 1  benthic_forams  Adercotryma glomeratum  NaN     NaN
# 2  benthic_forams         Adercotryma sp.  NaN     NaN
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN                   NaN            NaN
# 1                                    NaN                   NaN            NaN
# 2                                    NaN                   NaN            NaN
#
#     genus name subgenera modifier subgenera name  ... class_taxon_name  \
# 0   Abyssamina                NaN            NaN  ...    Globothalamea
# 1  Adercotryma                NaN            NaN  ...              NaN
# 2  Adercotryma                NaN            NaN  ...              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2          288974      Foraminifera           212476           Rhizaria
#
#   unranked clade_taxon_id unranked clade_taxon_name         normalized_name  \
# 0                     NaN                       NaN       Abyssamina incisa
# 1                     NaN                       NaN  Adercotryma glomeratum
# 2                     NaN                       NaN         Adercotryma sp.
#
#   eodp_id name comment field
# 0     NaN                NaN
# 1     NaN                NaN
# 2     NaN                NaN
#
# [3 rows x 37 columns]

# %%
data = []
for index, row in noaa_crosswalk.iterrows():
    if row['verbatim_name'] in noaa_lims_taxa:
        data.append(row)
        
noaa_lims_df = pd.DataFrame(data)
log_df(noaa_lims_df, 3)
# 85
# Out:
# (85, 37)
#         taxon_group        verbatim_name name Comment  \
# 143  benthic_forams  Bolivina albatrossi  NaN     NaN
# 257  benthic_forams      Bulimina exilis  NaN     NaN
# 415  benthic_forams   Cibicidoides parki  NaN     NaN
#
#     Notes (change to Internal only notes?)  Any taxon above genus  \
# 143                                    NaN                    NaN
# 257                                    NaN                    NaN
# 415                                    NaN                    NaN
#
#      genus modifier    genus name  subgenera modifier  subgenera name  ...  \
# 143             NaN      Bolivina                 NaN             NaN  ...
# 257             NaN      Bulimina                 NaN             NaN  ...
# 415             NaN  Cibicidoides                 NaN             NaN  ...
#
#      class_taxon_name phylum_taxon_id  phylum_taxon_name kingdom_taxon_id  \
# 143               NaN          288974       Foraminifera           212476
# 257               NaN          288974       Foraminifera           212476
# 415               NaN          288974       Foraminifera           212476
#
#      kingdom_taxon_name  unranked clade_taxon_id unranked clade_taxon_name  \
# 143            Rhizaria                      NaN                       NaN
# 257            Rhizaria                      NaN                       NaN
# 415            Rhizaria                      NaN                       NaN
#
#          normalized_name eodp_id  name comment field
# 143  Bolivina albatrossi     NaN                 NaN
# 257      Bulimina exilis     NaN                 NaN
# 415   Cibicidoides parki     NaN                 NaN
#
# [3 rows x 37 columns]

# %% [markdown]
# ### update LIMS crosswalk

# %%
existing_crosswalk = pd.read_csv(crosswalk_file, dtype=str)
log_df(existing_crosswalk, 3)
# 5295
# Out:
# (5295, 17)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor      normalized_name     taxon_group  \
# 0             NaN                 NaN   Euuvigerina miozea  benthic_forams
# 1             NaN                 NaN  Euuvigerina rodleyi  benthic_forams
# 2             NaN                 NaN  Foraminifera indet.  benthic_forams
#
#                        verbatim_name name comment field     Comment  \
# 0  Euuvigerina miozea (group) >100 m                NaN       group
# 1  Euuvigerina rodleyi (group) >50 m                NaN       group
# 2                             Others                NaN  not a taxa
#
#               Notes (change to Internal only notes?)  \
# 0  Summer 2020: enter "Euuvigerina miozea" and re...
# 1  Summer 2020: enter "Euuvigerina miozea" and re...
# 2                                               Andy
#
#                      comments
# 0                >100 m group
# 1                 >50 m group
# 2  other benthic foraminifera

# %%
filter_noaa_df = noaa_lims_df[existing_crosswalk.columns]

filter_noaa_df.columns == existing_crosswalk.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
combine_df = pd.concat([existing_crosswalk, filter_noaa_df])
remove_whitespace(combine_df)

combine_df.shape
# 5380
# Out:
# (5380, 17)

# %%
combine_df.to_csv(crosswalk_file, index=False)

# %% [markdown]
# ### update LIMS taxa list

# %%
existing_taxa = pd.read_csv(taxa_list_file, dtype=str)
log_df(existing_taxa, 3)
# 4660
# Out:
# (4660, 25)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2             NaN               NaN           212476           Rhizaria
#
# [3 rows x 25 columns]

# %%
filter_noaa_df = noaa_lims_df[existing_taxa.columns]

filter_noaa_df.columns == existing_taxa.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
combine_df = pd.concat([existing_taxa, filter_noaa_df])
remove_whitespace(combine_df)

combine_df.shape
# 4745
# Out:
# (4745, 25)

# %%
combine_df.to_csv(taxa_list_file, index=False)

# %% [markdown]
# ## add eodp_id to taxa crosswalk

# %%
df = pd.read_csv(crosswalk_file, dtype=str)
log_df(df, 3)
# 5380
# Out:
# (5380, 17)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor      normalized_name     taxon_group  \
# 0             NaN                 NaN   Euuvigerina miozea  benthic_forams
# 1             NaN                 NaN  Euuvigerina rodleyi  benthic_forams
# 2             NaN                 NaN  Foraminifera indet.  benthic_forams
#
#                        verbatim_name name comment field     Comment  \
# 0  Euuvigerina miozea (group) >100 m                NaN       group
# 1  Euuvigerina rodleyi (group) >50 m                NaN       group
# 2                             Others                NaN  not a taxa
#
#               Notes (change to Internal only notes?)  \
# 0  Summer 2020: enter "Euuvigerina miozea" and re...
# 1  Summer 2020: enter "Euuvigerina miozea" and re...
# 2                                               Andy
#
#                      comments
# 0                >100 m group
# 1                 >50 m group
# 2  other benthic foraminifera

# %%
df['eodp_id'] = df.index
log_df(df, 3)
# Out:
# (5380, 18)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor      normalized_name     taxon_group  \
# 0             NaN                 NaN   Euuvigerina miozea  benthic_forams
# 1             NaN                 NaN  Euuvigerina rodleyi  benthic_forams
# 2             NaN                 NaN  Foraminifera indet.  benthic_forams
#
#                        verbatim_name name comment field     Comment  \
# 0  Euuvigerina miozea (group) >100 m                NaN       group
# 1  Euuvigerina rodleyi (group) >50 m                NaN       group
# 2                             Others                NaN  not a taxa
#
#               Notes (change to Internal only notes?)  \
# 0  Summer 2020: enter "Euuvigerina miozea" and re...
# 1  Summer 2020: enter "Euuvigerina miozea" and re...
# 2                                               Andy
#
#                      comments  eodp_id
# 0                >100 m group        0
# 1                 >50 m group        1
# 2  other benthic foraminifera        2

# %%
df.to_csv(crosswalk_file, index=False)
