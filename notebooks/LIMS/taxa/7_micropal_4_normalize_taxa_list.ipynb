# %% [markdown]
# # Normalize taxa list micropal 4
#
# Cleanup the normalized micropal 4 taxa list from the eODP researchers. Add PBDB taxa data.

# %%
import sys
sys.path.append('../../../')

import pandas as pd
import numpy as np
import requests

from config import CLEAN_DATA_DIR, OUTPUT_DIR, RAW_DATA_DIR

import scripts.normalize_taxa as nt
import scripts.pbdb as pbdb
from scripts.normalize_data import remove_whitespace

from scripts.pbdb import (
    get_parent_taxa, 
    PBDB_TAXA_NAME, 
    PBDB_TAXA_ID,
    check_multiple_pbdb_id,
    create_genus_df,
    fetch_pdbd_data,
    add_pbdb_data,
    create_higher_taxa_df
)

from scripts.shared_utils import (
    log_df
)

# %%
date = '2022-11-15'

input_file = RAW_DATA_DIR/'PI_processed_files'/f'LIMS Micropal_CSV_4_taxa_{date}.csv'

pi_taxa_file_pbdb = OUTPUT_DIR /'taxa'/'LIMS'/f'PI_Micropal_CSV_4_normalized_taxa_list_with_pbdb_{date}.csv'

genus_pbdb_file = OUTPUT_DIR/'taxa'/'LIMS'/f"genera_pbdb_lims_4_{date}.csv"
higher_taxa_pbdb_file = OUTPUT_DIR/'taxa'/'LIMS'/f"higher_taxa_pbdb_lims_4_{date}.csv"

genus_letter_old_file= OUTPUT_DIR/'taxa'/'draft'/'LIMS'/f"micropal_4_genus_letter_2022-02-24.csv"
genus_letter_file= OUTPUT_DIR/'taxa'/'draft'/'LIMS'/f"micropal_4_genus_letter_{date}.csv"

crosswalk_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_crosswalk_{date}.csv"
taxa_list_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_list_{date}.csv"

# %% [markdown]
# ## fix abbreviated genus

# %%
df = pd.read_csv(input_file, dtype=str)
df = df.dropna(axis=0, how='all')
if 'abbrev_genus' in df.columns:
    del df['abbrev_genus']
           
log_df(df)
# 695
# Out:
# (695, 32)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                         Name                     Comment  \
# 0         Textulariia indet.                         NaN
# 1         Textulariia indet.                         NaN
# 2  Alabaminella weddellensis                         NaN
# 3              Alabamina sp.            genus misspelled
# 4  Alabaminella weddellensis  genus & species misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... order_taxon_id  \
# 0           NaN                NaN            NaN  ...            NaN
# 1           NaN                NaN            NaN  ...            NaN
# 2  Alabaminella                NaN            NaN  ...            NaN
# 3     Alabamina                NaN            NaN  ...            NaN
# 4  Alabaminella                NaN            NaN  ...            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN          288974
# 2              NaN            NaN              NaN          288974
# 3              NaN            NaN              NaN          288974
# 4              NaN            NaN              NaN          288974
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0      Foraminifera           212476           Rhizaria
# 1      Foraminifera           212476           Rhizaria
# 2      Foraminifera           212476           Rhizaria
# 3      Foraminifera           212476           Rhizaria
# 4      Foraminifera           212476           Rhizaria
#
#   unranked clade_taxon_id unranked clade_taxon_name
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
# [5 rows x 32 columns]

# %%
genus_df = pd.read_csv(genus_letter_old_file, dtype=str, usecols=['verbatim_name'])
genus_df['abbrev_genus'] = True
log_df(genus_df)
# Out:
# (34, 2)
#                              verbatim_name  abbrev_genus
# 0  Calc. Hyaline Foram. gen. et sp. indet.          True
# 1                        Gen. et sp. indet          True
# 2              O. centrocarpum var. Arctic          True
# 3     O. centrocarpum var. short processes          True
# 4        O. centrocarpum-Arctic morphotype          True

# %%
df = df.merge(genus_df, on ='verbatim_name', how='left')
df.loc[df['abbrev_genus'].isna() == True, 'abbrev_genus'] = False

log_df(df)
# Out:
# (695, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                         Name                     Comment  \
# 0         Textulariia indet.                         NaN
# 1         Textulariia indet.                         NaN
# 2  Alabaminella weddellensis                         NaN
# 3              Alabamina sp.            genus misspelled
# 4  Alabaminella weddellensis  genus & species misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... order_taxon_name  \
# 0           NaN                NaN            NaN  ...              NaN
# 1           NaN                NaN            NaN  ...              NaN
# 2  Alabaminella                NaN            NaN  ...              NaN
# 3     Alabamina                NaN            NaN  ...              NaN
# 4  Alabaminella                NaN            NaN  ...              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN          288974      Foraminifera
# 1            NaN              NaN          288974      Foraminifera
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4            NaN              NaN          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 0           212476           Rhizaria                     NaN
# 1           212476           Rhizaria                     NaN
# 2           212476           Rhizaria                     NaN
# 3           212476           Rhizaria                     NaN
# 4           212476           Rhizaria                     NaN
#
#   unranked clade_taxon_name abbrev_genus
# 0                       NaN        False
# 1                       NaN        False
# 2                       NaN        False
# 3                       NaN        False
# 4                       NaN        False
#
# [5 rows x 33 columns]

# %% [markdown]
# set name parts columns to null; reparse name parts column

# %%
columns = [
    'genus modifier', 'genus name', 'subgenera modifier', 'subgenera name',
    'species modifier', 'species name', 'subspecies modifier',
    'subspecies name', 'non-taxa descriptor', 'pbdb_taxon_id',
     'pbdb_taxon_name', 'pbdb_taxon_rank',
    'family_taxon_id', 'family_taxon_name', 'order_taxon_id',
    'order_taxon_name', 'class_taxon_id', 'class_taxon_name',
    'phylum_taxon_id', 'phylum_taxon_name', 'kingdom_taxon_id',
    'kingdom_taxon_name', 'unranked clade_taxon_id',
    'unranked clade_taxon_name'
]

def reparse_names():
    for index, row in df[df['abbrev_genus'] & df['Name'].notna()].iterrows():    
        taxon_name_parts = nt.taxon_name_parser(row['Name'])

        for col in columns:
            df.at[index, col] = np.nan

        for rank in taxon_name_parts:
            df.at[index, rank] = taxon_name_parts[rank]

# %% [markdown]
# add pbdb id

# %%
def add_pbdb_id():
    for index, row in df[df['abbrev_genus'] & df['Name'].notna()].iterrows(): 
        if index % 10 == 0:
            print(index)

        url =  PBDB_TAXA_NAME +  row['genus name']

        response = requests.get(url)

        if response.status_code == 200:
            data = response.json()["records"]
            if len(data) == 1:
                df.at[index, f'pbdb_taxon_id'] = str(data[0]["taxon_no"])
                df.at[index, f'pbdb_taxon_name'] = data[0]["taxon_name"]
                df.at[index, f'pbdb_taxon_rank'] = data[0]["taxon_rank"]

                round = 0
                get_parent_taxa(df, data[0]["parent_no"], data[0]["taxon_rank"], round, index, None)

# %% [markdown]
# check if pbdb data is same for each pbdb taxon id

# %%
check_multiple_pbdb_id(df)
# Out:
# Empty DataFrame
# Columns: [pbdb_taxon_id, pbdb_taxon_name, pbdb_taxon_rank, family_taxon_id, family_taxon_name, order_taxon_id, order_taxon_name, class_taxon_id, class_taxon_name, phylum_taxon_id, phylum_taxon_name, kingdom_taxon_id, kingdom_taxon_name]
# Index: []

# %%
# reparse_names()
# add_pbdb_id()

df.to_csv( pi_taxa_file_pbdb,index=False)

# %% [markdown]
# ## fix incorect pbdb_taxon_id
#
# incorported  pbdb_taxon_id that the PIs corrected into the taxalist.

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)
df = df.dropna(how="all", axis="index")
df['corrected'] = False

log_df(df)
# 695
# Out:
# (695, 34)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                         Name                     Comment  \
# 0         Textulariia indet.                         NaN
# 1         Textulariia indet.                         NaN
# 2  Alabaminella weddellensis                         NaN
# 3              Alabamina sp.            genus misspelled
# 4  Alabaminella weddellensis  genus & species misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... class_taxon_id  \
# 0           NaN                NaN            NaN  ...            NaN
# 1           NaN                NaN            NaN  ...            NaN
# 2  Alabaminella                NaN            NaN  ...            NaN
# 3     Alabamina                NaN            NaN  ...            NaN
# 4  Alabaminella                NaN            NaN  ...            NaN
#
#   class_taxon_name phylum_taxon_id phylum_taxon_name kingdom_taxon_id  \
# 0              NaN          288974      Foraminifera           212476
# 1              NaN          288974      Foraminifera           212476
# 2              NaN          288974      Foraminifera           212476
# 3              NaN          288974      Foraminifera           212476
# 4              NaN          288974      Foraminifera           212476
#
#   kingdom_taxon_name unranked clade_taxon_id unranked clade_taxon_name  \
# 0           Rhizaria                     NaN                       NaN
# 1           Rhizaria                     NaN                       NaN
# 2           Rhizaria                     NaN                       NaN
# 3           Rhizaria                     NaN                       NaN
# 4           Rhizaria                     NaN                       NaN
#
#   abbrev_genus corrected
# 0        False     False
# 1        False     False
# 2        False     False
# 3        False     False
# 4        False     False
#
# [5 rows x 34 columns]

# %%
df[['pbdb_taxon_id', 'Corrections to pbdb_taxon_id']].dropna(subset=['Corrections to pbdb_taxon_id'])
# Out:
#     pbdb_taxon_id Corrections to pbdb_taxon_id
# 49           1064                         1064
# 50           1064                         1064
# 51           1064                         1064
# 52           1064                         1064
# 53           1064                         1064
# 54           1064                         1064
# 304        432650                       432650
# 311         68421                        68421
# 325         71266                        71266
# 437        421517                       421517
# 438        421517                       421517
# 537         54452                        54452
# 540         54452                        54452
# 551        446918                       446918
# 623          2894                         2894
# 661         71284                        71284
# 663         82180                        82180
# 664         82180                        82180
# 665         82180                        82180
# 666         82180                        82180
# 667         82180                        82180
# 668         82180                        82180

# %%
tmp = df[df['Corrections to pbdb_taxon_id'].notna() & (df['corrected'] == False)]
tmp['Corrections to pbdb_taxon_id'].unique()
# Out:
# array(['1064', '432650', '68421', '71266', '421517', '54452', '446918',
#        '2894', '71284', '82180'], dtype=object)

# %%
pbdb.fix_pbdb_id(df, '1064', 1064)
pbdb.fix_pbdb_id(df, '432650', 432650)
pbdb.fix_pbdb_id(df, '68421', 68421)
pbdb.fix_pbdb_id(df, '71266', 71266)
pbdb.fix_pbdb_id(df, '421517', 421517)
pbdb.fix_pbdb_id(df, '54452', 54452)
pbdb.fix_pbdb_id(df, '446918', 446918)
pbdb.fix_pbdb_id(df, '2894', 2894)
pbdb.fix_pbdb_id(df, '71284', 71284)
pbdb.fix_pbdb_id(df, '82180', 82180)
# Out:
# 1064
# 432650
# 68421
# 71266
# 421517
# 54452
# 446918
# 2894
# 71284
# 82180

# %%
df.shape
# Out:
# (695, 34)

# %%
del df['corrected']

# %%
df.to_csv(pi_taxa_file_pbdb, index=False)

# %% [markdown]
# ## QA rows without pbdb id

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)

log_df(df, 3)
# 695
# Out:
# (695, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
#
#                         Name Comment Notes (change to Internal only notes?)  \
# 0         Textulariia indet.     NaN                                    NaN
# 1         Textulariia indet.     NaN                                    NaN
# 2  Alabaminella weddellensis     NaN                                    NaN
#
#   Any taxon above genus genus modifier    genus name subgenera modifier  \
# 0    Textulariia indet.            NaN           NaN                NaN
# 1    Textulariia indet.            NaN           NaN                NaN
# 2                   NaN            NaN  Alabaminella                NaN
#
#   subgenera name  ... order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN  ...              NaN            NaN              NaN
# 1            NaN  ...              NaN            NaN              NaN
# 2            NaN  ...              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2          288974      Foraminifera           212476           Rhizaria
#
#   unranked clade_taxon_id unranked clade_taxon_name abbrev_genus
# 0                     NaN                       NaN        False
# 1                     NaN                       NaN        False
# 2                     NaN                       NaN        False
#
# [3 rows x 33 columns]

# %%
tmp = df[df['pbdb_taxon_id'].isna() & df['Any taxon above genus'].isna() ]

log_df(tmp)
# 12

tmp['verbatim_name']
# Out:
# (12, 33)
# 25                                           Bathymetry
# 283    Diatom Zone (NPD) in Yanagisawa and Akiba (1998)
# 284            Diatom Zone (Yanagisawa and Akiba, 1998)
# 299                                   Gen. et sp. indet
# 307                                              Marine
# 462                                 Martini (1971) Zone
# 616                            Planktic foraminiferal %
# 617                          Planktic foraminiferal (%)
# 651                                    Radiolarian zone
# 652                            Radiolarian zone/subzone
# 679                Silicoflagellate Zone in Ling (1992)
# 680                                 Zone in Ling (1992)
# Name: verbatim_name, dtype: object

# %% [markdown]
# ## create genera csv

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)
log_df(df)
# 695
# Out:
# (695, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                         Name                     Comment  \
# 0         Textulariia indet.                         NaN
# 1         Textulariia indet.                         NaN
# 2  Alabaminella weddellensis                         NaN
# 3              Alabamina sp.            genus misspelled
# 4  Alabaminella weddellensis  genus & species misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... order_taxon_name  \
# 0           NaN                NaN            NaN  ...              NaN
# 1           NaN                NaN            NaN  ...              NaN
# 2  Alabaminella                NaN            NaN  ...              NaN
# 3     Alabamina                NaN            NaN  ...              NaN
# 4  Alabaminella                NaN            NaN  ...              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN          288974      Foraminifera
# 1            NaN              NaN          288974      Foraminifera
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4            NaN              NaN          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 0           212476           Rhizaria                     NaN
# 1           212476           Rhizaria                     NaN
# 2           212476           Rhizaria                     NaN
# 3           212476           Rhizaria                     NaN
# 4           212476           Rhizaria                     NaN
#
#   unranked clade_taxon_name abbrev_genus
# 0                       NaN        False
# 1                       NaN        False
# 2                       NaN        False
# 3                       NaN        False
# 4                       NaN        False
#
# [5 rows x 33 columns]

# %%
genus_df =  create_genus_df(df)

log_df(genus_df)
# 242
# Out:
# (242, 15)
#       taxon_group    genus name pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank  \
# 2  benthic_forams  Alabaminella        423746    Alabaminella           genus
# 3  benthic_forams     Alabamina           788       Alabamina           genus
# 5  benthic_forams    Ammodiscus           818      Ammodiscus           genus
# 6  benthic_forams       Ammonia           823         Ammonia           genus
# 7  benthic_forams   Amphicoryna           835     Amphicoryna           genus
#
#   family_taxon_id family_taxon_name order_taxon_id order_taxon_name  \
# 2          241423        Eponididae            NaN              NaN
# 3           82213      Alabaminidae            NaN              NaN
# 5          112199      Ammodiscidae            NaN              NaN
# 6          103768        Rotaliidae            NaN              NaN
# 7          112281     Vaginulinidae         428878     Vaginulinida
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 5            NaN              NaN          288974      Foraminifera
# 6            NaN              NaN          288974      Foraminifera
# 7         428875      Nodosariata          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name
# 2           212476           Rhizaria
# 3           212476           Rhizaria
# 5           212476           Rhizaria
# 6           212476           Rhizaria
# 7           212476           Rhizaria

# %% [markdown]
# check for duplicate genus

# %%
genus_df[genus_df.duplicated(subset=['taxon_group', 'genus name'])]
# Out:
# Empty DataFrame
# Columns: [taxon_group, genus name, pbdb_taxon_id, pbdb_taxon_name, pbdb_taxon_rank, family_taxon_id, family_taxon_name, order_taxon_id, order_taxon_name, class_taxon_id, class_taxon_name, phylum_taxon_id, phylum_taxon_name, kingdom_taxon_id, kingdom_taxon_name]
# Index: []

# %% [markdown]
# check for genus name used in more than taxon group

# %%
genus_df[genus_df.duplicated(subset=['genus name'])]
# Out:
# Empty DataFrame
# Columns: [taxon_group, genus name, pbdb_taxon_id, pbdb_taxon_name, pbdb_taxon_rank, family_taxon_id, family_taxon_name, order_taxon_id, order_taxon_name, class_taxon_id, class_taxon_name, phylum_taxon_id, phylum_taxon_name, kingdom_taxon_id, kingdom_taxon_name]
# Index: []

# %% [markdown]
# fetch pbdb info for genus that do not have pbdb info

# %%
fetch_pdbd_data(genus_df, 'genus name')
# Out:
# 200 250 300 350 400 600 650

# %%
genus_df.drop_duplicates(inplace=True)

log_df(genus_df)
# 242
# Out:
# (242, 15)
#       taxon_group    genus name pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank  \
# 2  benthic_forams  Alabaminella        423746    Alabaminella           genus
# 3  benthic_forams     Alabamina           788       Alabamina           genus
# 5  benthic_forams    Ammodiscus           818      Ammodiscus           genus
# 6  benthic_forams       Ammonia           823         Ammonia           genus
# 7  benthic_forams   Amphicoryna           835     Amphicoryna           genus
#
#   family_taxon_id family_taxon_name order_taxon_id order_taxon_name  \
# 2          241423        Eponididae            NaN              NaN
# 3           82213      Alabaminidae            NaN              NaN
# 5          112199      Ammodiscidae            NaN              NaN
# 6          103768        Rotaliidae            NaN              NaN
# 7          112281     Vaginulinidae         428878     Vaginulinida
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 5            NaN              NaN          288974      Foraminifera
# 6            NaN              NaN          288974      Foraminifera
# 7         428875      Nodosariata          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name
# 2           212476           Rhizaria
# 3           212476           Rhizaria
# 5           212476           Rhizaria
# 6           212476           Rhizaria
# 7           212476           Rhizaria

# %%
genus_df.to_csv(genus_pbdb_file, index=False)

# %% [markdown]
# ## add genus pbdb to input_file

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)
log_df(df)
# 695, 32
# Out:
# (695, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                         Name                     Comment  \
# 0         Textulariia indet.                         NaN
# 1         Textulariia indet.                         NaN
# 2  Alabaminella weddellensis                         NaN
# 3              Alabamina sp.            genus misspelled
# 4  Alabaminella weddellensis  genus & species misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... order_taxon_name  \
# 0           NaN                NaN            NaN  ...              NaN
# 1           NaN                NaN            NaN  ...              NaN
# 2  Alabaminella                NaN            NaN  ...              NaN
# 3     Alabamina                NaN            NaN  ...              NaN
# 4  Alabaminella                NaN            NaN  ...              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN          288974      Foraminifera
# 1            NaN              NaN          288974      Foraminifera
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4            NaN              NaN          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 0           212476           Rhizaria                     NaN
# 1           212476           Rhizaria                     NaN
# 2           212476           Rhizaria                     NaN
# 3           212476           Rhizaria                     NaN
# 4           212476           Rhizaria                     NaN
#
#   unranked clade_taxon_name abbrev_genus
# 0                       NaN        False
# 1                       NaN        False
# 2                       NaN        False
# 3                       NaN        False
# 4                       NaN        False
#
# [5 rows x 33 columns]

# %%
genus_df= pd.read_csv(genus_pbdb_file, dtype=str)

log_df(genus_df)
#242
# Out:
# (242, 15)
#       taxon_group    genus name pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank  \
# 0  benthic_forams  Alabaminella        423746    Alabaminella           genus
# 1  benthic_forams     Alabamina           788       Alabamina           genus
# 2  benthic_forams    Ammodiscus           818      Ammodiscus           genus
# 3  benthic_forams       Ammonia           823         Ammonia           genus
# 4  benthic_forams   Amphicoryna           835     Amphicoryna           genus
#
#   family_taxon_id family_taxon_name order_taxon_id order_taxon_name  \
# 0          241423        Eponididae            NaN              NaN
# 1           82213      Alabaminidae            NaN              NaN
# 2          112199      Ammodiscidae            NaN              NaN
# 3          103768        Rotaliidae            NaN              NaN
# 4          112281     Vaginulinidae         428878     Vaginulinida
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN          288974      Foraminifera
# 1            NaN              NaN          288974      Foraminifera
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4         428875      Nodosariata          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name
# 0           212476           Rhizaria
# 1           212476           Rhizaria
# 2           212476           Rhizaria
# 3           212476           Rhizaria
# 4           212476           Rhizaria

# %%
add_pbdb_data(df, genus_df, 'genus name')

# %%
log_df(df)
# 695
# Out:
# (695, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                         Name                     Comment  \
# 0         Textulariia indet.                         NaN
# 1         Textulariia indet.                         NaN
# 2  Alabaminella weddellensis                         NaN
# 3              Alabamina sp.            genus misspelled
# 4  Alabaminella weddellensis  genus & species misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... order_taxon_name  \
# 0           NaN                NaN            NaN  ...              NaN
# 1           NaN                NaN            NaN  ...              NaN
# 2  Alabaminella                NaN            NaN  ...              NaN
# 3     Alabamina                NaN            NaN  ...              NaN
# 4  Alabaminella                NaN            NaN  ...              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN          288974      Foraminifera
# 1            NaN              NaN          288974      Foraminifera
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4            NaN              NaN          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 0           212476           Rhizaria                     NaN
# 1           212476           Rhizaria                     NaN
# 2           212476           Rhizaria                     NaN
# 3           212476           Rhizaria                     NaN
# 4           212476           Rhizaria                     NaN
#
#   unranked clade_taxon_name abbrev_genus
# 0                       NaN        False
# 1                       NaN        False
# 2                       NaN        False
# 3                       NaN        False
# 4                       NaN        False
#
# [5 rows x 33 columns]

# %%
df.to_csv(pi_taxa_file_pbdb, index=False)

# %% [markdown]
# ## create higher taxa

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)
log_df(df, 3)
# 695
# Out:
# (695, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
#
#                         Name Comment Notes (change to Internal only notes?)  \
# 0         Textulariia indet.     NaN                                    NaN
# 1         Textulariia indet.     NaN                                    NaN
# 2  Alabaminella weddellensis     NaN                                    NaN
#
#   Any taxon above genus genus modifier    genus name subgenera modifier  \
# 0    Textulariia indet.            NaN           NaN                NaN
# 1    Textulariia indet.            NaN           NaN                NaN
# 2                   NaN            NaN  Alabaminella                NaN
#
#   subgenera name  ... order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN  ...              NaN            NaN              NaN
# 1            NaN  ...              NaN            NaN              NaN
# 2            NaN  ...              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2          288974      Foraminifera           212476           Rhizaria
#
#   unranked clade_taxon_id unranked clade_taxon_name abbrev_genus
# 0                     NaN                       NaN        False
# 1                     NaN                       NaN        False
# 2                     NaN                       NaN        False
#
# [3 rows x 33 columns]

# %% [markdown]
# check for for taxon that has both higher taxa and genus name

# %%
df[df['Any taxon above genus'].notna() & df['genus name'].notna()]
# Out:
# Empty DataFrame
# Columns: [taxon_group, verbatim_name, Name, Comment, Notes (change to Internal only notes?), Any taxon above genus, genus modifier, genus name, subgenera modifier, subgenera name, species modifier, species name, subspecies modifier, subspecies name, non-taxa descriptor, comments, pbdb_taxon_id, Corrections to pbdb_taxon_id, pbdb_taxon_name, pbdb_taxon_rank, family_taxon_id, family_taxon_name, order_taxon_id, order_taxon_name, class_taxon_id, class_taxon_name, phylum_taxon_id, phylum_taxon_name, kingdom_taxon_id, kingdom_taxon_name, unranked clade_taxon_id, unranked clade_taxon_name, abbrev_genus]
# Index: []
#
# [0 rows x 33 columns]

# %%
higher_df =  create_higher_taxa_df(df)

log_df(higher_df)
# 35
# Out:
# (35, 15)
#          taxon_group  Any taxon above genus pbdb_taxon_id pbdb_taxon_name  \
# 0     benthic_forams     Textulariia indet.        434530     Textulariia
# 47    benthic_forams    Foraminifera indet.        288974    Foraminifera
# 366  dinoflagellates  Dinoflagellata indet.        354791  Dinoflagellata
# 381  dinoflagellates    Foraminifera indet.        288974    Foraminifera
# 395  dinoflagellates     Dinophyceae indet.        321578     Dinophyceae
#
#     pbdb_taxon_rank family_taxon_id family_taxon_name order_taxon_id  \
# 0          subclass             NaN               NaN            NaN
# 47           phylum             NaN               NaN            NaN
# 366      superclass             NaN               NaN            NaN
# 381          phylum             NaN               NaN            NaN
# 395           class             NaN               NaN            NaN
#
#     order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0                NaN            NaN              NaN          288974
# 47               NaN            NaN              NaN             NaN
# 366              NaN            NaN              NaN          277918
# 381              NaN            NaN              NaN             NaN
# 395              NaN            NaN              NaN             NaN
#
#     phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0        Foraminifera           212476           Rhizaria
# 47                NaN           212476           Rhizaria
# 366           Myzozoa              NaN                NaN
# 381               NaN           212476           Rhizaria
# 395               NaN              NaN                NaN

# %%
higher_df[higher_df.duplicated(subset=['taxon_group', 'Any taxon above genus'])]
# Out:
# Empty DataFrame
# Columns: [taxon_group, Any taxon above genus, pbdb_taxon_id, pbdb_taxon_name, pbdb_taxon_rank, family_taxon_id, family_taxon_name, order_taxon_id, order_taxon_name, class_taxon_id, class_taxon_name, phylum_taxon_id, phylum_taxon_name, kingdom_taxon_id, kingdom_taxon_name]
# Index: []

# %%
higher_df[higher_df.duplicated(subset=['Any taxon above genus'])]
# Out:
#          taxon_group Any taxon above genus pbdb_taxon_id pbdb_taxon_name  \
# 381  dinoflagellates   Foraminifera indet.        288974    Foraminifera
# 531            other      Ostracoda indet.         22826       Ostracoda
# 559  planktic_forams        Bryozoa indet.         24773         Bryozoa
# 567  planktic_forams     Echinoidea indet.         32733      Echinoidea
# 569  planktic_forams          "Fish teeth"           NaN             NaN
# 608  planktic_forams      Ostracoda indet.         22826       Ostracoda
# 609  planktic_forams            "Otoliths"           NaN             NaN
# 620  planktic_forams     Radiolaria indet.             4      Radiolaria
#
#     pbdb_taxon_rank family_taxon_id family_taxon_name order_taxon_id  \
# 381          phylum             NaN               NaN            NaN
# 531           class             NaN               NaN            NaN
# 559          phylum             NaN               NaN            NaN
# 567           class             NaN               NaN            NaN
# 569             NaN             NaN               NaN            NaN
# 608           class             NaN               NaN            NaN
# 609             NaN             NaN               NaN            NaN
# 620          phylum             NaN               NaN            NaN
#
#     order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 381              NaN            NaN              NaN             NaN
# 531              NaN            NaN              NaN           18891
# 559              NaN            NaN              NaN             NaN
# 567              NaN            NaN              NaN           30739
# 569              NaN            NaN              NaN             NaN
# 608              NaN            NaN              NaN           18891
# 609              NaN            NaN              NaN             NaN
# 620              NaN            NaN              NaN             NaN
#
#     phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 381               NaN           212476           Rhizaria
# 531        Arthropoda           325038           Animalia
# 559               NaN           325038           Animalia
# 567     Echinodermata           325038           Animalia
# 569               NaN              NaN                NaN
# 608        Arthropoda           325038           Animalia
# 609               NaN              NaN                NaN
# 620               NaN           212476           Rhizaria

# %%
higher_df['Any taxon above genus edit'] = higher_df['Any taxon above genus'].replace(' indet.', '')

fetch_pdbd_data(higher_df, 'Any taxon above genus edit')
# Out:
# 0 "Fish scales"  not found
# "Fish teeth"  not found
# "Otoliths"  not found
# "Undifferentiated pollen from herbs"  not found
# "Undifferentiated pollen"  not found
# "Undifferentiated pollen from shrubs"  not found
# "Undifferentiated pollen from trees"  not found
# "Reworked palynomorphs"  not found
# "Undifferentiated spores from moss or ferns"  not found
# "Fish teeth"  not found
# "Otoliths"  not found

# %%
del higher_df['Any taxon above genus edit']
higher_df.drop_duplicates(inplace=True)

log_df(higher_df)
# 35
# Out:
# (35, 15)
#          taxon_group  Any taxon above genus pbdb_taxon_id pbdb_taxon_name  \
# 0     benthic_forams     Textulariia indet.        434530     Textulariia
# 47    benthic_forams    Foraminifera indet.        288974    Foraminifera
# 366  dinoflagellates  Dinoflagellata indet.        354791  Dinoflagellata
# 381  dinoflagellates    Foraminifera indet.        288974    Foraminifera
# 395  dinoflagellates     Dinophyceae indet.        321578     Dinophyceae
#
#     pbdb_taxon_rank family_taxon_id family_taxon_name order_taxon_id  \
# 0          subclass             NaN               NaN            NaN
# 47           phylum             NaN               NaN            NaN
# 366      superclass             NaN               NaN            NaN
# 381          phylum             NaN               NaN            NaN
# 395           class             NaN               NaN            NaN
#
#     order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0                NaN            NaN              NaN          288974
# 47               NaN            NaN              NaN             NaN
# 366              NaN            NaN              NaN          277918
# 381              NaN            NaN              NaN             NaN
# 395              NaN            NaN              NaN             NaN
#
#     phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0        Foraminifera           212476           Rhizaria
# 47                NaN           212476           Rhizaria
# 366           Myzozoa              NaN                NaN
# 381               NaN           212476           Rhizaria
# 395               NaN              NaN                NaN

# %%
higher_df.columns
# Out:
# Index(['taxon_group', 'Any taxon above genus', 'pbdb_taxon_id',
#        'pbdb_taxon_name', 'pbdb_taxon_rank', 'family_taxon_id',
#        'family_taxon_name', 'order_taxon_id', 'order_taxon_name',
#        'class_taxon_id', 'class_taxon_name', 'phylum_taxon_id',
#        'phylum_taxon_name', 'kingdom_taxon_id', 'kingdom_taxon_name'],
#       dtype='object')

# %%
higher_df.to_csv(higher_taxa_pbdb_file, index=False)

# %% [markdown]
# ## add higher pbdb to input_file

# %%
df = pd.read_csv(pi_taxa_file_pbdb,  dtype=str)
log_df(df)
# 695
# Out:
# (695, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                         Name                     Comment  \
# 0         Textulariia indet.                         NaN
# 1         Textulariia indet.                         NaN
# 2  Alabaminella weddellensis                         NaN
# 3              Alabamina sp.            genus misspelled
# 4  Alabaminella weddellensis  genus & species misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... order_taxon_name  \
# 0           NaN                NaN            NaN  ...              NaN
# 1           NaN                NaN            NaN  ...              NaN
# 2  Alabaminella                NaN            NaN  ...              NaN
# 3     Alabamina                NaN            NaN  ...              NaN
# 4  Alabaminella                NaN            NaN  ...              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN          288974      Foraminifera
# 1            NaN              NaN          288974      Foraminifera
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4            NaN              NaN          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 0           212476           Rhizaria                     NaN
# 1           212476           Rhizaria                     NaN
# 2           212476           Rhizaria                     NaN
# 3           212476           Rhizaria                     NaN
# 4           212476           Rhizaria                     NaN
#
#   unranked clade_taxon_name abbrev_genus
# 0                       NaN        False
# 1                       NaN        False
# 2                       NaN        False
# 3                       NaN        False
# 4                       NaN        False
#
# [5 rows x 33 columns]

# %%
higher_df = pd.read_csv(higher_taxa_pbdb_file, dtype=str)
log_df(higher_df)
# Out:
# (35, 15)
#        taxon_group  Any taxon above genus pbdb_taxon_id pbdb_taxon_name  \
# 0   benthic_forams     Textulariia indet.        434530     Textulariia
# 1   benthic_forams    Foraminifera indet.        288974    Foraminifera
# 2  dinoflagellates  Dinoflagellata indet.        354791  Dinoflagellata
# 3  dinoflagellates    Foraminifera indet.        288974    Foraminifera
# 4  dinoflagellates     Dinophyceae indet.        321578     Dinophyceae
#
#   pbdb_taxon_rank family_taxon_id family_taxon_name order_taxon_id  \
# 0        subclass             NaN               NaN            NaN
# 1          phylum             NaN               NaN            NaN
# 2      superclass             NaN               NaN            NaN
# 3          phylum             NaN               NaN            NaN
# 4           class             NaN               NaN            NaN
#
#   order_taxon_name class_taxon_id class_taxon_name phylum_taxon_id  \
# 0              NaN            NaN              NaN          288974
# 1              NaN            NaN              NaN             NaN
# 2              NaN            NaN              NaN          277918
# 3              NaN            NaN              NaN             NaN
# 4              NaN            NaN              NaN             NaN
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0      Foraminifera           212476           Rhizaria
# 1               NaN           212476           Rhizaria
# 2           Myzozoa              NaN                NaN
# 3               NaN           212476           Rhizaria
# 4               NaN              NaN                NaN

# %%
add_pbdb_data(df, higher_df, 'Any taxon above genus')

# %%
log_df(df)
# Out:
# (695, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
# 3  benthic_forams                          Alabammina sp.
# 4  benthic_forams               Alabamminella weddelensis
#
#                         Name                     Comment  \
# 0         Textulariia indet.                         NaN
# 1         Textulariia indet.                         NaN
# 2  Alabaminella weddellensis                         NaN
# 3              Alabamina sp.            genus misspelled
# 4  Alabaminella weddellensis  genus & species misspelled
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN    Textulariia indet.            NaN
# 1                                    NaN    Textulariia indet.            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#      genus name subgenera modifier subgenera name  ... order_taxon_name  \
# 0           NaN                NaN            NaN  ...              NaN
# 1           NaN                NaN            NaN  ...              NaN
# 2  Alabaminella                NaN            NaN  ...              NaN
# 3     Alabamina                NaN            NaN  ...              NaN
# 4  Alabaminella                NaN            NaN  ...              NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0            NaN              NaN          288974      Foraminifera
# 1            NaN              NaN          288974      Foraminifera
# 2            NaN              NaN          288974      Foraminifera
# 3            NaN              NaN          288974      Foraminifera
# 4            NaN              NaN          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 0           212476           Rhizaria                     NaN
# 1           212476           Rhizaria                     NaN
# 2           212476           Rhizaria                     NaN
# 3           212476           Rhizaria                     NaN
# 4           212476           Rhizaria                     NaN
#
#   unranked clade_taxon_name abbrev_genus
# 0                       NaN        False
# 1                       NaN        False
# 2                       NaN        False
# 3                       NaN        False
# 4                       NaN        False
#
# [5 rows x 33 columns]

# %%
df.to_csv(pi_taxa_file_pbdb, index=False)

# %% [markdown]
# ## add LIMS 4 to taxa crosswalk csv

# %%
existing_crosswalk = pd.read_csv(crosswalk_file, dtype=str)
log_df(existing_crosswalk, 3)
# 4593
# Out:
# (4593, 17)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor      normalized_name     taxon_group  \
# 0             NaN                 NaN   Euuvigerina miozea  benthic_forams
# 1             NaN                 NaN  Euuvigerina rodleyi  benthic_forams
# 2             NaN                 NaN  Foraminifera indet.  benthic_forams
#
#                        verbatim_name name comment field     Comment  \
# 0  Euuvigerina miozea (group) >100 m                NaN       group
# 1  Euuvigerina rodleyi (group) >50 m                NaN       group
# 2                             Others                NaN  not a taxa
#
#               Notes (change to Internal only notes?)  \
# 0  Summer 2020: enter "Euuvigerina miozea" and re...
# 1  Summer 2020: enter "Euuvigerina miozea" and re...
# 2                                               Andy
#
#                             comments
# 0  Euuvigerina miozea (group) >100 m
# 1  Euuvigerina rodleyi (group) >50 m
# 2         other benthic foraminifera

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)
df.rename(columns={'Name': 'name'}, inplace=True)
log_df(df, 3)
# 695
# Out:
# (695, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
#
#                         name Comment Notes (change to Internal only notes?)  \
# 0         Textulariia indet.     NaN                                    NaN
# 1         Textulariia indet.     NaN                                    NaN
# 2  Alabaminella weddellensis     NaN                                    NaN
#
#   Any taxon above genus genus modifier    genus name subgenera modifier  \
# 0    Textulariia indet.            NaN           NaN                NaN
# 1    Textulariia indet.            NaN           NaN                NaN
# 2                   NaN            NaN  Alabaminella                NaN
#
#   subgenera name  ... order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN  ...              NaN            NaN              NaN
# 1            NaN  ...              NaN            NaN              NaN
# 2            NaN  ...              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2          288974      Foraminifera           212476           Rhizaria
#
#   unranked clade_taxon_id unranked clade_taxon_name abbrev_genus
# 0                     NaN                       NaN        False
# 1                     NaN                       NaN        False
# 2                     NaN                       NaN        False
#
# [3 rows x 33 columns]

# %%
filtered_taxa = nt.create_taxa_crosswalk_df(df)
# (695, 17)
# (683, 17)
# (683, 17)
# Out:
# fields: ['Any taxon above genus', 'genus modifier', 'genus name', 'subgenera modifier', 'subgenera name', 'species modifier', 'species name', 'subspecies modifier', 'subspecies name', 'non-taxa descriptor', 'normalized_name', 'taxon_group', 'verbatim_name', 'name comment field', 'Comment', 'Notes (change to Internal only notes?)', 'comments']
# initial df:  (695, 17)
# remove nontaxa df:  (683, 17)
# drop duplicates df:  (683, 17)

# %%
existing_crosswalk.columns == filtered_taxa.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
combine_df = pd.concat([existing_crosswalk, filtered_taxa])
remove_whitespace(combine_df)

combine_df = combine_df.drop_duplicates()
combine_df.shape
# 5276
# Out:
# (5276, 17)

# %%
combine_df.drop_duplicates(subset=['normalized_name', 'taxon_group', 'verbatim_name'], 
                           keep='first', inplace=True)
log_df(combine_df)
# 5275
# Out:
# (5275, 17)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                                           Euuvigerina
# 1                                           Euuvigerina
# 2       Foraminifera indet.
# 3  Pleurostomellidae indet.
# 4          Ostracoda indet.
#
#   subgenera name species modifier species name subspecies modifier  \
# 0                                       miozea
# 1                                      rodleyi
# 2
# 3
# 4
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 0                                            Euuvigerina miozea
# 1                                           Euuvigerina rodleyi
# 2                                           Foraminifera indet.
# 3                                      Pleurostomellidae indet.
# 4                                              Ostracoda indet.
#
#       taxon_group                      verbatim_name name comment field  \
# 0  benthic_forams  Euuvigerina miozea (group) >100 m
# 1  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 2  benthic_forams                             Others
# 3  benthic_forams           Pleurostomellids comment
# 4  benthic_forams                     Ostracoda spp.     Ostracoda spp.
#
#            Comment             Notes (change to Internal only notes?)  \
# 0            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 1            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 2       not a taxa                                               Andy
# 3       not a taxa                                               Andy
# 4  group abundance  Summer 2020: go in as Ostracoda indet, and the...
#
#                             comments
# 0  Euuvigerina miozea (group) >100 m
# 1  Euuvigerina rodleyi (group) >50 m
# 2         other benthic foraminifera
# 3
# 4

# %%
combine_df.to_csv(crosswalk_file, index=False)

# %% [markdown]
# ## add LIMS 4 to taxa csv

# %%
existing_taxa = pd.read_csv(taxa_list_file, dtype=str)
log_df(existing_taxa, 3)
# 4153
# Out:
# (4153, 25)
#   Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                   NaN            NaN  Euuvigerina                NaN
# 1                   NaN            NaN  Euuvigerina                NaN
# 2   Foraminifera indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor  ... family_taxon_id family_taxon_name  \
# 0             NaN                 NaN  ...             NaN               NaN
# 1             NaN                 NaN  ...             NaN               NaN
# 2             NaN                 NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2             NaN               NaN           212476           Rhizaria
#
# [3 rows x 25 columns]

# %%
df = pd.read_csv(pi_taxa_file_pbdb, dtype=str)
log_df(df, 3)
# 695
# Out:
# (695, 33)
#       taxon_group                           verbatim_name  \
# 0  benthic_forams  Agglutinated Foram. gen. et sp. indet.
# 1  benthic_forams                     Agglutinated indet.
# 2  benthic_forams                Alabaminella weddelensis
#
#                         Name Comment Notes (change to Internal only notes?)  \
# 0         Textulariia indet.     NaN                                    NaN
# 1         Textulariia indet.     NaN                                    NaN
# 2  Alabaminella weddellensis     NaN                                    NaN
#
#   Any taxon above genus genus modifier    genus name subgenera modifier  \
# 0    Textulariia indet.            NaN           NaN                NaN
# 1    Textulariia indet.            NaN           NaN                NaN
# 2                   NaN            NaN  Alabaminella                NaN
#
#   subgenera name  ... order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN  ...              NaN            NaN              NaN
# 1            NaN  ...              NaN            NaN              NaN
# 2            NaN  ...              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0          288974      Foraminifera           212476           Rhizaria
# 1          288974      Foraminifera           212476           Rhizaria
# 2          288974      Foraminifera           212476           Rhizaria
#
#   unranked clade_taxon_id unranked clade_taxon_name abbrev_genus
# 0                     NaN                       NaN        False
# 1                     NaN                       NaN        False
# 2                     NaN                       NaN        False
#
# [3 rows x 33 columns]

# %%
filtered_taxa = nt.create_taxa_list_df(df)
# 695
# 683
# 607
# Out:
# fields: ['Any taxon above genus', 'genus modifier', 'genus name', 'subgenera modifier', 'subgenera name', 'species modifier', 'species name', 'subspecies modifier', 'subspecies name', 'non-taxa descriptor', 'normalized_name', 'taxon_group', 'pbdb_taxon_id', 'pbdb_taxon_name', 'pbdb_taxon_rank', 'family_taxon_id', 'family_taxon_name', 'order_taxon_id', 'order_taxon_name', 'class_taxon_id', 'class_taxon_name', 'phylum_taxon_id', 'phylum_taxon_name', 'kingdom_taxon_id', 'kingdom_taxon_name']
# initial df:  (695, 25)
# remove nontaxa df:  (683, 25)
# drop duplicates df:  (607, 25)

# %%
existing_taxa.columns == filtered_taxa.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
combine_df = pd.concat([existing_taxa, filtered_taxa])
remove_whitespace(combine_df)
combine_df = combine_df.drop_duplicates()

combine_df.shape
# 4606
# Out:
# (4606, 25)

# %%
check_multiple_pbdb_id(combine_df)
# Out:
# Empty DataFrame
# Columns: [pbdb_taxon_id, pbdb_taxon_name, pbdb_taxon_rank, family_taxon_id, family_taxon_name, order_taxon_id, order_taxon_name, class_taxon_id, class_taxon_name, phylum_taxon_id, phylum_taxon_name, kingdom_taxon_id, kingdom_taxon_name]
# Index: []

# %%
combine_df.to_csv(taxa_list_file, index=False)
