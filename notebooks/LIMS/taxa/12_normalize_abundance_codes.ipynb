# %% [markdown]
# # Normalize LIMS taxa

# %%
import sys
sys.path.append('../../../')
import glob
import re
import os.path
import hashlib
from pathlib import Path
import datetime

import pandas as pd
import numpy as np
import db as db

from config import CLEAN_DATA_DIR, OUTPUT_DIR, RAW_DATA_DIR

from scripts.normalize_data import (
    csv_cleanup,
    update_metadata,
    get_taxonomy_columns,
    clean_taxon_name,
    get_non_taxa_fields,
    remove_whitespace,
    normalize_abundance_codes
)
import scripts.normalize_taxa as nt
from scripts.shared_utils import (
    get_taxa_and_taxon_groups
)

# %%
metadata_file = OUTPUT_DIR/'metadata'/'LIMS'/'Micropal_changes.csv' 
# metadata_file = OUTPUT_DIR/'metadata'/'LIMS'/'Micropal_changes_4.csv'

normalized_fields_path =  OUTPUT_DIR/'normalized_data'/f'eODP_unified_data_structure_2022_02_21.csv'


clean_data_path = CLEAN_DATA_DIR

PI_additional_taxa_path = RAW_DATA_DIR/'PI_processed_files'/'LIMS_Micropal_CSV_4_taxa_ADDTL_TAXA.csv'
additional_taxa_path = OUTPUT_DIR/'taxa'/'LIMS'/'addtional_species.csv'
normalized_codes_path = RAW_DATA_DIR/'PI_processed_files'/'eODP Preservation Data v2.xlsx'


date = '2022-08-08'

crosswalk_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_crosswalk_{date}.csv"
taxa_list_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_list_{date}.csv"
PI_file = RAW_DATA_DIR/'PI_processed_files'/f'LIMS_Micropal_headers_PBDB_Taxonomy_notes_taxa_list_{date}.csv'

# %%
def log_df(df, row_count=5):
    print(df.shape)
    return df.head(row_count)

# %% [markdown]
# ## data QA

# %%
def create_report_df(rows):
    records = []
    for row in rows:
        data = {}
        for field, value in row.items():
            data[field] = value if value else np.nan
        records.append(data)

    records

    return pd.DataFrame(records)

# %% [markdown]
# ### files with multiple expeditions

# %%
sql = """
select samples.data_source_notes, 
 array_to_string(array_agg(distinct expeditions.name ), ', ') as exp,  
ARRAY_LENGTH( array_agg(distinct expeditions.name ), 1) as count
from  samples 
join sections on sections.id  = samples.section_id 
join cores on cores.id  = sections.core_id
join holes on holes.id  = cores.hole_id
join sites on sites.id = holes.site_id
join expeditions on expeditions.id = sites.expedition_id
group by samples.data_source_notes
having  ARRAY_LENGTH( array_agg(distinct expeditions.name ), 1)  > 1
;
"""
rows = db.fetch_all_dict(sql)

# %% [raw]
# BUG TODO

# %%
create_report_df(rows)
# Out:
#                                    data_source_notes  \
# 0    LIMS/Micropal_CSV_3/341_radiolarians_U1417A.csv
# 1  LIMS/Micropal_CSV_4/323_U1340A_benthic_forams.csv
#
#                                                  exp  count
# 0                                      341, 342, 343      3
# 1  323, 324, 325, 326, 327, 328, 329, 330, 331, 3...     68

# %% [markdown]
# ## create normalized abundance values files and save to database

# %%
def clean_value(value):
    if pd.isna(value):
        return 'NULL'
    
    value = value.replace("'", '"')
    return f"'{value}'" 

def create_records(df):
    for index, row in df.iterrows():
        if pd.isna(row["original_abundance"]):
            continue

        sql = f"""
        INSERT INTO public.abundance_crosswalk(original_abundance, expedition, taxon_group, 
            normalized_abundance, definition, notes, 
            type, created_at)  
        VALUES ({clean_value(row["original_abundance"])}, 
        {clean_value(row["expedition"])},
        {clean_value(row["taxon_group"])},
        {clean_value(row["normalized_abundance"])},
        {clean_value(row["definition"])},
        {clean_value(row["notes"])},
        {clean_value(row["type"])},
        '{datetime.datetime.now()}')
        """

        db.execute(sql);

# %% [markdown]
# ### taxa codes

# %%
df = pd.read_excel(normalized_codes_path, sheet_name='Abund.Code.NEW')
log_df(df)
# Out:
# (1109, 7)
#   code  expedition         taxon abundance value  \
# 0   2?         371  nannofossils              2?
# 1    ?         342  nannofossils               ?
# 2    ?         371  radiolarians               ?
# 3    ?         318       diatoms               ?
# 4   ??         318       diatoms               ?
#
#                           abundance unit Notes  \
# 0  count, undefined suggest questionable     ?
# 1                questionable occurrence     ?
# 2                questionable occurrence     ?
# 3                questionable occurrence     ?
# 4                questionable occurrence     ?
#
#    The PBDB has freeform text fields for "abundance":
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
cols = ['code', 'expedition', 'taxon', 'abundance value', 'abundance unit', 'Notes']
codes_df = pd.read_excel(normalized_codes_path, sheet_name='Abund.Code.NEW', usecols=cols, dtype=str)

log_df(codes_df)
# Out:
# (1109, 6)
#   code expedition         taxon abundance value  \
# 0   2?        371  nannofossils              2?
# 1    ?        342  nannofossils               ?
# 2    ?        371  radiolarians               ?
# 3    ?        318       diatoms               ?
# 4   ??        318       diatoms               ?
#
#                           abundance unit Notes
# 0  count, undefined suggest questionable     ?
# 1                questionable occurrence     ?
# 2                questionable occurrence     ?
# 3                questionable occurrence     ?
# 4                questionable occurrence     ?

# %%
data = {
    "code": "original_abundance", 
    "expedition": "expedition",
    "taxon": "taxon_group", 
    "abundance value": "normalized_abundance", 
    "abundance unit": "definition",
    "Notes": "notes"
}
codes_df.rename(columns=data, inplace=True)
codes_df['type'] = 'taxa'

log_df(codes_df)
# Out:
# (1109, 7)
#   original_abundance expedition   taxon_group normalized_abundance  \
# 0                 2?        371  nannofossils                   2?
# 1                  ?        342  nannofossils                    ?
# 2                  ?        371  radiolarians                    ?
# 3                  ?        318       diatoms                    ?
# 4                 ??        318       diatoms                    ?
#
#                               definition notes  type
# 0  count, undefined suggest questionable     ?  taxa
# 1                questionable occurrence     ?  taxa
# 2                questionable occurrence     ?  taxa
# 3                questionable occurrence     ?  taxa
# 4                questionable occurrence     ?  taxa

# %%
groups = list(codes_df['taxon_group'].unique())
groups.sort()
groups
# Out:
# ['benthic_forams',
#  'bolboformids',
#  'chrysophyte_cysts',
#  'diatoms',
#  'dinoflagellates',
#  'ebridians',
#  'nannofossils',
#  'ostracods',
#  'palynology',
#  'planktic_forams',
#  'radiolarians',
#  'silicoflagellates']

# %%
# create_records(codes_df)

# %%
codes_df.to_csv(OUTPUT_DIR/'normalized_data'/'abundance_codes_taxa.csv', index=False)

# %% [markdown]
# ### group codes

# %%
df = pd.read_excel(normalized_codes_path, sheet_name='Group Abund Code', dtype=str)
log_df(df)
# Out:
# (770, 10)
#    Exp             Group (from pres) Group Code Code Definition  \
# 0  323        Preservation (diatoms)       20.8  NaN        NaN
# 1  323        Preservation (diatoms)      30.48  NaN        NaN
# 2  382               (benthic foram)          B    B     barren
# 3  383               (benthic foram)          B    B     barren
# 4  327  Preservation (benthic foram)          F  NaN        NaN
#
#   abundant', 'common', 'few', 'rare'  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   This is a rough placeholder for the Group (using Pres info)  \
# 0                            Depth/age in wrong spot
# 1                            Depth/age in wrong spot
# 2                                                NaN
# 3                                                NaN
# 4  I think there's something wrong w/ the Exp num...
#
#   Extracted from heterogeneous "group abundance"-related Field at collection level  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unnamed: 8  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
#   This would go in PBDB.collections.abund_in_sediment, which is standardized:
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
cols = ['Exp', 'Group (from pres)', 'Group Code', 'Code', 'Definition', 
        'This is a rough placeholder for the Group (using Pres info)']
codes_df = pd.read_excel(normalized_codes_path, sheet_name='Group Abund Code', usecols=cols, dtype=str)

log_df(codes_df)
# Out:
# (770, 6)
#    Exp             Group (from pres) Group Code Code Definition  \
# 0  323        Preservation (diatoms)       20.8  NaN        NaN
# 1  323        Preservation (diatoms)      30.48  NaN        NaN
# 2  382               (benthic foram)          B    B     barren
# 3  383               (benthic foram)          B    B     barren
# 4  327  Preservation (benthic foram)          F  NaN        NaN
#
#   This is a rough placeholder for the Group (using Pres info)
# 0                            Depth/age in wrong spot
# 1                            Depth/age in wrong spot
# 2                                                NaN
# 3                                                NaN
# 4  I think there's something wrong w/ the Exp num...

# %%
data = {
    "Exp": "expedition",
    "Group (from pres)": "taxon_group", 
    "Group Code": "original_abundance", 
    "Code": "normalized_abundance", 
    "Definition": "definition",
    "This is a rough placeholder for the Group (using Pres info)": "notes"
}
codes_df.rename(columns=data, inplace=True)
codes_df['type'] = 'taxa'

log_df(codes_df)
# Out:
# (770, 7)
#   expedition                   taxon_group original_abundance  \
# 0        323        Preservation (diatoms)               20.8
# 1        323        Preservation (diatoms)              30.48
# 2        382               (benthic foram)                  B
# 3        383               (benthic foram)                  B
# 4        327  Preservation (benthic foram)                  F
#
#   normalized_abundance definition  \
# 0                  NaN        NaN
# 1                  NaN        NaN
# 2                    B     barren
# 3                    B     barren
# 4                  NaN        NaN
#
#                                                notes  type
# 0                            Depth/age in wrong spot  taxa
# 1                            Depth/age in wrong spot  taxa
# 2                                                NaN  taxa
# 3                                                NaN  taxa
# 4  I think there's something wrong w/ the Exp num...  taxa

# %%
codes_df['taxon_group'].unique()
# Out:
# array(['Preservation (diatoms)', '(benthic foram)',
#        'Preservation (benthic foram)', 'Preservation (nannos)', '(rads)',
#        'Preservation (planktic foram)',
#        'Diatom preservation dissolution (diatoms)', '(planktic foram)',
#        'BF preservation (benthic foram)',
#        'PF preservation (planktic foram)', 'Preservation (rads)',
#        'Group preservation (palynology)',
#        'PF Preservation (planktic foram)', '(nannos)',
#        'Preservation (ebridians)', 'Preservation (silicoflag)',
#        '(diatoms)', '(silicoflag)', '(ebridians)', nan, '(palynology)'],
#       dtype=object)

# %%
groups_dict = {
    'Preservation (diatoms)': 'diatoms', 
    '(benthic foram)': 'benthic_forams',
    'Preservation (benthic foram)': 'benthic_forams', 
    'Preservation (nannos)': 'nannofossils', 
    '(rads)': 'radiolarians',
    'Preservation (planktic foram)': 'planktic_forams',
    'Diatom preservation dissolution (diatoms)': 'diatoms', 
    '(planktic foram)': 'planktic_forams',
    'BF preservation (benthic foram)': 'benthic_forams',
    'PF preservation (planktic foram)': 'planktic_forams', 
    'Preservation (rads)': 'radiolarians',
    'Group preservation (palynology)': 'palynology',
    'PF Preservation (planktic foram)': 'planktic_forams', 
    '(nannos)': 'nannofossils',
    'Preservation (ebridians)': 'ebridians', 
    'Preservation (silicoflag)': 'silicoflagellates',
    '(diatoms)': 'diatoms', 
    '(silicoflag)': 'silicoflagellates', 
    '(ebridians)': 'ebridians', 
    '(palynology)': 'palynology'   
}

codes_df['type'] = 'groups'

for old, new in groups_dict.items():
    codes_df.loc[codes_df['taxon_group'] == old, 'taxon_group'] = new

# %%
groups = list(codes_df['taxon_group'].dropna().unique())
groups.sort()
groups
# Out:
# ['benthic_forams',
#  'diatoms',
#  'ebridians',
#  'nannofossils',
#  'palynology',
#  'planktic_forams',
#  'radiolarians',
#  'silicoflagellates']

# %%
# create_records(codes_df)

# %%
codes_df.to_csv(OUTPUT_DIR/'normalized_data'/'abundance_codes_groups.csv', index=False)

# %% [markdown]
# ## abundance codes QA

# %%
sql = """
select original_abundance, 
array_agg(distinct normalized_abundance) as normalized_abundance, 
taxon_group,
expedition,  
type,
array_length(array_agg(distinct normalized_abundance), 1)
from abundance_crosswalk
group by original_abundance, taxon_group, expedition, type
having array_length(array_agg(distinct normalized_abundance), 1) > 1;
"""

# TODO BUG: 'A' maps to multiple abundances

rows = db.fetch_all_dict(sql)
create_report_df(rows)
# Out:
#   original_abundance normalized_abundance taxon_group expedition    type  \
# 0                  A             [A, A-D]  palynology        339  groups
#
#    array_length
# 0             2

# %%
sql = """
select original_abundance, 
array_agg(distinct normalized_abundance) as normalized_abundance, 
array_agg(taxon_group) as taxon_group,
expedition, 
type,
array_length(array_agg(distinct normalized_abundance), 1)
from abundance_crosswalk
group by original_abundance, expedition, type
having array_length(array_agg(distinct normalized_abundance), 1) > 1;
"""

rows = db.fetch_all_dict(sql)
create_report_df(rows)
# Out:
#   original_abundance normalized_abundance  \
# 0                  A             [A, A-D]
# 1                  F            [F, Freq]
# 2                  F               [F, R]
# 3                  F            [F, Freq]
# 4                  F            [F, Freq]
# 5                  P            [P, None]
# 6                  P            [P, None]
# 7                  X               [P, X]
# 8                 rw              [*, rw]
#
#                                          taxon_group expedition    type  \
# 0  [benthic_forams, planktic_forams, benthic_fora...        339  groups
# 1    [nannofossils, benthic_forams, planktic_forams]        324    taxa
# 2       [radiolarians, benthic_forams, nannofossils]        349  groups
# 3            [benthic_forams, diatoms, radiolarians]        374  groups
# 4  [planktic_forams, ebridians, diatoms, radiolar...        374    taxa
# 5         [benthic_forams, diatoms, planktic_forams]        323  groups
# 6    [nannofossils, planktic_forams, benthic_forams]        369  groups
# 7  [ebridians, diatoms, radiolarians, dinoflagell...        374    taxa
# 8                               [diatoms, ebridians]        374    taxa
#
#    array_length
# 0             2
# 1             2
# 2             2
# 3             2
# 4             2
# 5             2
# 6             2
# 7             2
# 8             2

# %%
sql = """
select original_abundance, 
array_agg(distinct normalized_abundance) as normalized_abundance, 
taxon_group,
array_agg(expedition) as expedition, 
type,
array_length(array_agg(distinct normalized_abundance), 1)
from abundance_crosswalk
group by original_abundance, taxon_group , type
having array_length(array_agg(distinct normalized_abundance), 1) > 1;
"""

rows = db.fetch_all_dict(sql)
create_report_df(rows)
# Out:
#    original_abundance normalized_abundance        taxon_group  \
# 0                   A            [A, None]     benthic_forams
# 1                   A             [A, A-D]         palynology
# 2                   F         [F, R, None]     benthic_forams
# 3                   F            [F, Freq]            diatoms
# 4                   F            [F, Freq]            diatoms
# 5                   F            [F, Freq]       nannofossils
# 6                   F            [F, Freq]       nannofossils
# 7                   F            [F, Freq]       radiolarians
# 8                   F            [F, Freq]       radiolarians
# 9                   P            [P, None]     benthic_forams
# 10                  P            [P, None]            diatoms
# 11                  P            [P, None]       nannofossils
# 12                  R            [R, None]     benthic_forams
# 13                  T               [T, X]            diatoms
# 14                  V              [V, VA]       nannofossils
# 15                  X               [P, X]            diatoms
# 16                  X               [P, X]    planktic_forams
# 17                  X               [P, X]  silicoflagellates
#
#                                            expedition    type  array_length
# 0   [330, 375, 351, 374, 342, 371, 339, 339, 341, ...  groups             2
# 1                                          [339, 339]  groups             2
# 2   [341, 374, 356, 342, 317, 323, 329, 342, 340, ...  groups             3
# 3   [318, 317, 368, 323, 341, 346, 355, 346, 353, ...  groups             2
# 4   [374, 346, 362, 341, 353, 361, 355, 318, 368, ...    taxa             2
# 5   [369, 368, 350, 342, 367, 324, 363, 344, 346, ...  groups             2
# 6   [320, 355, 330, 359, 371, 375, 342, 367, 368, ...    taxa             2
# 7   [371, 362, 359, 349, 374, 346, 323, 320, 342, ...  groups             2
# 8   [349, 361, 341, 356, 355, 362, 344, 323, 321, ...    taxa             2
# 9   [339, 375, 341, 374, 360, 371, 371, 369, 356, ...  groups             2
# 10                                         [317, 323]  groups             2
# 11                                    [369, 339, 349]  groups             2
# 12  [346, 323, 363, 342, 361, 341, 346, 354, 390, ...  groups             2
# 13                                         [321, 318]    taxa             2
# 14           [363, 355, 356, 353, 350, 369, 354, 352]    taxa             2
# 15                          [361, 317, 355, 355, 318]  groups             2
# 16                                         [375, 361]    taxa             2
# 17                                         [374, 318]    taxa             2

# %% [markdown]
# ## Update taxa abundances

# %%
metadata = pd.read_csv(metadata_file, dtype=str)
log_df(metadata)
# Out:
# (1253, 16)
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#   change_file_encoding remove_bad_characters remove_empty_rows remove_spaces  \
# 0                False                 False             False          True
# 1                False                 False             False          True
# 2                False                 False             False          True
# 3                False                 False             False          True
# 4                False                 False             False         False
#
#   delete_duplicate_rows delete_duplicate_columns add_expedition_section_cols  \
# 0                 False                    False                        True
# 1                 False                    False                       False
# 2                 False                    False                        True
# 3                 False                    False                       False
# 4                 False                    False                       False
#
#   update_sample_col update_top_bottom add_missing_cols clean_up_taxa_values  \
# 0             False             False            False                False
# 1              True             False            False                False
# 2             False             False            False                False
# 3              True             False            False                False
# 4              True             False            False                False
#
#   clean_up_taxa_metadata_values split_dextral_sinistral
# 0                          True                   False
# 1                         False                   False
# 2                         False                   False
# 3                         False                   False
# 4                         False                   False

# %%
taxa_df = pd.read_csv(crosswalk_file, dtype=str)
log_df(taxa_df)
# Out:
# (5281, 18)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 0             NaN                 NaN        Euuvigerina miozea
# 1             NaN                 NaN       Euuvigerina rodleyi
# 2             NaN                 NaN       Foraminifera indet.
# 3             NaN                 NaN  Pleurostomellidae indet.
# 4             NaN                 NaN          Ostracoda indet.
#
#       taxon_group                      verbatim_name name comment field  \
# 0  benthic_forams  Euuvigerina miozea (group) >100 m                NaN
# 1  benthic_forams  Euuvigerina rodleyi (group) >50 m                NaN
# 2  benthic_forams                             Others                NaN
# 3  benthic_forams           Pleurostomellids comment                NaN
# 4  benthic_forams                     Ostracoda spp.     Ostracoda spp.
#
#            Comment             Notes (change to Internal only notes?)  \
# 0            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 1            group  Summer 2020: enter "Euuvigerina miozea" and re...
# 2       not a taxa                                               Andy
# 3       not a taxa                                               Andy
# 4  group abundance  Summer 2020: go in as Ostracoda indet, and the...
#
#                      comments eodp_id
# 0                >100 m group       0
# 1                 >50 m group       1
# 2  other benthic foraminifera       2
# 3                         NaN       3
# 4                         NaN       4

# %%
verbatim_names_taxon_groups = get_taxa_and_taxon_groups(taxa_df)
len(verbatim_names_taxon_groups)
# Out:
# 5269

# %%
verbatim_names = set(taxa_df['verbatim_name'])
len(verbatim_names)
# Out:
# 5269

# %%
set(verbatim_names_taxon_groups) - set(verbatim_names)
# Out:
# set()

# %%
cols = ['original_abundance', 'expedition', 'taxon_group', 'normalized_abundance']
codes_taxa_df = pd.read_csv(OUTPUT_DIR/'normalized_data'/'abundance_codes_taxa.csv', usecols=cols, dtype=str)

log_df(codes_taxa_df)
# Out:
# (1109, 4)
#   original_abundance expedition   taxon_group normalized_abundance
# 0                 2?        371  nannofossils                   2?
# 1                  ?        342  nannofossils                    ?
# 2                  ?        371  radiolarians                    ?
# 3                  ?        318       diatoms                    ?
# 4                 ??        318       diatoms                    ?

# %%
set(codes_taxa_df['taxon_group']) - set(metadata['taxon_groups'])
# Out:
# set()

# %%
set(metadata['taxon_groups']) - set(codes_taxa_df['taxon_group'])
# Out:
# {'other'}

# %%
change_columns = []
for index, row in metadata.iterrows():
    path = Path(CLEAN_DATA_DIR/row['path'])
    df = pd.read_csv(path, dtype=str)
    res = normalize_abundance_codes(df, row['taxon_groups'], codes_taxa_df, 
                                    verbatim_names_taxon_groups, row['path']) 
    
    if res['changed']:
        content = csv_cleanup(res['df'], path)
        content.to_csv(path, index=False)
        
    change_columns.append(res['changed'])
# Out:
# multiple expeditions:  LIMS/Micropal_CSV_4/320_U1336B_108_T10_planktic forams.csv ['320' nan]

# %%
dict = {"update_taxa_abundances": change_columns}
new_metadata = update_metadata(metadata, dict)
new_metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#   change_file_encoding remove_bad_characters remove_empty_rows remove_spaces  \
# 0                False                 False             False          True
# 1                False                 False             False          True
# 2                False                 False             False          True
# 3                False                 False             False          True
# 4                False                 False             False         False
#
#   delete_duplicate_rows delete_duplicate_columns add_expedition_section_cols  \
# 0                 False                    False                        True
# 1                 False                    False                       False
# 2                 False                    False                        True
# 3                 False                    False                       False
# 4                 False                    False                       False
#
#   update_sample_col update_top_bottom add_missing_cols clean_up_taxa_values  \
# 0             False             False            False                False
# 1              True             False            False                False
# 2             False             False            False                False
# 3              True             False            False                False
# 4              True             False            False                False
#
#   clean_up_taxa_metadata_values split_dextral_sinistral  \
# 0                          True                   False
# 1                         False                   False
# 2                         False                   False
# 3                         False                   False
# 4                         False                   False
#
#    update_taxa_abundances
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
