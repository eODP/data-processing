# %% [markdown]
# # Normalize non-taxa fields

# %% [markdown]
# Normalize the final list of non-taxa fields from eODP researchers.

# %%
import sys
sys.path.append('../../../')
import glob
import re
import os.path

import pandas as pd
import numpy as np

from config import CLEAN_DATA_DIR, OUTPUT_DIR, RAW_DATA_DIR

from scripts.normalize_data import (
    csv_cleanup,
    get_non_taxa_fields,
    update_metadata
)
from scripts.shared_utils import (
    log_df
)

# %%
date = '2022-08-08'
crosswalk_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_crosswalk_{date}.csv"
taxa_list_file = OUTPUT_DIR/'taxa'/'LIMS'/f"taxa_list_{date}.csv"
taxa_list_path = OUTPUT_DIR /'taxa'/'LIMS'/f'PI_normalized_taxa_list_with_pbdb_{date}.csv'
metadata_file = OUTPUT_DIR/'metadata'/'LIMS'/'Micropal_changes.csv' 

date = '2022-08-30'
input_normalized_fields_path = RAW_DATA_DIR/'PI_processed_files'/f'eODP unified data structure_{date}.csv'
normalized_fields_path =  OUTPUT_DIR/'normalized_data'/'LIMS'/f'unified_data_structure_{date}.csv'
nontaxa_fields_path =  OUTPUT_DIR/'normalized_data'/'LIMS'/f'nontaxa_fields_{date}.csv'

# %% [markdown]
# ## create nontaxa file

# %%
nontaxa_df = pd.read_csv(input_normalized_fields_path, dtype=str, header=5)
log_df(nontaxa_df)
# Out:
# (578, 12)
#   category  normalized lithology_1-96 lithology_101-126 lithology_317-present  \
# 0   common      Sample            NaN               NaN      Label ID; Sample
# 1      NaN  Expedition            leg               leg                   Exp
# 2      NaN        Site           site              site                  Site
# 3      NaN        Hole           hole              hole                  Hole
# 4      NaN        Core           core              core                  Core
#
#   taxa_1-96 taxa_101-210 taxa_317-present-b  taxa_317-present age_models_1-96  \
# 0       NaN          NaN                NaN  Label ID; Sample             NaN
# 1       leg          Leg    Exp; Expedition               Exp             leg
# 2      site         Site               Site              Site            site
# 3      hole            H               Hole              Hole            hole
# 4      core          Cor               Core              Core             NaN
#
#   age_models_101-190 hard_rocks_2-94
# 0                NaN             NaN
# 1                Leg             leg
# 2               Site            site
# 3                  H            hole
# 4                NaN            core

# %%
row_index = nontaxa_df.index[nontaxa_df['category']=='original column names'].to_list()[0]
row_index
# Out:
# 163

# %%
nontaxa_df = nontaxa_df.drop(index=list(range(row_index, len(nontaxa_df))))

# %%
nontaxa_df = nontaxa_df.dropna(how='all', axis=0)
nontaxa_df.tail()
# Out:
#     category          normalized lithology_1-96 lithology_101-126  \
# 152      NaN                 IRD            NaN               NaN
# 153      NaN       Fragmentation            NaN               NaN
# 154      NaN  Fragmentation rank            NaN               NaN
# 155      NaN      Organic matter            NaN               NaN
# 156      NaN     Sponge spicules            NaN               NaN
#
#     lithology_317-present taxa_1-96 taxa_101-210 taxa_317-present-b  \
# 152                   NaN       NaN          NaN                IRD
# 153                   NaN       NaN          NaN                NaN
# 154                   NaN       NaN          NaN                NaN
# 155                   NaN       NaN          NaN                NaN
# 156                   NaN       NaN          NaN                NaN
#
#                                taxa_317-present age_models_1-96  \
# 152                                         NaN             NaN
# 153                               Fragmentation             NaN
# 154               Fragmentation rank [auto-pop]             NaN
# 155  Organic matter; Terrestrial organic matter             NaN
# 156                             Sponge spicules             NaN
#
#     age_models_101-190 hard_rocks_2-94
# 152                NaN             NaN
# 153                NaN             NaN
# 154                NaN             NaN
# 155                NaN             NaN
# 156                NaN             NaN

# %%
nontaxa_df.to_csv(normalized_fields_path, index=False)

# %% [markdown]
# ## create nontaxa file that will be imported  into database

# %%
cols = ['normalized', 'taxa_317-present-b', 'taxa_317-present']
df = pd.read_csv(normalized_fields_path, dtype=str, usecols = cols)
log_df(df)
# 150
# Out:
# (150, 3)
#    normalized taxa_317-present-b  taxa_317-present
# 0      Sample                NaN  Label ID; Sample
# 1  Expedition    Exp; Expedition               Exp
# 2        Site               Site              Site
# 3        Hole               Hole              Hole
# 4        Core               Core              Core

# %%
ignore_fields = [
    'Sample',
    'Expedition',
    'Site',
    'Hole',
    'Core',
    'Core Type',
    'Section',
    'A/W',
    'Extra Sample ID Data',
    'Top [cm]',
    'Bottom [cm]',
    'Top Depth [m]',
    'Bottom Depth [m]',
]

# %%
data = []
old_new_fields = set()

def process_column(column):
    if pd.notna(row[column]):
        for field in row[column].split('; '):
            name = field + "|" + row['normalized']
            if name not in old_new_fields:
                data.append({"original_name": field, "name": row['normalized'], 
                             "dataset": "LIMS", "dataset_type": "taxa"})
                old_new_fields.add(name)

for index, row in df.iterrows():
    if row['normalized'] not in ignore_fields:
        process_column('taxa_317-present')
        process_column('taxa_317-present-b')

# %%
nontaxa_df = pd.DataFrame(data)
log_df(nontaxa_df)
# 144
# Out:
# (144, 4)
#                          original_name                                 name  \
# 0     Top Offset (cm) on Parent Sample     Top Offset (cm) on Parent Sample
# 1  Bottom Offset (cm) on Parent Sample  Bottom Offset (cm) on Parent Sample
# 2                    mean depth (mbsf)                    mean depth (mbsf)
# 3      (taxon names are in the header)                           Taxon Name
# 4                            Abundance                      Group abundance
#
#   dataset dataset_type
# 0    LIMS         taxa
# 1    LIMS         taxa
# 2    LIMS         taxa
# 3    LIMS         taxa
# 4    LIMS         taxa

# %%
nontaxa_df.to_csv(nontaxa_fields_path, index=False)

# %% [markdown]
# ## QA normlized fields
#
# ### look for files where multiple columns map to the same normalized column name

# %%
metadata = pd.read_csv(metadata_file)
log_df(metadata)
# Out:
# (1253, 17)
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral  update_group_abundances
# 0                    False                     True
# 1                    False                     True
# 2                    False                     True
# 3                    False                     True
# 4                    False                    False

# %%
cols = ['normalized', 'taxa_317-present-b', 'taxa_317-present']
df = pd.read_csv(normalized_fields_path, dtype=str, usecols = cols)
log_df(df)
# 150
# Out:
# (150, 3)
#    normalized taxa_317-present-b  taxa_317-present
# 0      Sample                NaN  Label ID; Sample
# 1  Expedition    Exp; Expedition               Exp
# 2        Site               Site              Site
# 3        Hole               Hole              Hole
# 4        Core               Core              Core

# %%
def process_columns(columns):
    old_new_dict = {}
    for column in columns:
        old_new_dict = {**old_new_dict, **get_non_taxa_fields(df, column)}
        
    return old_new_dict

columns = ['taxa_317-present', 'taxa_317-present-b']
old_new_dict = process_columns(columns)
old_fields = list(old_new_dict.keys())
len(old_fields)
# 162
# Out:
# 162

# %%
# old_new_dict

# %%
for index, row in metadata.iterrows():
    path = f"{CLEAN_DATA_DIR}/{row['path']}"
    df = pd.read_csv(path, dtype=str)
    df = df.dropna(axis=1, how="all")
    df = df.dropna(axis=0, how="all")
    
    nontaxa_cols = set(df.columns).intersection(old_fields)
    
    new_fields = set()
    for col in nontaxa_cols:
        new_field = old_new_dict[col]
        if new_field in new_fields:
            if 'comment' not in new_field.lower():
                print(row['file'], ',', col, ',', new_field)
                print('----')
        else:
            new_fields.add(new_field)
# Out:
# 363-U1488A-planktic_forams.csv , Additional zone name , Sample Zone
# ----
# 363-U1488A-planktic_forams.csv , Additional zone name (short) , Sample Zone (short)
# ----
# 363-U1482B-planktic_forams.csv , Additional zone name , Sample Zone
# ----
# 363-U1482B-planktic_forams.csv , Additional zone name (short) , Sample Zone (short)
# ----
# 363-U1490A-planktic_forams.csv , Additional zone name , Sample Zone
# ----
# 363-U1490A-planktic_forams.csv , Additional zone name (short) , Sample Zone (short)
# ----
# 363-U1483A-planktic_forams.csv , Additional zone name , Sample Zone
# ----
# 363-U1483A-planktic_forams.csv , Additional zone name (short) , Sample Zone (short)
# ----
# 363-U1489C-planktic_forams.csv , Additional zone name , Sample Zone
# ----
# 363-U1489C-planktic_forams.csv , Additional zone name (short) , Sample Zone (short)
# ----
# 363-U1489B-planktic_forams.csv , Additional zone name , Sample Zone
# ----
# 363-U1489B-planktic_forams.csv , Additional zone name (short) , Sample Zone (short)
# ----
# 363-U1489D-planktic_forams.csv , Additional zone name , Sample Zone
# ----
# 363-U1489D-planktic_forams.csv , Additional zone name (short) , Sample Zone (short)
# ----
# 350_U1437D_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 354_U1449A_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 356-U1462C_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 354_U1451A_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 351_U1438B_nannofossils.csv , Datum name , Sample Datum name
# ----
# 350_U1437B_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 350_U1437B_planktic_forams.csv , Upper boundary age av. [Ma] , Datum region
# ----
# 356-U1462A_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 350_U1436C_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 356-U1463B_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 356-U1463C_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 350_U1436A_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 351_U1438D_nannofossils.csv , Datum name , Sample Datum name
# ----
# 355_U1457C_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 346_U1425B_radiolarians_events.csv , Datum name , Sample Datum name
# ----
# 356-U1464B_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 356-U1463B_benthic_forams.csv , Datum name , Sample Datum name
# ----
# 356-U1461B_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 351_U1438E_nannofossils.csv , Datum name , Sample Datum name
# ----
# 355_U1456C_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 356-U1461D_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 356-U1464D_planktic_forams.csv , Datum name , Sample Datum name
# ----
# 317_U1352_planktic_forams.csv , Foraminiferal abundance , Planktic Foraminifera abundance
# ----
# 317_U1353_planktic_forams.csv , Foraminiferal abundance , Planktic Foraminifera abundance
# ----
# 317_U1351_planktic_forams.csv , Foraminiferal abundance , Planktic Foraminifera abundance
# ----
# 317_U1354_planktic_forams.csv , Planktic foraminiferal (%) , Planktic Foraminifera abundance
# ----

# %% [markdown]
# ### compare the list of all column, all taxa columns, and all nontaxa columns

# %%
all_columns_file = OUTPUT_DIR/'tmp/all_LIMS_taxa_columns.csv'
all_df = pd.read_csv(all_columns_file)

all_columns = set(all_df['column'])
len(all_columns)
# 5554
# Out:
# 5554

# %%
non_taxa_df = pd.read_csv(nontaxa_fields_path)

non_taxa = set(non_taxa_df['original_name'])
len(non_taxa)
# 131
# Out:
# 131

# %%
taxa_df = pd.read_csv(crosswalk_file)

taxa = set(taxa_df['verbatim_name'])
len(taxa)
# 5368
# Out:
# 5368

# %%
all_columns - taxa - non_taxa
# Out:
# {'342-U1408A-2H-2-W 100/102-FORAM',
#  'A/W',
#  'ADDITIONAL SPECIES',
#  'Bottom Depth [m]',
#  'Bottom [cm]',
#  'Core',
#  'Core Type - Section',
#  'Core,    section',
#  'Core, Section',
#  'Core, Section, Interval',
#  'Core, Type, Section',
#  'Core, section',
#  'Core, section, interval',
#  'Core, section, interval (cm)',
#  'Core-Sect',
#  'Datum group',
#  'Datum group code',
#  'Depth (cm)',
#  'Depth Method',
#  'Dextral:Sinistral _N. acostaensis_',
#  'Dextral:Sinistral _P. finalis_',
#  'Dextral:Sinistral _P. obliquiloculata_',
#  'Dextral:Sinistral _P. praecursor_',
#  'Dextral:Sinistral _P. praespectabilis_',
#  'Dextral:Sinistral _P. primalis_',
#  'Dextral:Sinistral _P. spectabilis_',
#  'Diatom preservation - pyritization2',
#  'Exp',
#  'Expedition, site, hole, core, section, interval (cm):',
#  'Extra Sample ID Data',
#  'File Data',
#  'Gen. et sp. indet',
#  'Half',
#  'Hole',
#  'Hole, Core, Section',
#  'Labl ID',
#  'Marine',
#  'Original Bottom Depth (m)',
#  'Original Top Depth (m)',
#  'Piece',
#  'Sample',
#  'Section',
#  'Section Half',
#  'Secton Half',
#  'Ship File Links',
#  'Shore File Links',
#  'Site',
#  'Top Depth [m]',
#  'Top [cm]',
#  'Type',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Zone group',
#  'Zone name [short]',
#  'constituent',
#  'core, section',
#  'dupes and comments',
#  'eodp_id',
#  'fossil',
#  'fossil_group',
#  'interval (cm)',
#  'pc_abundance_name_mode',
#  'pc_fossil_group',
#  'pc_fossil_name',
#  'physical_constituent_name'}

# %% [markdown]
# ## Normalize non-taxa fields in data files
# Use the normalized non taxa fields from the PIs to update the non-taxa fields in the data files.

# %%
metadata = pd.read_csv(metadata_file)
log_df(metadata)
# Out:
# (1253, 17)
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral  update_group_abundances
# 0                    False                     True
# 1                    False                     True
# 2                    False                     True
# 3                    False                     True
# 4                    False                    False

# %%
cols = ['normalized', 'taxa_317-present-b', 'taxa_317-present']
non_taxa_df = pd.read_csv(normalized_fields_path, dtype=str, usecols = cols)
log_df(non_taxa_df)
# Out:
# (131, 3)
#    normalized taxa_317-present-b   taxa_317-present
# 0      Sample                NaN  Label ID | Sample
# 1  Expedition   Exp | Expedition                Exp
# 2        Site               Site               Site
# 3        Hole               Hole               Hole
# 4        Core               Core               Core

# %%
non_taxa_dict = get_non_taxa_fields(non_taxa_df, 'taxa_317-present')
non_taxa_list = set(non_taxa_dict.keys())

# %%
def normalize_non_taxa(file):
    path = f"{CLEAN_DATA_DIR}/{file}"
    content = pd.read_csv(path)
    
    nontaxa_cols = set(content.columns).intersection(non_taxa_list)
    
    rename_dict = {}
    old_columns = list(content.columns)
    for col in nontaxa_cols:
        rename_dict[col] = non_taxa_dict[col]
        
    content.rename(columns = rename_dict, inplace=True)
    
    changed = list(content.columns) != list(old_columns)

    if changed:
        content = csv_cleanup(content, path)
        content.to_csv(path, index=False)
    return changed
    
# change_columns = [normalize_non_taxa(file) for file in metadata['path']] 

change_columns = []

# %%
dict = {"normalize_non_taxa": change_columns}
new_metadata = update_metadata(metadata, dict)
new_metadata.head()
# Out:
#                              file  \
# 0   363-U1482A-Benthic_Forams.csv
# 1   320_U1336A_Nannofossils_2.csv
# 2  375_U1518F_planktic_forams.csv
# 3   320_U1334A_Nannofossils_1.csv
# 4       318_U1358B_Palynology.csv
#
#                                                 path     taxon_groups  \
# 0  LIMS/Micropal_CSV_1/363-U1482A-Benthic_Forams.csv   benthic_forams
# 1  LIMS/Micropal_CSV_1/320_U1336A_Nannofossils_2.csv     nannofossils
# 2  LIMS/Micropal_CSV_1/375_U1518F_planktic_forams...  planktic_forams
# 3  LIMS/Micropal_CSV_1/320_U1334A_Nannofossils_1.csv     nannofossils
# 4      LIMS/Micropal_CSV_1/318_U1358B_Palynology.csv       palynology
#
#    change_file_encoding  remove_bad_characters  remove_empty_rows  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
#
#    remove_spaces  delete_duplicate_rows  delete_duplicate_columns  \
# 0           True                  False                     False
# 1           True                  False                     False
# 2           True                  False                     False
# 3           True                  False                     False
# 4          False                  False                     False
#
#    add_expedition_section_cols  update_sample_col  update_top_bottom  \
# 0                         True              False              False
# 1                        False               True              False
# 2                         True              False              False
# 3                        False               True              False
# 4                        False               True              False
#
#    add_missing_cols  clean_up_taxa_values  clean_up_taxa_metadata_values  \
# 0             False                 False                           True
# 1             False                 False                          False
# 2             False                 False                          False
# 3             False                 False                          False
# 4             False                 False                          False
#
#    split_dextral_sinistral  normalize_non_taxa
# 0                    False                 NaN
# 1                    False                 NaN
# 2                    False                 NaN
# 3                    False                 NaN
# 4                    False                 NaN

# %%
# new_metadata.to_csv(metadata_file, index=False)
