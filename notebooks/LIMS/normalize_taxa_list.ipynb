# %% [markdown]
# # Normalize taxa list
#
# Cleanup the normalized taxa list from the eODP researchers for a given particular taxon group. Create csvs to import the taxa data into the database.

# %%
import sys

import pandas as pd
import numpy as np
import requests

sys.path.append('../../')
import scripts.normalize_taxa as nt

# %%
date = '2021-07-28'
input_file = f'../../raw_data/PI_processed_files/LIMS_Micropal_headers_PBDB_Taxonomy_notes_taxa_list_{date}.csv'
input_pbdb_file = f"../../output/taxa/LIMS/PI_normalized_taxa_list_with_pbdb_{date}.csv"

crosswalk_file = f"../../output/taxa/LIMS/taxa_crosswalk_{date}.csv"
taxa_list_file = f"../../output/taxa/LIMS/taxa_list_{date}.csv"

genus_pbdb_file = f"../../output/taxa/LIMS/genera_pbdb_{date}.csv"
higher_taxa_pbdb_file = f"../../output/taxa/LIMS/higher_taxa_pbdb_{date}.csv"

# %%
def log_df(df, row_count=5):
    print(df.shape)
    return df.head(row_count)

# %%
PBDB_API = "https://paleobiodb.org/data1.2/"
PBDB_TAXA_NAME = f"{PBDB_API}taxa/single.json?vocab=pbdb&name="
PBDB_TAXA_ID = f"{PBDB_API}taxa/single.json?vocab=pbdb&id="

def fill_taxon(df, index, data, taxon_rank):
    # cast taxon_no to string to avoid pandas converting it to a float    
    df.at[index, f'{taxon_rank}_taxon_id'] = str(data[0]["taxon_no"])
    df.at[index, f'{taxon_rank}_taxon_name'] = data[0]["taxon_name"]
                

def get_parent_taxa(df, parent_id, taxon_rank, round, data): 
    if taxon_rank == 'kingdom':
        return data
    if round > 20:
        return data 
    
    round = round + 1
       
    url_parent = PBDB_TAXA_ID + parent_id
    response = requests.get(url_parent)
    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            taxon_rank = data[0]["taxon_rank"]
            parent_id = data[0]["parent_no"]
            if taxon_rank == 'family':
                fill_taxon(df, index, data, taxon_rank)
            if taxon_rank == 'order':
                fill_taxon(df, index, data, taxon_rank)
            if taxon_rank == 'class':
                fill_taxon(df, index, data, taxon_rank)
            if taxon_rank == 'phylum':
                fill_taxon(df, index, data, taxon_rank)
            if taxon_rank == 'kingdom':
                fill_taxon(df, index, data, taxon_rank)

                
            return get_parent_taxa(df, parent_id, taxon_rank, round, data)

# %% [markdown]
# ## Import normalized taxa list

# %%
df = pd.read_csv(input_file, skiprows = 9)
df = df.drop(df.index[[0, 1]])
df = df.dropna(how="all", axis="index")

log_df(df)
# Out:
# (4742, 21)
#       taxon_group                      verbatim_name  \
# 2  benthic_forams  Euuvigerina miozea (group) >100 m
# 3  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 4  benthic_forams                             Others
# 5  benthic_forams           Pleurostomellids comment
# 6  benthic_forams                     Ostracoda spp.
#
#                                 name name to use (if different from "name")  \
# 2  Euuvigerina miozea (group) >100 m                     Euuvigerina miozea
# 3  Euuvigerina rodleyi (group) >50 m                    Euuvigerina rodleyi
# 4                             Others                    Foraminifera indet.
# 5           Pleurostomellids comment                 Pleurostomellia indet.
# 6                     Ostracoda spp.                       Ostracoda indet.
#
#   name comment field          Comment  \
# 2                NaN            group
# 3                NaN            group
# 4                NaN       not a taxa
# 5                NaN       not a taxa
# 6     Ostracoda spp.  group abundance
#
#                                                notes  \
# 2  Summer 2020: enter "Euuvigerina miozea" and re...
# 3  Summer 2020: enter "Euuvigerina miozea" and re...
# 4                                               Andy
# 5                                               Andy
# 6  Summer 2020: go in as Ostracoda indet, and the...
#
#       Any taxon above genus genus modifier   genus name  ... subgenera name  \
# 2                       NaN            NaN  Euuvigerina  ...            NaN
# 3                       NaN            NaN  Euuvigerina  ...            NaN
# 4       Foraminifera indet.            NaN          NaN  ...            NaN
# 5  Pleurostomellidae indet.            NaN          NaN  ...            NaN
# 6          Ostracoda indet.            NaN          NaN  ...            NaN
#
#   species modifier species name subspecies modifier subspecies name  \
# 2              NaN       miozea                 NaN             NaN
# 3              NaN      rodleyi                 NaN             NaN
# 4              NaN          NaN                 NaN             NaN
# 5              NaN          NaN                 NaN             NaN
# 6              NaN          NaN                 NaN             NaN
#
#   non-taxa descriptor                    comments pbdb_taxon_id  \
# 2                 NaN                >100 m group           NaN
# 3                 NaN                 >50 m group           NaN
# 4                 NaN  other benthic foraminifera           NaN
# 5                 NaN                         NaN           NaN
# 6                 NaN                         NaN           NaN
#
#    pbdb_taxon_name pbdb_taxon_rank
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# 5              NaN             NaN
# 6              NaN             NaN
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (4742, 21)

# %% [markdown]
# ## Create crosswalk csv

# %%
fields = nt.taxa_rank_fields + nt.taxa_fields + nt.metadata_fields
filtered_taxa = pd.DataFrame(df, columns=fields)

# %% [markdown]
# set normalized_name using the taxa fields

# %%
nt.add_normalized_name_column(filtered_taxa)
log_df(filtered_taxa)
# Out:
# (4742, 14)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 2                       NaN            NaN  Euuvigerina                NaN
# 3                       NaN            NaN  Euuvigerina                NaN
# 4       Foraminifera indet.            NaN          NaN                NaN
# 5  Pleurostomellidae indet.            NaN          NaN                NaN
# 6          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 2            NaN              NaN       miozea                 NaN
# 3            NaN              NaN      rodleyi                 NaN
# 4            NaN              NaN          NaN                 NaN
# 5            NaN              NaN          NaN                 NaN
# 6            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 2             NaN                 NaN        Euuvigerina miozea
# 3             NaN                 NaN       Euuvigerina rodleyi
# 4             NaN                 NaN       Foraminifera indet.
# 5             NaN                 NaN  Pleurostomellidae indet.
# 6             NaN                 NaN          Ostracoda indet.
#
#       taxon_group                      verbatim_name  \
# 2  benthic_forams  Euuvigerina miozea (group) >100 m
# 3  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 4  benthic_forams                             Others
# 5  benthic_forams           Pleurostomellids comment
# 6  benthic_forams                     Ostracoda spp.
#
#                      comments
# 2                >100 m group
# 3                 >50 m group
# 4  other benthic foraminifera
# 5                         NaN
# 6                         NaN

# %%
filtered_taxa = filtered_taxa.drop(filtered_taxa[filtered_taxa['normalized_name'] == ''].index)
log_df(filtered_taxa)
# Out:
# (4735, 14)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 2                       NaN            NaN  Euuvigerina                NaN
# 3                       NaN            NaN  Euuvigerina                NaN
# 4       Foraminifera indet.            NaN          NaN                NaN
# 5  Pleurostomellidae indet.            NaN          NaN                NaN
# 6          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 2            NaN              NaN       miozea                 NaN
# 3            NaN              NaN      rodleyi                 NaN
# 4            NaN              NaN          NaN                 NaN
# 5            NaN              NaN          NaN                 NaN
# 6            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 2             NaN                 NaN        Euuvigerina miozea
# 3             NaN                 NaN       Euuvigerina rodleyi
# 4             NaN                 NaN       Foraminifera indet.
# 5             NaN                 NaN  Pleurostomellidae indet.
# 6             NaN                 NaN          Ostracoda indet.
#
#       taxon_group                      verbatim_name  \
# 2  benthic_forams  Euuvigerina miozea (group) >100 m
# 3  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 4  benthic_forams                             Others
# 5  benthic_forams           Pleurostomellids comment
# 6  benthic_forams                     Ostracoda spp.
#
#                      comments
# 2                >100 m group
# 3                 >50 m group
# 4  other benthic foraminifera
# 5                         NaN
# 6                         NaN

# %%
filtered_taxa.drop_duplicates(keep='first', inplace=True, subset =['verbatim_name', 'normalized_name'])
log_df(filtered_taxa)
# Out:
# (4594, 14)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 2                       NaN            NaN  Euuvigerina                NaN
# 3                       NaN            NaN  Euuvigerina                NaN
# 4       Foraminifera indet.            NaN          NaN                NaN
# 5  Pleurostomellidae indet.            NaN          NaN                NaN
# 6          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 2            NaN              NaN       miozea                 NaN
# 3            NaN              NaN      rodleyi                 NaN
# 4            NaN              NaN          NaN                 NaN
# 5            NaN              NaN          NaN                 NaN
# 6            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 2             NaN                 NaN        Euuvigerina miozea
# 3             NaN                 NaN       Euuvigerina rodleyi
# 4             NaN                 NaN       Foraminifera indet.
# 5             NaN                 NaN  Pleurostomellidae indet.
# 6             NaN                 NaN          Ostracoda indet.
#
#       taxon_group                      verbatim_name  \
# 2  benthic_forams  Euuvigerina miozea (group) >100 m
# 3  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 4  benthic_forams                             Others
# 5  benthic_forams           Pleurostomellids comment
# 6  benthic_forams                     Ostracoda spp.
#
#                      comments
# 2                >100 m group
# 3                 >50 m group
# 4  other benthic foraminifera
# 5                         NaN
# 6                         NaN

# %% [markdown]
# create crosswalk csv

# %%
filtered_taxa.to_csv(crosswalk_file, index=False)

# %% [markdown]
# ## Create taxa list csv

# %% [markdown]
# create taxa list with unique taxa fields

# %%
fields = nt.taxa_rank_fields + nt.taxa_fields
taxa_df = pd.DataFrame(filtered_taxa, columns=fields)

# drop duplicate data
taxa_df = taxa_df.drop_duplicates() 

log_df(taxa_df)
# Out:
# (4209, 12)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 2                       NaN            NaN  Euuvigerina                NaN
# 3                       NaN            NaN  Euuvigerina                NaN
# 4       Foraminifera indet.            NaN          NaN                NaN
# 5  Pleurostomellidae indet.            NaN          NaN                NaN
# 6          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 2            NaN              NaN       miozea                 NaN
# 3            NaN              NaN      rodleyi                 NaN
# 4            NaN              NaN          NaN                 NaN
# 5            NaN              NaN          NaN                 NaN
# 6            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 2             NaN                 NaN        Euuvigerina miozea
# 3             NaN                 NaN       Euuvigerina rodleyi
# 4             NaN                 NaN       Foraminifera indet.
# 5             NaN                 NaN  Pleurostomellidae indet.
# 6             NaN                 NaN          Ostracoda indet.
#
#       taxon_group
# 2  benthic_forams
# 3  benthic_forams
# 4  benthic_forams
# 5  benthic_forams
# 6  benthic_forams

# %% [markdown]
# ### create taxa csv

# %%
taxa_df.to_csv(taxa_list_file, index=False)

# %% [markdown]
# ## create genera csv

# %%
taxa_df = pd.read_csv(taxa_list_file)
log_df(taxa_df)
# Out:
# (4209, 12)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 0             NaN                 NaN        Euuvigerina miozea
# 1             NaN                 NaN       Euuvigerina rodleyi
# 2             NaN                 NaN       Foraminifera indet.
# 3             NaN                 NaN  Pleurostomellidae indet.
# 4             NaN                 NaN          Ostracoda indet.
#
#       taxon_group
# 0  benthic_forams
# 1  benthic_forams
# 2  benthic_forams
# 3  benthic_forams
# 4  benthic_forams

# %%
genus_df = pd.DataFrame(taxa_df['genus name'].str.strip().dropna().unique(), columns=['genus name']) 

log_df(genus_df)
# Out:
# (1015, 1)
#     genus name
# 0  Euuvigerina
# 1    Nodosaria
# 2    Cibicides
# 3    Brizalina
# 4     Candeina

# %%
genus_df.loc[genus_df['genus name'] == 'Martinotiella', 'genus name'] = 'Martinottiella'

# %%
for index, row in genus_df.iterrows():        
    if index % 50 == 0:
        print(index, end=' ')
        
    url =  PBDB_TAXA_NAME +  row['genus name']
        
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            genus_df.at[index, f'pbdb_taxon_id'] = str(data[0]["taxon_no"])
            genus_df.at[index, f'pbdb_taxon_name'] = data[0]["taxon_name"]
            genus_df.at[index, f'pbdb_taxon_rank'] = data[0]["taxon_rank"]
            
            round = 0
            get_parent_taxa(genus_df, data[0]["parent_no"], data[0]["taxon_rank"], round, None)
# Out:
# 0 50 100 150 200 250 300 350 400 450 500 550 600 650 700 750 800 850 900 950 1000

# %%
genus_df = genus_df.reindex(columns=[
    'genus name', 
    'pbdb_taxon_id', 'pbdb_taxon_name', 'pbdb_taxon_rank',
    'family_taxon_id', 'family_taxon_name',
    'order_taxon_id', 'order_taxon_name', 
    'class_taxon_id', 'class_taxon_name',
    'phylum_taxon_id', 'phylum_taxon_name', 
    'kingdom_taxon_id', 'kingdom_taxon_name', 
    ])

# %%
genus_df[0:20]
# Out:
#              genus name pbdb_taxon_id      pbdb_taxon_name pbdb_taxon_rank  \
# 0           Euuvigerina          1408          Euuvigerina           genus
# 1             Nodosaria          1952            Nodosaria           genus
# 2             Cibicides          1107            Cibicides           genus
# 3             Brizalina          1017            Brizalina           genus
# 4              Candeina          1053             Candeina           genus
# 5      Dentoglobigerina          1264     Dentoglobigerina           genus
# 6           Globigerina          1498          Globigerina           genus
# 7        Globigerinella          1501       Globigerinella           genus
# 8         Globigerinita          1503        Globigerinita           genus
# 9       Globigerinoides          1504      Globigerinoides           genus
# 10         Globoconella        103797         Globoconella           genus
# 11         Globorotalia          1521         Globorotalia           genus
# 12   Globoturborotalita          1529   Globoturborotalita           genus
# 13     Neogloboquadrina          1917     Neogloboquadrina           genus
# 14             Orbulina          2002             Orbulina           genus
# 15         Pulleniatina          2325         Pulleniatina           genus
# 16  Sphaeroidinellopsis          2569  Sphaeroidinellopsis           genus
# 17        Turborotalita          2740        Turborotalita           genus
# 18           Abyssamina           762           Abyssamina           genus
# 19           Acervulina           766           Acervulina           genus
#
#    family_taxon_id family_taxon_name order_taxon_id order_taxon_name  \
# 0              NaN               NaN            NaN              NaN
# 1            82197      Nodosariidae         429322      Nodosariida
# 2            82208       Cibicididae            NaN              NaN
# 3           112279       Bolivinidae            NaN              NaN
# 4           422277       Candeinidae            NaN              NaN
# 5            82191    Globigerinidae            NaN              NaN
# 6            82191    Globigerinidae            NaN              NaN
# 7            82191    Globigerinidae            NaN              NaN
# 8           422373  Globigerinitidae            NaN              NaN
# 9            82191    Globigerinidae            NaN              NaN
# 10           82192   Globorotaliidae            NaN              NaN
# 11           82192   Globorotaliidae            NaN              NaN
# 12           82191    Globigerinidae            NaN              NaN
# 13           82192   Globorotaliidae            NaN              NaN
# 14           82191    Globigerinidae            NaN              NaN
# 15           82192   Globorotaliidae            NaN              NaN
# 16           82191    Globigerinidae            NaN              NaN
# 17           82191    Globigerinidae            NaN              NaN
# 18          103796  Chilostomellidae         279579        Rotaliida
# 19           54414     Acervulinidae            NaN              NaN
#
#    class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0             NaN              NaN          288974      Foraminifera
# 1          428875      Nodosariata          288974      Foraminifera
# 2             NaN              NaN          288974      Foraminifera
# 3             NaN              NaN          288974      Foraminifera
# 4             NaN              NaN          288974      Foraminifera
# 5             NaN              NaN          288974      Foraminifera
# 6             NaN              NaN          288974      Foraminifera
# 7             NaN              NaN          288974      Foraminifera
# 8             NaN              NaN          288974      Foraminifera
# 9             NaN              NaN          288974      Foraminifera
# 10            NaN              NaN          288974      Foraminifera
# 11            NaN              NaN          288974      Foraminifera
# 12            NaN              NaN          288974      Foraminifera
# 13            NaN              NaN          288974      Foraminifera
# 14            NaN              NaN          288974      Foraminifera
# 15            NaN              NaN          288974      Foraminifera
# 16            NaN              NaN          288974      Foraminifera
# 17            NaN              NaN          288974      Foraminifera
# 18         428504    Globothalamea          288974      Foraminifera
# 19            NaN              NaN          288974      Foraminifera
#
#    kingdom_taxon_id kingdom_taxon_name
# 0            212476           Rhizaria
# 1            212476           Rhizaria
# 2            212476           Rhizaria
# 3            212476           Rhizaria
# 4            212476           Rhizaria
# 5            212476           Rhizaria
# 6            212476           Rhizaria
# 7            212476           Rhizaria
# 8            212476           Rhizaria
# 9            212476           Rhizaria
# 10           212476           Rhizaria
# 11           212476           Rhizaria
# 12           212476           Rhizaria
# 13           212476           Rhizaria
# 14           212476           Rhizaria
# 15           212476           Rhizaria
# 16           212476           Rhizaria
# 17           212476           Rhizaria
# 18           212476           Rhizaria
# 19           212476           Rhizaria

# %%
genus_df.shape
# Out:
# (1015, 14)

# %%
genus_df.to_csv(genus_pbdb_file, index=False)

# %% [markdown]
# ### add genus pbdb to input_file

# %%
df = pd.read_csv(input_file, skiprows = 9, dtype=str)
log_df(df)
# Out:
# (4754, 21)
#       taxon_group                      verbatim_name  \
# 0             NaN  RESOLVED NAMES BY TAXONOMIC GROUP
# 1  benthic_forams                             Pyrite
# 2  benthic_forams  Euuvigerina miozea (group) >100 m
# 3  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 4  benthic_forams                             Others
#
#                                 name name to use (if different from "name")  \
# 0                                NaN                                    NaN
# 1                             Pyrite                                    NaN
# 2  Euuvigerina miozea (group) >100 m                     Euuvigerina miozea
# 3  Euuvigerina rodleyi (group) >50 m                    Euuvigerina rodleyi
# 4                             Others                    Foraminifera indet.
#
#   name comment field                                      Comment  \
# 0                NaN                                          NaN
# 1                NaN  not a taxa; Going into Macrostrat, not PBDB
# 2                NaN                                        group
# 3                NaN                                        group
# 4                NaN                                   not a taxa
#
#                                                notes Any taxon above genus  \
# 0                                                NaN                   NaN
# 1  Summer 2020: deal with later; should go in as ...                   NaN
# 2  Summer 2020: enter "Euuvigerina miozea" and re...                   NaN
# 3  Summer 2020: enter "Euuvigerina miozea" and re...                   NaN
# 4                                               Andy   Foraminifera indet.
#
#   genus modifier   genus name  ... subgenera name species modifier  \
# 0            NaN          NaN  ...            NaN              NaN
# 1            NaN          NaN  ...            NaN              NaN
# 2            NaN  Euuvigerina  ...            NaN              NaN
# 3            NaN  Euuvigerina  ...            NaN              NaN
# 4            NaN          NaN  ...            NaN              NaN
#
#   species name subspecies modifier subspecies name non-taxa descriptor  \
# 0          NaN                 NaN             NaN                 NaN
# 1          NaN                 NaN             NaN                 NaN
# 2       miozea                 NaN             NaN                 NaN
# 3      rodleyi                 NaN             NaN                 NaN
# 4          NaN                 NaN             NaN                 NaN
#
#                      comments pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank
# 0                         NaN           NaN             NaN             NaN
# 1                         NaN           NaN             NaN             NaN
# 2                >100 m group           NaN             NaN             NaN
# 3                 >50 m group           NaN             NaN             NaN
# 4  other benthic foraminifera           NaN             NaN             NaN
#
# [5 rows x 21 columns]

# %%
genus_df= pd.read_csv(genus_pbdb_file, dtype=str)

log_df(genus_df)
# Out:
# (1015, 14)
#     genus name pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank family_taxon_id  \
# 0  Euuvigerina          1408     Euuvigerina           genus             NaN
# 1    Nodosaria          1952       Nodosaria           genus           82197
# 2    Cibicides          1107       Cibicides           genus           82208
# 3    Brizalina          1017       Brizalina           genus          112279
# 4     Candeina          1053        Candeina           genus          422277
#
#   family_taxon_name order_taxon_id order_taxon_name class_taxon_id  \
# 0               NaN            NaN              NaN            NaN
# 1      Nodosariidae         429322      Nodosariida         428875
# 2       Cibicididae            NaN              NaN            NaN
# 3       Bolivinidae            NaN              NaN            NaN
# 4       Candeinidae            NaN              NaN            NaN
#
#   class_taxon_name phylum_taxon_id phylum_taxon_name kingdom_taxon_id  \
# 0              NaN          288974      Foraminifera           212476
# 1      Nodosariata          288974      Foraminifera           212476
# 2              NaN          288974      Foraminifera           212476
# 3              NaN          288974      Foraminifera           212476
# 4              NaN          288974      Foraminifera           212476
#
#   kingdom_taxon_name
# 0           Rhizaria
# 1           Rhizaria
# 2           Rhizaria
# 3           Rhizaria
# 4           Rhizaria

# %%
df['genus name'] = df['genus name'].str.strip()
genus_df['genus name'] = genus_df['genus name'].str.strip()

merged_df = df.merge(genus_df, on="genus name", how="left", suffixes=('_prev', None))
log_df(merged_df)
# Out:
# (4754, 34)
#       taxon_group                      verbatim_name  \
# 0             NaN  RESOLVED NAMES BY TAXONOMIC GROUP
# 1  benthic_forams                             Pyrite
# 2  benthic_forams  Euuvigerina miozea (group) >100 m
# 3  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 4  benthic_forams                             Others
#
#                                 name name to use (if different from "name")  \
# 0                                NaN                                    NaN
# 1                             Pyrite                                    NaN
# 2  Euuvigerina miozea (group) >100 m                     Euuvigerina miozea
# 3  Euuvigerina rodleyi (group) >50 m                    Euuvigerina rodleyi
# 4                             Others                    Foraminifera indet.
#
#   name comment field                                      Comment  \
# 0                NaN                                          NaN
# 1                NaN  not a taxa; Going into Macrostrat, not PBDB
# 2                NaN                                        group
# 3                NaN                                        group
# 4                NaN                                   not a taxa
#
#                                                notes Any taxon above genus  \
# 0                                                NaN                   NaN
# 1  Summer 2020: deal with later; should go in as ...                   NaN
# 2  Summer 2020: enter "Euuvigerina miozea" and re...                   NaN
# 3  Summer 2020: enter "Euuvigerina miozea" and re...                   NaN
# 4                                               Andy   Foraminifera indet.
#
#   genus modifier   genus name  ... family_taxon_id family_taxon_name  \
# 0            NaN          NaN  ...             NaN               NaN
# 1            NaN          NaN  ...             NaN               NaN
# 2            NaN  Euuvigerina  ...             NaN               NaN
# 3            NaN  Euuvigerina  ...             NaN               NaN
# 4            NaN          NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
# 2          288974      Foraminifera           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4             NaN               NaN              NaN                NaN
#
# [5 rows x 34 columns]

# %%
merged_df.to_csv(input_pbdb_file, index=False)

# %% [markdown]
# ## create higher csv

# %%
taxa_df = pd.read_csv(taxa_list_file)
log_df(taxa_df)
# Out:
# (4209, 12)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 0             NaN                 NaN        Euuvigerina miozea
# 1             NaN                 NaN       Euuvigerina rodleyi
# 2             NaN                 NaN       Foraminifera indet.
# 3             NaN                 NaN  Pleurostomellidae indet.
# 4             NaN                 NaN          Ostracoda indet.
#
#       taxon_group
# 0  benthic_forams
# 1  benthic_forams
# 2  benthic_forams
# 3  benthic_forams
# 4  benthic_forams

# %%
higher_df = pd.DataFrame(taxa_df['Any taxon above genus'].str.strip().dropna().unique(), columns=['Any taxon above genus']) 
higher_df.replace('', np.nan, inplace=True)
higher_df.dropna(inplace=True)
log_df(higher_df)
# Out:
# (66, 1)
#       Any taxon above genus
# 0       Foraminifera indet.
# 1  Pleurostomellidae indet.
# 2          Ostracoda indet.
# 3        Textulariia indet.
# 4        Elphidiidae indet.

# %%
for index, row in higher_df.iterrows():        
    if index % 20 == 0:
        print(index)
        
    name = row['Any taxon above genus'].replace(' indet.', '')

  
    url =  PBDB_TAXA_NAME +  name
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            higher_df.at[index, f'pbdb_taxon_id'] = str(data[0]["taxon_no"])
            higher_df.at[index, f'pbdb_taxon_name'] = data[0]["taxon_name"]
            higher_df.at[index, f'pbdb_taxon_rank'] = data[0]["taxon_rank"]
            
            round = 0
            get_parent_taxa(higher_df, data[0]["parent_no"], data[0]["taxon_rank"], round, None)
        else:
            print(name, len(data), ' found')
    else:
        print(name, ' not found')
# Out:
# 0
# "Challengeria spp."  not found
# "Phytolith"  not found
# 20
# "Amorphous organic matter"  not found
# "Black phytoclasts"  not found
# "Brown phytoclasts"  not found
# "round browns, psilate"  not found
# "Terrestrial palynomorphs"  not found
# "Unknown taxa"  not found
# "other pollen"  not found
# "Spores"  not found
# "Fungal spores"  not found
# "Pollen/spores reworked"  not found
# "Other pollen"  not found
# 40
# "Sporomorphs"  not found
# "Black woody phytoclasts"  not found
# "Brown woody phytoclasts"  not found
# "Saccate pollen"  not found
# "Monolete ornamented"  not found
# "Monolete psilate"  not found
# "Trilete ornamented"  not found
# "Trilete psilate"  not found
# 60

# %%
higher_df.columns
# Out:
# Index(['Any taxon above genus', 'pbdb_taxon_id', 'pbdb_taxon_name',
#        'pbdb_taxon_rank', 'kingdom_taxon_id', 'kingdom_taxon_name',
#        'phylum_taxon_id', 'phylum_taxon_name'],
#       dtype='object')

# %%
higher_df = higher_df.reindex(columns=[
    'Any taxon above genus', 
    'pbdb_taxon_id', 'pbdb_taxon_name', 'pbdb_taxon_rank',
    'order_taxon_id', 'order_taxon_name', 
    'class_taxon_id', 'class_taxon_name',
    'phylum_taxon_id', 'phylum_taxon_name', 
    'kingdom_taxon_id', 'kingdom_taxon_name', 
    ])
higher_df

# %%
higher_df.to_csv(higher_taxa_pbdb_file, index=False)

# %% [markdown]
# ### add higher pbdb to input_file

# %%
df = pd.read_csv(input_pbdb_file,  dtype=str)
log_df(df)
# Out:
# (4754, 34)
#       taxon_group                      verbatim_name  \
# 0             NaN  RESOLVED NAMES BY TAXONOMIC GROUP
# 1  benthic_forams                             Pyrite
# 2  benthic_forams  Euuvigerina miozea (group) >100 m
# 3  benthic_forams  Euuvigerina rodleyi (group) >50 m
# 4  benthic_forams                             Others
#
#                                 name name to use (if different from "name")  \
# 0                                NaN                                    NaN
# 1                             Pyrite                                    NaN
# 2  Euuvigerina miozea (group) >100 m                     Euuvigerina miozea
# 3  Euuvigerina rodleyi (group) >50 m                    Euuvigerina rodleyi
# 4                             Others                    Foraminifera indet.
#
#   name comment field                                      Comment  \
# 0                NaN                                          NaN
# 1                NaN  not a taxa; Going into Macrostrat, not PBDB
# 2                NaN                                        group
# 3                NaN                                        group
# 4                NaN                                   not a taxa
#
#                                                notes Any taxon above genus  \
# 0                                                NaN                   NaN
# 1  Summer 2020: deal with later; should go in as ...                   NaN
# 2  Summer 2020: enter "Euuvigerina miozea" and re...                   NaN
# 3  Summer 2020: enter "Euuvigerina miozea" and re...                   NaN
# 4                                               Andy   Foraminifera indet.
#
#   genus modifier   genus name  ... family_taxon_id family_taxon_name  \
# 0            NaN          NaN  ...             NaN               NaN
# 1            NaN          NaN  ...             NaN               NaN
# 2            NaN  Euuvigerina  ...             NaN               NaN
# 3            NaN  Euuvigerina  ...             NaN               NaN
# 4            NaN          NaN  ...             NaN               NaN
#
#   order_taxon_id order_taxon_name class_taxon_id class_taxon_name  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   phylum_taxon_id phylum_taxon_name kingdom_taxon_id kingdom_taxon_name
# 0             NaN               NaN              NaN                NaN
# 1             NaN               NaN              NaN                NaN
# 2          288974      Foraminifera           212476           Rhizaria
# 3          288974      Foraminifera           212476           Rhizaria
# 4             NaN               NaN              NaN                NaN
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['taxon_group', 'verbatim_name', 'name',
#        'name to use (if different from "name")', 'name comment field',
#        'Comment', 'notes', 'Any taxon above genus', 'genus modifier',
#        'genus name', 'subgenera modifier', 'subgenera name',
#        'species modifier', 'species name', 'subspecies modifier',
#        'subspecies name', 'non-taxa descriptor', 'comments',
#        'pbdb_taxon_id_prev', 'pbdb_taxon_name_prev', 'pbdb_taxon_rank_prev',
#        'pbdb_taxon_id', 'pbdb_taxon_name', 'pbdb_taxon_rank',
#        'family_taxon_id', 'family_taxon_name', 'order_taxon_id',
#        'order_taxon_name', 'class_taxon_id', 'class_taxon_name',
#        'phylum_taxon_id', 'phylum_taxon_name', 'kingdom_taxon_id',
#        'kingdom_taxon_name'],
#       dtype='object')

# %%
higher_df = pd.read_csv(higher_taxa_pbdb_file, dtype=str)

# %%
for index, row in higher_df.iterrows():    
    for col in higher_df.columns:
        if col == 'Any taxon above genus':
            continue

        df.loc[df['Any taxon above genus'] == row['Any taxon above genus'], col] = row[col]

# %%
df.to_csv(input_pbdb_file,  index=False)

# %%
foo = df[df['Any taxon above genus'].notna()]
foo
# Out:
#          taxon_group                                     verbatim_name  \
# 4     benthic_forams                                            Others
# 5     benthic_forams                          Pleurostomellids comment
# 6     benthic_forams                                    Ostracoda spp.
# 7     benthic_forams                                         Elongated
# 8     benthic_forams                                       Planispiral
# ...              ...                                               ...
# 4125    radiolarians                                ADDITIONAL SPECIES
# 4128    radiolarians                               Acrobotrys tritubus
# 4274    radiolarians                               Corocalyptra cervus
# 4742    radiolarians                          Octopyle/Tetrapyle Group
# 4743    radiolarians  Phormacantha hystrix/Plectacantha oikiskos group
#
#                                                   name  \
# 4                                               Others
# 5                             Pleurostomellids comment
# 6                                       Ostracoda spp.
# 7                                            Elongated
# 8                                          Planispiral
# ...                                                ...
# 4125                                ADDITIONAL SPECIES
# 4128                               Acrobotrys tritubus
# 4274                               Corocalyptra cervus
# 4742                          Octopyle/Tetrapyle Group
# 4743  Phormacantha hystrix/Plectacantha oikiskos group
#
#      name to use (if different from "name")  \
# 4                       Foraminifera indet.
# 5                    Pleurostomellia indet.
# 6                          Ostracoda indet.
# 7                       Foraminifera indet.
# 8                       Foraminifera indet.
# ...                                     ...
# 4125                      Radiolaria indet.
# 4128                                    NaN
# 4274                    Corocalyptra cervus
# 4742                      Pyloniidae indet.
# 4743                      Radiolaria indet.
#
#                                     name comment field          Comment  \
# 4                                                  NaN       not a taxa
# 5                                                  NaN       not a taxa
# 6                                       Ostracoda spp.  group abundance
# 7                                            Elongated      not a taxa
# 8                                          Planispiral       not a taxa
# ...                                                ...              ...
# 4125                                ADDITIONAL SPECIES  not a taxa name
# 4128                                               NaN              NaN
# 4274                                               NaN              NaN
# 4742                          Octopyle/Tetrapyle Group    multiple taxa
# 4743  Phormacantha hystrix/Plectacantha oikiskos group    multiple taxa
#
#                                                   notes  \
# 4                                                  Andy
# 5                                                  Andy
# 6     Summer 2020: go in as Ostracoda indet, and the...
# 7     Summer 2020: Andy; AF: same as above. I bet th...
# 8     Summer 2020: Andy AF: Can't do better than 'be...
# ...                                                 ...
# 4125        in PBDB, so it will be classified correctly
# 4128        in PBDB, so it will be classified correctly
# 4274        in PBDB, so it will be classified correctly
# 4742        in PBDB, so it will be classified correctly
# 4743        in PBDB, so it will be classified correctly
#
#          Any taxon above genus genus modifier    genus name  ...  \
# 4          Foraminifera indet.            NaN           NaN  ...
# 5     Pleurostomellidae indet.            NaN           NaN  ...
# 6             Ostracoda indet.            NaN           NaN  ...
# 7          Foraminifera indet.            NaN           NaN  ...
# 8          Foraminifera indet.            NaN           NaN  ...
# ...                        ...            ...           ...  ...
# 4125         Radiolaria indet.            NaN           NaN  ...
# 4128                                      NaN    Acrobotrys  ...
# 4274                                      NaN  Corocalyptra  ...
# 4742         Pyloniidae indet.            NaN           NaN  ...
# 4743         Radiolaria indet.            NaN           NaN  ...
#
#      family_taxon_id family_taxon_name order_taxon_id order_taxon_name  \
# 4                NaN               NaN            NaN              NaN
# 5                NaN               NaN            NaN              NaN
# 6                NaN               NaN            NaN              NaN
# 7                NaN               NaN            NaN              NaN
# 8                NaN               NaN            NaN              NaN
# ...              ...               ...            ...              ...
# 4125             NaN               NaN            NaN              NaN
# 4128           85922    Cannobotryidae            402      Nassellaria
# 4274             NaN               NaN            402      Nassellaria
# 4742             NaN               NaN              5      Spumellaria
# 4743             NaN               NaN            NaN              NaN
#
#      class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 4               NaN              NaN             NaN               NaN
# 5               NaN              NaN          288974      Foraminifera
# 6               NaN              NaN           18891        Arthropoda
# 7               NaN              NaN             NaN               NaN
# 8               NaN              NaN             NaN               NaN
# ...             ...              ...             ...               ...
# 4125            NaN              NaN             NaN               NaN
# 4128            NaN              NaN               4        Radiolaria
# 4274            NaN              NaN               4        Radiolaria
# 4742            NaN              NaN               4        Radiolaria
# 4743            NaN              NaN             NaN               NaN
#
#      kingdom_taxon_id kingdom_taxon_name
# 4              212476           Rhizaria
# 5              212476           Rhizaria
# 6              325038           Animalia
# 7              212476           Rhizaria
# 8              212476           Rhizaria
# ...               ...                ...
# 4125           212476           Rhizaria
# 4128           212476           Rhizaria
# 4274           212476           Rhizaria
# 4742           212476           Rhizaria
# 4743           212476           Rhizaria
#
# [105 rows x 34 columns]

# %%
foo.to_csv('foo.csv')
