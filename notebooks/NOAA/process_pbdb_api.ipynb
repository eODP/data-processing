# %%
import requests
import sys
import pandas as pd
import time

sys.path.append('../../')

from config import CLEAN_DATA_DIR, OUTPUT_DIR, RAW_DATA_DIR
import scripts.normalize_taxa as nt
from scripts.shared_utils import (
    log_df
)

import scripts.pbdb as pbdb

# %%
PBDB_API = "https://paleobiodb.org/data1.2/"
PBDB_TAXA_LIST_NAME = f"{PBDB_API}taxa/list.json?show=class&rel=all_parents&name="


PBDB_TAXA_NAME = f"{PBDB_API}taxa/single.json?vocab=pbdb&name="


date = '2024-01-18'
initial_input_file = RAW_DATA_DIR/'PI_processed_files'/f'NOAA_2_taxa_lists_taxa_list_{date}.csv'

# %%
def add_genus_species(taxa_df):

    taxa_df.loc[~taxa_df['species name'].str.contains('spp\.|sp\..*?', regex=True).fillna(False), 'genus species']=taxa_df['genus name'] + ' ' + taxa_df['species name']
    taxa_df.loc[taxa_df['species name'].str.contains('spp\.|sp\..*?', regex=True).fillna(False), 'genus species']=taxa_df['genus name'] 
    
    taxa_df.loc[taxa_df['species name'].isna(), 'genus species']=taxa_df['genus name'] 
    taxa_df.loc[taxa_df['Any taxon above genus'].notna(), 'genus species']=''
    taxa_df.loc[taxa_df['Any taxon above genus modifier'].notna(), 'genus species']=''

    

    taxa_df['genus species'] = taxa_df['genus species'].str.strip()

# %% [markdown]
# # get taxa ranks

# %%
df = pd.read_csv(initial_input_file)
nt.add_normalized_name_column(df)
add_genus_species(df)

log_df(df)
# Out:
# (8906, 42)
#        taxon_group              verbatim_name                      name  \
# 0  dinoflagellates    ?Labyrinthodinium sp. 1  ? Labyrinthodinium sp. 1
# 1  dinoflagellates          ?Maduradinium sp.        ? Maduradinium sp.
# 2  dinoflagellates          ?Pyxidiella sp. 1        ? Pyxidiella sp. 1
# 3  dinoflagellates   Aandalusiella ivoirensis   Andalusiella ivoirensis
# 4  dinoflagellates  Abratopdinium cardioforme                       NaN
#
#            Comment Notes (temp; JAS will remove when finished with dinos)  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3  genus missplled                                                NaN
# 4              NaN                                                NaN
#
#               Notes (change to Internal only notes?)  \
# 0  Updated taxon_group from "Dinoflagellates/Acri...
# 1  Updated taxon_group from "Dinoflagellates/Acri...
# 2  Updated taxon_group from "Dinoflagellates/Acri...
# 3  Updated taxon_group from "Dinoflagellates/Acri...
# 4  Updated taxon_group from "Dinoflagellates/Acri...
#
#   Any taxon above genus modifier Any taxon above genus genus modifier  \
# 0                            NaN                   NaN              ?
# 1                            NaN                   NaN              ?
# 2                            NaN                   NaN              ?
# 3                            NaN                   NaN            NaN
# 4                            NaN                   NaN            NaN
#
#          genus name  ...  class_taxon_id class_taxon_name phylum_taxon_id  \
# 0  Labyrinthodinium  ...        321578.0      Dinophyceae             NaN
# 1      Maduradinium  ...        321578.0      Dinophyceae             NaN
# 2        Pyxidiella  ...        321578.0      Dinophyceae             NaN
# 3      Andalusiella  ...             NaN              NaN             NaN
# 4     Abratopdinium  ...             NaN              NaN             NaN
#
#   phylum_taxon_name kingdom_taxon_id kingdom_taxon_name  \
# 0               NaN              NaN                NaN
# 1               NaN              NaN                NaN
# 2               NaN              NaN                NaN
# 3               NaN              NaN                NaN
# 4               NaN              NaN                NaN
#
#   unranked clade_taxon_id unranked clade_taxon_name  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#              normalized_name              genus species
# 0   ? Labyrinthodinium sp. 1           Labyrinthodinium
# 1         ? Maduradinium sp.               Maduradinium
# 2         ? Pyxidiella sp. 1                 Pyxidiella
# 3    Andalusiella ivoirensis    Andalusiella ivoirensis
# 4  Abratopdinium cardioforme  Abratopdinium cardioforme
#
# [5 rows x 42 columns]

# %%
set(df[df['genus species'].isna()]['normalized_name'])
# Out:
# {'', 'Katacycloclypeus spp.', 'bulbosa', 'inornata', 'spp.'}

# %%
def get_ranks(name, rank_dict, rank_ids):
    if pd.isna(name):
        return 
    
    url = PBDB_TAXA_LIST_NAME + name
    response = requests.get(url)


    if response.status_code == 200:
        records = response.json()['records']

        for record in records:
            found = False
            rank_id = record['rnk']
            
            if rank_id in rank_ids:
                continue 
            
            if 'gnl' in record:
                if record['gnl'] == record['nam']:
                    rank_dict[rank_id] = 'genus'
                    rank_ids.add(rank_id)
                    found = True

            elif 'fml' in record:
                if record['fml'] == record['nam']:
                    rank_dict[rank_id] = 'family'
                    rank_ids.add(rank_id)  
                    found = True

            elif 'odl' in record:
                if record['odl'] == record['nam']:
                    rank_dict[rank_id] = 'order'
                    rank_ids.add(rank_id)
                    found = True

            elif 'cll' in record:
                if record['cll'] == record['nam']:
                    rank_dict[rank_id] = 'class'
                    rank_ids.add(rank_id)
                    found = True

            elif 'phl' in record:
                if record['phl'] == record['nam']:
                    rank_dict[rank_id] = 'phylum'
                    rank_ids.add(rank_id)
                    found = True

            if not found:
                # print(record)
                url2 = PBDB_TAXA_NAME + record['nam']
                response2 = requests.get(url2)
                if response2.status_code == 200:
                    records2 = response2.json()['records'][0]

                    rank_dict[rank_id] = records2['taxon_rank']
                    rank_ids.add(rank_id)

    return rank_dict

# %%
rank_dict = {}
rank_ids = set()

# %%
for index, row in df.iterrows():
    # if index < 3500:
    #     continue
    
    if index % 10 == 0:
        time.sleep(0.5)
    if index % 50 == 0:
        print(index, end=' ')
        
    get_ranks(row['genus species'], rank_dict, rank_ids)
# Out:
# 3500 3550 3600 3650 3700 3750 3800 3850 3900 3950 4000 4050 4100 4150 4200 4250 4300 4350 4400 4450 4500 4550 4600 4650 4700 4750 4800 4850 4900 4950 5000 5050 5100 5150 5200 5250 5300 5350 5400 5450 5500 5550 5600 5650 5700 5750 5800 5850 5900 5950 6000 6050 6100 6150 6200 6250 6300 6350 6400 6450 6500 6550 6600 6650 6700 6750 6800 6850 6900 6950 7000 7050 7100 7150 7200 7250 7300 7350 7400 7450 7500 7550 7600 7650 7700 7750 7800 7850 7900 7950 8000 8050 8100 8150 8200 8250 8300 8350 8400 8450 8500 8550 8600 8650 8700 8750 8800 8850 8900

# %%
rank_dict
# Out:
# {20: 'phylum',
#  19: 'subphylum',
#  18: 'superclass',
#  17: 'class',
#  13: 'order',
#  5: 'genus',
#  9: 'family',
#  3: 'species',
#  8: 'subfamily',
#  25: 'unranked clade',
#  23: 'kingdom',
#  21: 'phylum',
#  12: 'suborder',
#  10: 'superfamily',
#  16: 'subclass',
#  15: 'infraclass',
#  14: 'superorder',
#  11: 'infraorder',
#  22: 'subkingdom',
#  4: 'subgenus',
#  2: 'subspecies',
#  7: 'tribe'}

# %% [markdown]
# {20: 'phylum',
#  19: 'subphylum',
#  18: 'superclass',
#  17: 'class',
#  13: 'order',
#  5: 'genus',
#  9: 'family',
#  3: 'species',
#  8: 'subfamily',
#  25: 'unranked clade',
#  23: 'kingdom',
#  21: 'phylum',
#  12: 'suborder',
#  10: 'superfamily',
#  16: 'subclass',
#  15: 'infraclass',
#  14: 'superorder',
#  11: 'infraorder',
#  22: 'subkingdom',
#  4: 'subgenus',
#  2: 'subspecies',
#  7: 'tribe'}

# %% [markdown]
# # get pbdb info

# %%
df = pd.read_csv(initial_input_file)

log_df(df)
# Out:
# (8906, 40)
#        taxon_group              verbatim_name                      name  \
# 0  dinoflagellates    ?Labyrinthodinium sp. 1  ? Labyrinthodinium sp. 1
# 1  dinoflagellates          ?Maduradinium sp.        ? Maduradinium sp.
# 2  dinoflagellates          ?Pyxidiella sp. 1        ? Pyxidiella sp. 1
# 3  dinoflagellates   Aandalusiella ivoirensis   Andalusiella ivoirensis
# 4  dinoflagellates  Abratopdinium cardioforme                       NaN
#
#            Comment Notes (temp; JAS will remove when finished with dinos)  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3  genus missplled                                                NaN
# 4              NaN                                                NaN
#
#               Notes (change to Internal only notes?)  \
# 0  Updated taxon_group from "Dinoflagellates/Acri...
# 1  Updated taxon_group from "Dinoflagellates/Acri...
# 2  Updated taxon_group from "Dinoflagellates/Acri...
# 3  Updated taxon_group from "Dinoflagellates/Acri...
# 4  Updated taxon_group from "Dinoflagellates/Acri...
#
#   Any taxon above genus modifier Any taxon above genus genus modifier  \
# 0                            NaN                   NaN              ?
# 1                            NaN                   NaN              ?
# 2                            NaN                   NaN              ?
# 3                            NaN                   NaN            NaN
# 4                            NaN                   NaN            NaN
#
#          genus name  ...  subclass_taxon_id subclass_taxon_name  \
# 0  Labyrinthodinium  ...                NaN                 NaN
# 1      Maduradinium  ...                NaN                 NaN
# 2        Pyxidiella  ...                NaN                 NaN
# 3      Andalusiella  ...                NaN                 NaN
# 4     Abratopdinium  ...                NaN                 NaN
#
#   class_taxon_id class_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0       321578.0      Dinophyceae             NaN               NaN
# 1       321578.0      Dinophyceae             NaN               NaN
# 2       321578.0      Dinophyceae             NaN               NaN
# 3            NaN              NaN             NaN               NaN
# 4            NaN              NaN             NaN               NaN
#
#   kingdom_taxon_id kingdom_taxon_name  unranked clade_taxon_id  \
# 0              NaN                NaN                      NaN
# 1              NaN                NaN                      NaN
# 2              NaN                NaN                      NaN
# 3              NaN                NaN                      NaN
# 4              NaN                NaN                      NaN
#
#   unranked clade_taxon_name
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 40 columns]

# %%
genus_df = df[df['genus name'].notna()].copy()[['taxon_group', 'genus name']]
genus_df.drop_duplicates(inplace=True)
genus_df['check'] = False

log_df(genus_df)
# Out:
# (2067, 3)
#        taxon_group        genus name  check
# 0  dinoflagellates  Labyrinthodinium  False
# 1  dinoflagellates      Maduradinium  False
# 2  dinoflagellates        Pyxidiella  False
# 3  dinoflagellates      Andalusiella  False
# 4  dinoflagellates     Abratopdinium  False

# %%
pbdb.fetch_pdbd_data(genus_df, 'genus name')
# Out:
# 0

# %%
log_df(genus_df, 20)
# Out:
# (2067, 16)
#         taxon_group          genus name  check pbdb_taxon_id  \
# 0   dinoflagellates    Labyrinthodinium   True        443826
# 1   dinoflagellates        Maduradinium   True        325673
# 2   dinoflagellates          Pyxidiella   True        336773
# 3   dinoflagellates        Andalusiella   True        276893
# 4   dinoflagellates       Abratopdinium   True        477210
# 6   dinoflagellates         Acanthaulax   True        276986
# 8   dinoflagellates      Achilleodinium   True        323991
# 10  dinoflagellates       Achomosphaera   True        277048
# 35  dinoflagellates          Actiniscus  False          <NA>
# 36  dinoflagellates   Adnatosphaeridium  False          <NA>
# 40  dinoflagellates            Aireiana  False          <NA>
# 42  dinoflagellates            Aldorfia  False          <NA>
# 44  dinoflagellates   Algidasphaeridium  False          <NA>
# 58  dinoflagellates          Alisocysta  False          <NA>
# 61  dinoflagellates        Alisogymnium  False          <NA>
# 62  dinoflagellates       Alterbidinium  False          <NA>
# 68  dinoflagellates      Amiculosphaera  False          <NA>
# 70  dinoflagellates        Amphidiadema  False          <NA>
# 72  dinoflagellates  Amphorosphaeridium  False          <NA>
# 74  dinoflagellates           Amphorula  False          <NA>
#
#      pbdb_taxon_name pbdb_taxon_rank phylum_taxon_id phylum_taxon_name  \
# 0   Labyrinthodinium           genus          277918           Myzozoa
# 1       Maduradinium           genus          277918           Myzozoa
# 2         Pyxidiella           genus          277918           Myzozoa
# 3       Andalusiella           genus          277918           Myzozoa
# 4      Abratopdinium           genus          277918           Myzozoa
# 6        Acanthaulax           genus          277918           Myzozoa
# 8     Achilleodinium           genus          277918           Myzozoa
# 10     Achomosphaera           genus          277918           Myzozoa
# 35               NaN             NaN             NaN               NaN
# 36               NaN             NaN             NaN               NaN
# 40               NaN             NaN             NaN               NaN
# 42               NaN             NaN             NaN               NaN
# 44               NaN             NaN             NaN               NaN
# 58               NaN             NaN             NaN               NaN
# 61               NaN             NaN             NaN               NaN
# 62               NaN             NaN             NaN               NaN
# 68               NaN             NaN             NaN               NaN
# 70               NaN             NaN             NaN               NaN
# 72               NaN             NaN             NaN               NaN
# 74               NaN             NaN             NaN               NaN
#
#    class_taxon_id class_taxon_name order_taxon_id order_taxon_name  \
# 0          321578      Dinophyceae         321606    Gonyaulacales
# 1          321578      Dinophyceae         277919     Peridiniales
# 2          321578      Dinophyceae         277919     Peridiniales
# 3          321578      Dinophyceae         277919     Peridiniales
# 4          321578      Dinophyceae         277919     Peridiniales
# 6             NaN              NaN            NaN              NaN
# 8          321578      Dinophyceae         321606    Gonyaulacales
# 10         321578      Dinophyceae         321606    Gonyaulacales
# 35            NaN              NaN            NaN              NaN
# 36            NaN              NaN            NaN              NaN
# 40            NaN              NaN            NaN              NaN
# 42            NaN              NaN            NaN              NaN
# 44            NaN              NaN            NaN              NaN
# 58            NaN              NaN            NaN              NaN
# 61            NaN              NaN            NaN              NaN
# 62            NaN              NaN            NaN              NaN
# 68            NaN              NaN            NaN              NaN
# 70            NaN              NaN            NaN              NaN
# 72            NaN              NaN            NaN              NaN
# 74            NaN              NaN            NaN              NaN
#
#    genus_taxon_id  genus_taxon_name family_taxon_id family_taxon_name
# 0          443826  Labyrinthodinium             NaN               NaN
# 1          325673      Maduradinium          277915     Peridiniaceae
# 2          336773        Pyxidiella          277915     Peridiniaceae
# 3          276893      Andalusiella          277915     Peridiniaceae
# 4          477210     Abratopdinium          321581    Deflandreaceae
# 6          276986       Acanthaulax             NaN               NaN
# 8          323991    Achilleodinium          321603    Gonyaulacaceae
# 10         277048     Achomosphaera          321603    Gonyaulacaceae
# 35            NaN               NaN             NaN               NaN
# 36            NaN               NaN             NaN               NaN
# 40            NaN               NaN             NaN               NaN
# 42            NaN               NaN             NaN               NaN
# 44            NaN               NaN             NaN               NaN
# 58            NaN               NaN             NaN               NaN
# 61            NaN               NaN             NaN               NaN
# 62            NaN               NaN             NaN               NaN
# 68            NaN               NaN             NaN               NaN
# 70            NaN               NaN             NaN               NaN
# 72            NaN               NaN             NaN               NaN
# 74            NaN               NaN             NaN               NaN

# %%
genus_df.to_csv('tmp/genus.csv', index=False)
