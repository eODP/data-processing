# %% [markdown]
# #  NOAA DSDP taxa list
# ## 1-96 taxa
#
# Create list of taxa for NOAA DSDP files. Compare NOAA taxa with the LIMS approved taxa that the PIs have already approved in order create a list of unapproved NOAA taxa. Add PBDB data to unapproved taxa.

# %%
import sys
import csv
import glob
import os
import requests
import re
import time 

sys.path.append('../../')
import pandas as pd
import numpy as np

# import db 
import scripts.normalize_taxa as nt
from config import OUTPUT_DIR, CLEAN_DATA_DIR, RAW_DATA_DIR
from scripts.pbdb import get_parent_taxa, PBDB_TAXA_NAME

# %%
# date = '2021-07-28'
# date = '2021-08-05'
date='2021-11-29'

base_dir = CLEAN_DATA_DIR

input_file = RAW_DATA_DIR/'PI_processed_files'/f'NOAA_taxa_lists_taxa_list_{date}.csv'
input_pbdb_file = OUTPUT_DIR/'taxa'/'NOAA'/f"PI_normalized_taxa_list_with_pbdb_{date}.csv"


metadata_path = OUTPUT_DIR/'metadata'/'NOAA'/'noaa_dsdp_files.csv'
LIMS_taxa_path = OUTPUT_DIR/'taxa'/'LIMS'/f'taxa_list_2021-07-28.csv'


merged_path = OUTPUT_DIR/'taxa'/'draft'/'NOAA'/f'taxa_merged_{date}.csv'
merged2_path = OUTPUT_DIR/'taxa'/'draft'/'NOAA'/f'taxa_merged2_{date}.csv'

all_taxa_path = OUTPUT_DIR/'taxa'/'draft'/'NOAA'/f'all_taxa_list_{date}.csv'

taxa_path = OUTPUT_DIR/'taxa'/'draft'/'NOAA'/f'taxa_list_{date}.csv'
genus_path = OUTPUT_DIR/'taxa'/'draft'/'NOAA'/f'genus_pbdb_{date}.csv'
taxa_pbdb_path = OUTPUT_DIR/'taxa'/'draft'/'NOAA'/f'taxa_list_pbdb_{date}.csv'

# %%
def log_df(df, row_count=5):
    print(df.shape)
    return df.head(row_count)

# %% [markdown]
# ## Create NOAA taxa list

# %%
metadata = pd.read_csv(metadata_path)
log_df(metadata)
# Out:
# (4477, 5)
#                                       path       type           taxon_group  \
# 0  NOAA/DSDP_core_data/61/462/radiolar.csv       taxa          radiolarians
# 1   NOAA/DSDP_core_data/61/462/ageprof.csv        age                   NaN
# 2  NOAA/DSDP_core_data/61/462/b_forams.csv       taxa   benthic_foraminfera
# 3  NOAA/DSDP_core_data/61/462/p_forams.csv       taxa  planktic_foraminfera
# 4   NOAA/DSDP_core_data/61/462/hr_desc.csv  hard_rock                   NaN
#
#   expedition site
# 0         61  462
# 1         61  462
# 2         61  462
# 3         61  462
# 4         61  462

# %% [markdown]
# read all the taxa files to get unique taxa names

# %%
# 9933
taxa = set()

for index, row in metadata.iterrows():
    if row['type'] == 'taxa':
        df = pd.read_csv(base_dir/row['path'])
        df.dropna(axis=0, inplace=True, how='all')
        df['temp'] = df['fossil'].str.strip() +  '|' + row['taxon_group']
        
        taxa.update(df['temp'])
        
len(taxa)
#9933
# Out:
# 9933

# %%
list(taxa)[0:5]
# Out:
# [nan,
#  'Boldia sp.|benthic_foraminfera',
#  'Dictyocha perlaevis flexatella|silicoflagellates',
#  'Cladogramma californicum|diatoms',
#  'Spiroplectammina biformis|benthic_foraminfera']

# %%
# 9932
taxa_list = []

for taxon in taxa:
    if not pd.isna(taxon):
        taxon_name, taxon_group = taxon.split('|')
        
        # remove (text) (q) from taxon name    
        simplified_name = re.sub('\(.*?\)$', '', taxon_name).strip()
        taxon_name_parts = simplified_name.split(' ')

        data = {'verbatim_name': taxon_name, 
                'taxon_group': taxon_group, 
                'genus name': taxon_name_parts[0],
                'simplified_name': simplified_name}
        if len(taxon_name_parts) > 1:
            data['species name'] = taxon_name_parts[1]
        if len(taxon_name_parts) == 3:
            data['subspecies name'] = taxon_name_parts[2]

        taxa_list.append(data)
        
len(taxa_list)
# Out:
# 9932

# %%
noaa_taxa_df = pd.DataFrame(taxa_list).sort_values('verbatim_name')
log_df(noaa_taxa_df)
# Out:
# (9932, 6)
#                   verbatim_name           taxon_group     genus name  \
# 4650                Abas wittii               diatoms           Abas
# 585   Abathomphalus intermedius  planktic_foraminfera  Abathomphalus
# 6324  Abathomphalus mayaroensis  planktic_foraminfera  Abathomphalus
# 2806                  Abies sp.                pollen          Abies
# 3588           Abutilon sp. (q)                pollen       Abutilon
#
#                 simplified_name species name subspecies name
# 4650                Abas wittii       wittii             NaN
# 585   Abathomphalus intermedius  intermedius             NaN
# 6324  Abathomphalus mayaroensis  mayaroensis             NaN
# 2806                  Abies sp.          sp.             NaN
# 3588               Abutilon sp.          sp.             NaN

# %% [markdown]
# ## compare and replace taxon groups
#
# replace NOAA taxon groups with LIMS taxon groups

# %%
LIMS_taxa_df = pd.read_csv(LIMS_taxa_path)

# %%
LIMS_groups = list(LIMS_taxa_df['taxon_group'].unique())
LIMS_groups.sort()
LIMS_groups
# Out:
# ['benthic_forams',
#  'bolboformids',
#  'chrysophyte_cysts',
#  'diatoms',
#  'dinoflagellates',
#  'ebridians',
#  'nannofossils',
#  'ostracods',
#  'palynology',
#  'planktic_forams',
#  'radiolarians',
#  'silicoflagellates']

# %%
noaa_groups = list(noaa_taxa_df['taxon_group'].unique())
noaa_groups.sort()
noaa_groups
# Out:
# ['benthic_foraminfera',
#  'diatoms',
#  'dinoflagellates',
#  'ebridians',
#  'nannofossils',
#  'ostracods',
#  'phytoliths',
#  'planktic_foraminfera',
#  'pollen',
#  'radiolarians',
#  'silicoflagellates']

# %%
set(noaa_groups) -  set(LIMS_groups)
# Out:
# {'benthic_foraminfera', 'phytoliths', 'planktic_foraminfera', 'pollen'}

# %%
noaa_taxa_df = noaa_taxa_df.replace(['benthic_foraminfera', 'planktic_foraminfera'],
                                    ['benthic_forams', 'planktic_forams'])
noaa_taxa_df.head()
# Out:
#                   verbatim_name      taxon_group     genus name  \
# 4650                Abas wittii          diatoms           Abas
# 585   Abathomphalus intermedius  planktic_forams  Abathomphalus
# 6324  Abathomphalus mayaroensis  planktic_forams  Abathomphalus
# 2806                  Abies sp.           pollen          Abies
# 3588           Abutilon sp. (q)           pollen       Abutilon
#
#                 simplified_name species name subspecies name
# 4650                Abas wittii       wittii             NaN
# 585   Abathomphalus intermedius  intermedius             NaN
# 6324  Abathomphalus mayaroensis  mayaroensis             NaN
# 2806                  Abies sp.          sp.             NaN
# 3588               Abutilon sp.          sp.             NaN

# %%
noaa_taxa_df.to_csv(all_taxa_path, index=False)

# %% [markdown]
# ## create csv that compares NOAA taxa list with LIMS approved taxa

# %% [markdown]
# get NOAA taxa

# %%
# 9932
noaa_taxa_df = pd.read_csv(all_taxa_path)

log_df(noaa_taxa_df)
# Out:
# (9932, 6)
#                verbatim_name      taxon_group     genus name  \
# 0                Abas wittii          diatoms           Abas
# 1  Abathomphalus intermedius  planktic_forams  Abathomphalus
# 2  Abathomphalus mayaroensis  planktic_forams  Abathomphalus
# 3                  Abies sp.           pollen          Abies
# 4           Abutilon sp. (q)           pollen       Abutilon
#
#              simplified_name species name subspecies name
# 0                Abas wittii       wittii             NaN
# 1  Abathomphalus intermedius  intermedius             NaN
# 2  Abathomphalus mayaroensis  mayaroensis             NaN
# 3                  Abies sp.          sp.             NaN
# 4               Abutilon sp.          sp.             NaN

# %% [markdown]
# get LIMS taxa

# %%
# 4209
LIMS_taxa_df = pd.read_csv(LIMS_taxa_path)
log_df(LIMS_taxa_df)
# Out:
# (4209, 12)
#       Any taxon above genus genus modifier   genus name subgenera modifier  \
# 0                       NaN            NaN  Euuvigerina                NaN
# 1                       NaN            NaN  Euuvigerina                NaN
# 2       Foraminifera indet.            NaN          NaN                NaN
# 3  Pleurostomellidae indet.            NaN          NaN                NaN
# 4          Ostracoda indet.            NaN          NaN                NaN
#
#   subgenera name species modifier species name subspecies modifier  \
# 0            NaN              NaN       miozea                 NaN
# 1            NaN              NaN      rodleyi                 NaN
# 2            NaN              NaN          NaN                 NaN
# 3            NaN              NaN          NaN                 NaN
# 4            NaN              NaN          NaN                 NaN
#
#   subspecies name non-taxa descriptor           normalized_name  \
# 0             NaN                 NaN        Euuvigerina miozea
# 1             NaN                 NaN       Euuvigerina rodleyi
# 2             NaN                 NaN       Foraminifera indet.
# 3             NaN                 NaN  Pleurostomellidae indet.
# 4             NaN                 NaN          Ostracoda indet.
#
#       taxon_group
# 0  benthic_forams
# 1  benthic_forams
# 2  benthic_forams
# 3  benthic_forams
# 4  benthic_forams

# %% [markdown]
# add simplified_name without descriptor

# %%
del LIMS_taxa_df['normalized_name']

# %%
LIMS_taxa_df = nt.add_normalized_name_column(LIMS_taxa_df, 
                                                 include_descriptor=False, 
                                                 col_name="simplified_name")

# %%
LIMS_taxa_df[LIMS_taxa_df['non-taxa descriptor'].notna()].head(2)
# Out:
#     Any taxon above genus genus modifier       genus name subgenera modifier  \
# 28                    NaN            NaN  Globigerinoides                NaN
# 201                   NaN            NaN         Bolivina                NaN
#
#     subgenera name species modifier species name subspecies modifier  \
# 28             NaN              NaN   sacculifer                 NaN
# 201            NaN             cf.     crenulata                 NaN
#
#     subspecies name non-taxa descriptor      taxon_group  \
# 28              NaN         without sac  planktic_forams
# 201             NaN           crenulate   benthic_forams
#
#                 simplified_name
# 28   Globigerinoides sacculifer
# 201      Bolivina cf. crenulata

# %%
LIMS_taxa_df = pd.DataFrame(LIMS_taxa_df[['taxon_group', 'simplified_name']])
log_df(LIMS_taxa_df)
# Out:
# (4209, 2)
#       taxon_group           simplified_name
# 0  benthic_forams        Euuvigerina miozea
# 1  benthic_forams       Euuvigerina rodleyi
# 2  benthic_forams       Foraminifera indet.
# 3  benthic_forams  Pleurostomellidae indet.
# 4  benthic_forams          Ostracoda indet.

# %% [markdown]
# ### merge NOAA taxa with LIMS taxa

# %%
# 10109 
merged_df = pd.merge(noaa_taxa_df, LIMS_taxa_df,  
                     on=['simplified_name', 'taxon_group' ], 
                     how='left',
                     indicator='_merge_approved')

log_df(merged_df)
# Out:
# (10109, 7)
#                verbatim_name      taxon_group     genus name  \
# 0                Abas wittii          diatoms           Abas
# 1  Abathomphalus intermedius  planktic_forams  Abathomphalus
# 2  Abathomphalus mayaroensis  planktic_forams  Abathomphalus
# 3                  Abies sp.           pollen          Abies
# 4           Abutilon sp. (q)           pollen       Abutilon
#
#              simplified_name species name subspecies name _merge_approved
# 0                Abas wittii       wittii             NaN       left_only
# 1  Abathomphalus intermedius  intermedius             NaN       left_only
# 2  Abathomphalus mayaroensis  mayaroensis             NaN            both
# 3                  Abies sp.          sp.             NaN       left_only
# 4               Abutilon sp.          sp.             NaN       left_only

# %%
# 9932
merged_df = merged_df.drop_duplicates()
log_df(merged_df)
# Out:
# (9932, 7)
#                verbatim_name      taxon_group     genus name  \
# 0                Abas wittii          diatoms           Abas
# 1  Abathomphalus intermedius  planktic_forams  Abathomphalus
# 2  Abathomphalus mayaroensis  planktic_forams  Abathomphalus
# 3                  Abies sp.           pollen          Abies
# 4           Abutilon sp. (q)           pollen       Abutilon
#
#              simplified_name species name subspecies name _merge_approved
# 0                Abas wittii       wittii             NaN       left_only
# 1  Abathomphalus intermedius  intermedius             NaN       left_only
# 2  Abathomphalus mayaroensis  mayaroensis             NaN            both
# 3                  Abies sp.          sp.             NaN       left_only
# 4               Abutilon sp.          sp.             NaN       left_only

# %%
merged_df.to_csv(merged_path, index=False)

# %% [markdown]
# ### compare merge methods
# do merge on simplified_name without taxon groups

# %%
# 10114 
merged2_df = pd.merge(noaa_taxa_df, LIMS_taxa_df,  
                     on=['simplified_name'], 
                     how='left',
                     indicator='_merge_approved')

log_df(merged2_df)
# Out:
# (10114, 8)
#                verbatim_name    taxon_group_x     genus name  \
# 0                Abas wittii          diatoms           Abas
# 1  Abathomphalus intermedius  planktic_forams  Abathomphalus
# 2  Abathomphalus mayaroensis  planktic_forams  Abathomphalus
# 3                  Abies sp.           pollen          Abies
# 4           Abutilon sp. (q)           pollen       Abutilon
#
#              simplified_name species name subspecies name    taxon_group_y  \
# 0                Abas wittii       wittii             NaN              NaN
# 1  Abathomphalus intermedius  intermedius             NaN              NaN
# 2  Abathomphalus mayaroensis  mayaroensis             NaN  planktic_forams
# 3                  Abies sp.          sp.             NaN              NaN
# 4               Abutilon sp.          sp.             NaN              NaN
#
#   _merge_approved
# 0       left_only
# 1       left_only
# 2            both
# 3       left_only
# 4       left_only

# %%
# 9937
merged2_df = merged2_df.drop_duplicates()
log_df(merged2_df)
# Out:
# (9937, 8)
#                verbatim_name    taxon_group_x     genus name  \
# 0                Abas wittii          diatoms           Abas
# 1  Abathomphalus intermedius  planktic_forams  Abathomphalus
# 2  Abathomphalus mayaroensis  planktic_forams  Abathomphalus
# 3                  Abies sp.           pollen          Abies
# 4           Abutilon sp. (q)           pollen       Abutilon
#
#              simplified_name species name subspecies name    taxon_group_y  \
# 0                Abas wittii       wittii             NaN              NaN
# 1  Abathomphalus intermedius  intermedius             NaN              NaN
# 2  Abathomphalus mayaroensis  mayaroensis             NaN  planktic_forams
# 3                  Abies sp.          sp.             NaN              NaN
# 4               Abutilon sp.          sp.             NaN              NaN
#
#   _merge_approved
# 0       left_only
# 1       left_only
# 2            both
# 3       left_only
# 4       left_only

# %% [markdown]
# the reason for the count difference is because the LIMS taxa list sometimes puts a taxa in two groups
#
# NOAA: Selenopemphix nephroides - dinoflagellates
# LIMS: Selenopemphix nephroides - dinoflagellates, palynology

# %% [markdown]
# ## Created taxa list with unapproved NOAA taxa

# %% [markdown]
# Select unapproved NOAA taxa. When _merged is both, it means the taxa has been approved. When _merged is left_only, it means the taxa has not been approved.

# %%
merged_df = pd.read_csv(merged_path)
log_df(merged_df)
# Out:
# (9932, 7)
#                verbatim_name      taxon_group     genus name  \
# 0                Abas wittii          diatoms           Abas
# 1  Abathomphalus intermedius  planktic_forams  Abathomphalus
# 2  Abathomphalus mayaroensis  planktic_forams  Abathomphalus
# 3                  Abies sp.           pollen          Abies
# 4           Abutilon sp. (q)           pollen       Abutilon
#
#              simplified_name species name subspecies name _merge_approved
# 0                Abas wittii       wittii             NaN       left_only
# 1  Abathomphalus intermedius  intermedius             NaN       left_only
# 2  Abathomphalus mayaroensis  mayaroensis             NaN            both
# 3                  Abies sp.          sp.             NaN       left_only
# 4               Abutilon sp.          sp.             NaN       left_only

# %%
# (7763, 7)
LIMS_taxa_df = merged_df[merged_df['_merge_approved'] == 'left_only'].copy()

log_df(LIMS_taxa_df)
# Out:
# (7763, 7)
#                verbatim_name      taxon_group     genus name  \
# 0                Abas wittii          diatoms           Abas
# 1  Abathomphalus intermedius  planktic_forams  Abathomphalus
# 3                  Abies sp.           pollen          Abies
# 4           Abutilon sp. (q)           pollen       Abutilon
# 5          Abyssamina incisa   benthic_forams     Abyssamina
#
#              simplified_name species name subspecies name _merge_approved
# 0                Abas wittii       wittii             NaN       left_only
# 1  Abathomphalus intermedius  intermedius             NaN       left_only
# 3                  Abies sp.          sp.             NaN       left_only
# 4               Abutilon sp.          sp.             NaN       left_only
# 5          Abyssamina incisa       incisa             NaN       left_only

# %% [markdown]
# create csv of unapproved NOAA taxa

# %%
LIMS_taxa_df.to_csv(taxa_path, index=False)

# %% [markdown]
# ## Create genus list with PBDB data for NOAA taxa that aren't approved

# %% [markdown]
# Look up the genus for unapproved taxa in PBDB

# %%
taxa_df = pd.read_csv(taxa_path)
log_df(taxa_df)
# Out:
# (7763, 7)
#                verbatim_name      taxon_group     genus name  \
# 0                Abas wittii          diatoms           Abas
# 1  Abathomphalus intermedius  planktic_forams  Abathomphalus
# 2                  Abies sp.           pollen          Abies
# 3           Abutilon sp. (q)           pollen       Abutilon
# 4          Abyssamina incisa   benthic_forams     Abyssamina
#
#              simplified_name species name subspecies name _merge_approved
# 0                Abas wittii       wittii             NaN       left_only
# 1  Abathomphalus intermedius  intermedius             NaN       left_only
# 2                  Abies sp.          sp.             NaN       left_only
# 3               Abutilon sp.          sp.             NaN       left_only
# 4          Abyssamina incisa       incisa             NaN       left_only

# %% [markdown]
# create a dataframe of unique genera

# %%
genus_df = pd.DataFrame(taxa_df['genus name'].unique(), columns=['genus name'])

log_df(genus_df)
# Out:
# (1707, 1)
#       genus name
# 0           Abas
# 1  Abathomphalus
# 2          Abies
# 3       Abutilon
# 4     Abyssamina

# %% [markdown]
# add pbdb taxa data

# %%
for index, row in genus_df.iterrows():        
    if index < 250:
        continue
    time.sleep(0.5)
    
    if index % 50 == 0:
        print(index, end=' ')

        
    url =  PBDB_TAXA_NAME +  row['genus name']
        
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            genus_df.at[index, f'pbdb_taxon_id'] = str(data[0]["taxon_no"])
            genus_df.at[index, f'pbdb_taxon_name'] = data[0]["taxon_name"]
            genus_df.at[index, f'pbdb_taxon_rank'] = data[0]["taxon_rank"]
            
            round = 0
            get_parent_taxa(genus_df, data[0]["parent_no"], data[0]["taxon_rank"], round, index, None)

# %%
genus_df.head()

# %% [markdown]
# create genus csv

# %%
genus_df.to_csv(genus_path, index=False)

# %% [markdown]
# # update genus file
# look for genus that don't have higher pbdb data

# %%
genus_df = pd.read_csv(genus_path, dtype=str)

# %%
missing_df = genus_df[genus_df['pbdb_taxon_id'].notna() & 
         genus_df['family_taxon_id'].isna() &
         genus_df['order_taxon_id'].isna() &
         genus_df['class_taxon_id'].isna() &
         genus_df['phylum_taxon_id'].isna() &
         genus_df['kingdom_taxon_id'].isna()]

missing_df.shape
# Out:
# (32, 16)

# %%
for index, row in missing_df.iterrows():        
    time.sleep(0.5)
    
    
    print(index, row['genus name'])

        
    url =  PBDB_TAXA_NAME +  row['genus name']
        
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()["records"]
        if len(data) == 1:
            genus_df.at[index, f'pbdb_taxon_id'] = str(data[0]["taxon_no"])
            genus_df.at[index, f'pbdb_taxon_name'] = data[0]["taxon_name"]
            genus_df.at[index, f'pbdb_taxon_rank'] = data[0]["taxon_rank"]
            
            round = 0
            get_parent_taxa(genus_df, data[0]["parent_no"], data[0]["taxon_rank"], round, index, None)
# Out:
# 7 Acaciapollenites
# 94 Anthocorys
# 151 Australopollis
# 319 Chenopodipollis
# 329 Chrysophyta
# 370 Comasphaeridium
# 405 Crassosphaera
# 443 Cyclopsiella
# 446 Cymatiosphaera
# 507 Dictyosphaeridium
# 553 Echitricolporites
# 746 Helminthopsis
# 779 Homotryblium
# 792 Hypericum
# 861 Leiofusa
# 862 Leiosphaeridia
# 974 Membranosphaera
# 981 Micrhystridium
# 993 Mimosaceae
# 1182 Platycystidia
# 1379 Sagittaria
# 1396 Schizocolpus
# 1409 Sethamphora
# 1458 Spondias
# 1509 Striatricolpites
# 1535 Tasmanites
# 1540 Tectatodinium
# 1637 Tuberculodinium
# 1675 Veryhachium
# 1678 Virola
# 1737 Nipponocythere
# 1739 Palaeostomocystis

# %%
genus_df.to_csv(genus_path, index=False)

# %% [markdown]
# ## create taxa list with pbdb info for the PIs

# %%
genus_df = pd.read_csv(genus_path, dtype= str)
log_df(genus_df)
# Out:
# (1751, 16)
#       genus name pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank class_taxon_id  \
# 0           Abas        441243            Abas           genus          69587
# 1  Abathomphalus           758   Abathomphalus           genus            NaN
# 2          Abies         55065           Abies           genus          82141
# 3       Abutilon           NaN             NaN             NaN            NaN
# 4     Abyssamina           762      Abyssamina           genus         428504
#
#     class_taxon_name order_taxon_id order_taxon_name family_taxon_id  \
# 0  Bacillariophyceae         426784      Hemiaulales          387088
# 1                NaN            NaN              NaN             NaN
# 2          Pinopsida          82140          Pinales           54794
# 3                NaN            NaN              NaN             NaN
# 4      Globothalamea         279579        Rotaliida          103796
#
#   family_taxon_name phylum_taxon_id phylum_taxon_name kingdom_taxon_id  \
# 0      Hemiaulaceae          432613        Ochrophyta              NaN
# 1               NaN          288974      Foraminifera           212476
# 2          Pinaceae           82139         Pinophyta            54311
# 3               NaN             NaN               NaN              NaN
# 4  Chilostomellidae          288974      Foraminifera           212476
#
#   kingdom_taxon_name unranked clade_taxon_id unranked clade_taxon_name
# 0                NaN                     NaN                       NaN
# 1           Rhizaria                     NaN                       NaN
# 2            Plantae                     NaN                       NaN
# 3                NaN                     NaN                       NaN
# 4           Rhizaria                     NaN                       NaN

# %%
unapproved_df = pd.read_csv(taxa_path)

log_df(unapproved_df)
# Out:
# (7763, 7)
#                verbatim_name      taxon_group     genus name  \
# 0                Abas wittii          diatoms           Abas
# 1  Abathomphalus intermedius  planktic_forams  Abathomphalus
# 2                  Abies sp.           pollen          Abies
# 3           Abutilon sp. (q)           pollen       Abutilon
# 4          Abyssamina incisa   benthic_forams     Abyssamina
#
#              simplified_name species name subspecies name _merge_approved
# 0                Abas wittii       wittii             NaN       left_only
# 1  Abathomphalus intermedius  intermedius             NaN       left_only
# 2                  Abies sp.          sp.             NaN       left_only
# 3               Abutilon sp.          sp.             NaN       left_only
# 4          Abyssamina incisa       incisa             NaN       left_only

# %% [markdown]
# merge NOAA unapproved taxa with pbdb data

# %%
merged_df = pd.merge(LIMS_taxa_df, genus_df, 
                     on = 'genus name', 
                     how='left',
                     indicator='_merge_pbdb')

log_df(merged_df)
# Out:
# (7763, 23)
#                verbatim_name      taxon_group     genus name  \
# 0                Abas wittii          diatoms           Abas
# 1  Abathomphalus intermedius  planktic_forams  Abathomphalus
# 2                  Abies sp.           pollen          Abies
# 3           Abutilon sp. (q)           pollen       Abutilon
# 4          Abyssamina incisa   benthic_forams     Abyssamina
#
#              simplified_name species name subspecies name _merge_approved  \
# 0                Abas wittii       wittii             NaN       left_only
# 1  Abathomphalus intermedius  intermedius             NaN       left_only
# 2                  Abies sp.          sp.             NaN       left_only
# 3               Abutilon sp.          sp.             NaN       left_only
# 4          Abyssamina incisa       incisa             NaN       left_only
#
#   pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank  ... order_taxon_name  \
# 0        441243            Abas           genus  ...      Hemiaulales
# 1           758   Abathomphalus           genus  ...              NaN
# 2         55065           Abies           genus  ...          Pinales
# 3           NaN             NaN             NaN  ...              NaN
# 4           762      Abyssamina           genus  ...        Rotaliida
#
#   family_taxon_id family_taxon_name phylum_taxon_id phylum_taxon_name  \
# 0          387088      Hemiaulaceae          432613        Ochrophyta
# 1             NaN               NaN          288974      Foraminifera
# 2           54794          Pinaceae           82139         Pinophyta
# 3             NaN               NaN             NaN               NaN
# 4          103796  Chilostomellidae          288974      Foraminifera
#
#   kingdom_taxon_id kingdom_taxon_name unranked clade_taxon_id  \
# 0              NaN                NaN                     NaN
# 1           212476           Rhizaria                     NaN
# 2            54311            Plantae                     NaN
# 3              NaN                NaN                     NaN
# 4           212476           Rhizaria                     NaN
#
#   unranked clade_taxon_name _merge_pbdb
# 0                       NaN        both
# 1                       NaN        both
# 2                       NaN        both
# 3                       NaN        both
# 4                       NaN        both
#
# [5 rows x 23 columns]

# %% [markdown]
# add columns

# %%
merged_df['name'] = merged_df['verbatim_name'].str.strip()
merged_df['Comment'] = np.nan
merged_df['Notes (change to Internal only notes?)'] = np.nan
merged_df['Any taxon above genus'] = np.nan
merged_df['genus modifier'] = ''
merged_df['subgenera modifier'] = np.nan
merged_df['subgenera name'] = np.nan
merged_df['species modifier'] = np.nan
merged_df['subspecies modifier'] = np.nan
merged_df['non-taxa descriptor'] = np.nan
merged_df['comments'] = np.nan

# %% [markdown]
# remove (q) from name, and add (q) to genus modifier

# %%
for index, row in merged_df.iterrows():
    if '(q)' in row['name']:
        
        merged_df.at[index,'name']=re.sub('(.*?) \(q\)', r'? \1', row['name'])
        merged_df.at[index,'genus modifier'] = '?'
        
log_df(merged_df)
# Out:
# (7763, 34)
#                verbatim_name      taxon_group     genus name  \
# 0                Abas wittii          diatoms           Abas
# 1  Abathomphalus intermedius  planktic_forams  Abathomphalus
# 2                  Abies sp.           pollen          Abies
# 3           Abutilon sp. (q)           pollen       Abutilon
# 4          Abyssamina incisa   benthic_forams     Abyssamina
#
#              simplified_name species name subspecies name _merge_approved  \
# 0                Abas wittii       wittii             NaN       left_only
# 1  Abathomphalus intermedius  intermedius             NaN       left_only
# 2                  Abies sp.          sp.             NaN       left_only
# 3               Abutilon sp.          sp.             NaN       left_only
# 4          Abyssamina incisa       incisa             NaN       left_only
#
#   pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank  ... Comment  \
# 0        441243            Abas           genus  ...     NaN
# 1           758   Abathomphalus           genus  ...     NaN
# 2         55065           Abies           genus  ...     NaN
# 3           NaN             NaN             NaN  ...     NaN
# 4           762      Abyssamina           genus  ...     NaN
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN                   NaN
# 1                                    NaN                   NaN
# 2                                    NaN                   NaN
# 3                                    NaN                   NaN              ?
# 4                                    NaN                   NaN
#
#   subgenera modifier subgenera name species modifier subspecies modifier  \
# 0                NaN            NaN              NaN                 NaN
# 1                NaN            NaN              NaN                 NaN
# 2                NaN            NaN              NaN                 NaN
# 3                NaN            NaN              NaN                 NaN
# 4                NaN            NaN              NaN                 NaN
#
#   non-taxa descriptor comments
# 0                 NaN      NaN
# 1                 NaN      NaN
# 2                 NaN      NaN
# 3                 NaN      NaN
# 4                 NaN      NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# reorder columns and sort rows

# %%
merged_df = merged_df.reindex(columns=['taxon_group', 'verbatim_name', 'name', 'Comment',
                                       'Notes (change to Internal only notes?)',
                                       'Any taxon above genus', 
                                       'genus modifier', 'genus name', 
                                       'subgenera modifier', 'subgenera name',
                                       'species modifier', 'species name', 
                                       'subspecies modifier', 'subspecies name',
                                       'non-taxa descriptor', 'comments',
                                       'pbdb_taxon_id', 'pbdb_taxon_name',
                                       'pbdb_taxon_rank', '_simplified_name',
                                       '_merge_approved', '_merge_pbdb'
                                      ])

merged_df.sort_values(by=['taxon_group', 'verbatim_name'], inplace=True)

log_df(merged_df)
# Out:
# (7763, 22)
#         taxon_group           verbatim_name                    name  Comment  \
# 4    benthic_forams       Abyssamina incisa       Abyssamina incisa      NaN
# 131  benthic_forams  Adercotryma glomeratum  Adercotryma glomeratum      NaN
# 132  benthic_forams         Adercotryma sp.         Adercotryma sp.      NaN
# 144  benthic_forams      Alabamina decorata      Alabamina decorata      NaN
# 145  benthic_forams    Alabamina haitiensis    Alabamina haitiensis      NaN
#
#      Notes (change to Internal only notes?)  Any taxon above genus  \
# 4                                       NaN                    NaN
# 131                                     NaN                    NaN
# 132                                     NaN                    NaN
# 144                                     NaN                    NaN
# 145                                     NaN                    NaN
#
#     genus modifier   genus name  subgenera modifier  subgenera name  ...  \
# 4                    Abyssamina                 NaN             NaN  ...
# 131                 Adercotryma                 NaN             NaN  ...
# 132                 Adercotryma                 NaN             NaN  ...
# 144                   Alabamina                 NaN             NaN  ...
# 145                   Alabamina                 NaN             NaN  ...
#
#      subspecies modifier subspecies name  non-taxa descriptor comments  \
# 4                    NaN             NaN                  NaN      NaN
# 131                  NaN             NaN                  NaN      NaN
# 132                  NaN             NaN                  NaN      NaN
# 144                  NaN             NaN                  NaN      NaN
# 145                  NaN             NaN                  NaN      NaN
#
#      pbdb_taxon_id  pbdb_taxon_name pbdb_taxon_rank _simplified_name  \
# 4              762       Abyssamina           genus              NaN
# 131            774      Adercotryma           genus              NaN
# 132            774      Adercotryma           genus              NaN
# 144            788        Alabamina           genus              NaN
# 145            788        Alabamina           genus              NaN
#
#     _merge_approved  _merge_pbdb
# 4         left_only         both
# 131       left_only         both
# 132       left_only         both
# 144       left_only         both
# 145       left_only         both
#
# [5 rows x 22 columns]

# %%
merged_df.to_csv(taxa_pbdb_path, index=False)

# %% [markdown]
# ## fix taxalist from PIs

# %% [markdown]
# update google sheet taxa list from PIs to deal with (q) in verbatim name. only need to do this once.

# %%
input_file = RAW_DATA_DIR/'PI_processed_files'/f'NOAA_taxa_lists_taxa_list_2021-08-05.csv'

taxa_df = pd.read_csv(input_file, dtype=str)
log_df(taxa_df)
# Out:
# (7763, 20)
#       taxon_group           verbatim_name name Comment  \
# 0  benthic_forams       Abyssamina incisa  NaN     NaN
# 1  benthic_forams  Adercotryma glomeratum  NaN     NaN
# 2  benthic_forams         Adercotryma sp.  NaN     NaN
# 3  benthic_forams      Alabamina decorata  NaN     NaN
# 4  benthic_forams    Alabamina haitiensis  NaN     NaN
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN                   NaN            NaN
# 1                                    NaN                   NaN            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#     genus name subgenera modifier subgenera name species modifier  \
# 0   Abyssamina                NaN            NaN              NaN
# 1  Adercotryma                NaN            NaN              NaN
# 2  Adercotryma                NaN            NaN              NaN
# 3    Alabamina                NaN            NaN              NaN
# 4    Alabamina                NaN            NaN              NaN
#
#   species name subspecies modifier subspecies name non-taxa descriptor  \
# 0       incisa                 NaN             NaN                 NaN
# 1   glomeratum                 NaN             NaN                 NaN
# 2          sp.                 NaN             NaN                 NaN
# 3     decorata                 NaN             NaN                 NaN
# 4   haitiensis                 NaN             NaN                 NaN
#
#   comments pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank Unnamed: 19
# 0      NaN           762      Abyssamina           genus         NaN
# 1      NaN           774     Adercotryma           genus         NaN
# 2      NaN           774     Adercotryma           genus         NaN
# 3      NaN           788       Alabamina           genus         NaN
# 4      NaN           788       Alabamina           genus         NaN

# %%
for index, row in taxa_df.iterrows():
    # don't overwrite existing name
    if isinstance(row['name'], str) :
        continue
    # if verbatim name has '(q)'
    if '(q)' in row['verbatim_name']:
        # set 'name' to 'verbatim name' without '(q)' 
        taxa_df.at[index,'name']=re.sub('(.*?) ?\(q\)', r'? \1', row['verbatim_name'])
        # set 'genus modifier' to '?'
        taxa_df.at[index,'genus modifier'] = '?'

        
log_df(taxa_df)
# Out:
# (7763, 20)
#       taxon_group           verbatim_name name Comment  \
# 0  benthic_forams       Abyssamina incisa  NaN     NaN
# 1  benthic_forams  Adercotryma glomeratum  NaN     NaN
# 2  benthic_forams         Adercotryma sp.  NaN     NaN
# 3  benthic_forams      Alabamina decorata  NaN     NaN
# 4  benthic_forams    Alabamina haitiensis  NaN     NaN
#
#   Notes (change to Internal only notes?) Any taxon above genus genus modifier  \
# 0                                    NaN                   NaN            NaN
# 1                                    NaN                   NaN            NaN
# 2                                    NaN                   NaN            NaN
# 3                                    NaN                   NaN            NaN
# 4                                    NaN                   NaN            NaN
#
#     genus name subgenera modifier subgenera name species modifier  \
# 0   Abyssamina                NaN            NaN              NaN
# 1  Adercotryma                NaN            NaN              NaN
# 2  Adercotryma                NaN            NaN              NaN
# 3    Alabamina                NaN            NaN              NaN
# 4    Alabamina                NaN            NaN              NaN
#
#   species name subspecies modifier subspecies name non-taxa descriptor  \
# 0       incisa                 NaN             NaN                 NaN
# 1   glomeratum                 NaN             NaN                 NaN
# 2          sp.                 NaN             NaN                 NaN
# 3     decorata                 NaN             NaN                 NaN
# 4   haitiensis                 NaN             NaN                 NaN
#
#   comments pbdb_taxon_id pbdb_taxon_name pbdb_taxon_rank Unnamed: 19
# 0      NaN           762      Abyssamina           genus         NaN
# 1      NaN           774     Adercotryma           genus         NaN
# 2      NaN           774     Adercotryma           genus         NaN
# 3      NaN           788       Alabamina           genus         NaN
# 4      NaN           788       Alabamina           genus         NaN

# %%
taxa_df.to_csv(OUTPUT_DIR/'taxa'/'draft'/'NOAA'/'google_sheet_taxa_lists_2021-08-05.csv', index=False)
